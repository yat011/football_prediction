# %%
import urllib 
import math
from datetime import date
import re
import time
from IPython.display import clear_output
from datetime import date
import sys
import pandas as pd
import numpy as np
class DataGrapper:
    
    def updateTeams(self,from_year,to_year):
        df = pd.read_csv('teamId.csv',index_col=0)
        teamMatchUrl = 'http://app.gooooal.com/teamAllMatch.do?sid={}&tid={}&t=0&lang=tr'
        teams = df.values
        for i in range(teams.shape[0]):
            thisDf = None
            for year in range(from_year,to_year):
                url = teamMatchUrl.format(year,teams[i,0])
                print(url)
                tdf = pd.read_html(url,attrs={'id':'fb_match_odds_result_table_0_0'},encoding='UTF-8')[0]
                tdf = tdf.drop(df.index[[0]])
                if thisDf is None:
                    thisDf=tdf
                else:
                    thisDf =thisDf.append(tdf)
            print(teams[i,1])
            thisDf.to_csv("teams/"+teams[i,1]+".csv",index=False)

    def getOdds(self,date):
        dateStr = "{}-{}-{}".format(date.year,date.month,date.day)
        print("get {}".format(dateStr))
        url = 'http://info.livescore123.com/1x2/companyhistory.aspx?id=432&company=HK+Jockey+Club'
        data = {'matchdate': dateStr,'Submit': 'Search','key': ""}
        f = urllib.request.urlopen(
                url     = url,
                data    = urllib.parse.urlencode(data).encode('utf8')
            )
        raw= f.read()
        df = pd.read_html(raw,attrs={'class':'schedule'},header=0)[0]
        df = df[df['League'] == 'ENG PR'] 
        df = df [['Home','Away','HW','D','AW']]
        return df 
    def updateOdds(self,greater_than,origin, out_odds):
        footballdata = pd.read_csv(origin)
        footballdata['Date'] = pd.to_datetime(footballdata['Date'],dayfirst=True)
        if 'JocH' not in footballdata:
            footballdata['JocH']=pd.Series(np.zeros(shape=(footballdata.shape[0],)), index=footballdata.index) 
            footballdata['JocD'] = pd.Series(np.zeros(shape=(footballdata.shape[0],)), index=footballdata.index) 
            footballdata['JocA'] = pd.Series(np.zeros(shape=(footballdata.shape[0],)), index=footballdata.index)         
        dates = footballdata['Date'].drop_duplicates()
        dates  = dates[dates > greater_than]
        for indx, d in enumerate(dates):
            clear_output()
            print("{}/{} -- {}".format(indx,dates.shape[0],d))
            sys.stdout.flush()
            odds = None
            err_count =0
            while err_count < 5:
                try:
                    odds = self.getOdds(d)
                    break
                except Exception as e:
                    print (e)
                    time.sleep(3)
                err_count = err_count +1
            tempdf = footballdata[footballdata['Date'] == d]
            tempdf = tempdf.sort(columns='HomeTeam')
            odds = odds.sort(columns='Home')
            tempdf['JocH']= odds['HW'].values
            tempdf['JocD'] = odds['D'].values
            tempdf['JocA'] = odds['AW'].values
           # print(odds)
            footballdata.update(tempdf)
        footballdata.to_csv(out_odds,index=False)
    def readLastestMatches(self):
        url = 'http://bet.hkjc.com/football/odds/odds_had.aspx?ci=en-US'
        content= urllib.request.urlopen(url).read().decode('utf-8')
        #print(content)
        p2 = '<img src="/nas/jcbwinfo/football/info/images/.*?" alt="(.*?)"'
        p1= '<img src="/nas/jcbwinfo/football/info/images/.*?" alt="(.*?)".*?>'
        league = []
        for m in re.finditer(p1,content,flags=re.M):
            league.append(m.group(1))
        df= pd.read_html(url,attrs={'class':'tOdds'},header =0)[1]
        df = df.dropna(subset=['Expected StopSelling Time'])
        df['Unnamed: 1']=league
        ta = df['Teams(Home vs Away)'].values
        print(ta.shape)
        homeAways =[]
        for v in ta:
            homeAways.append([e.strip() for e in (v.split(' vs '))])
        nha = np.array(homeAways)
        df['HomeTeam']=nha[:,0]
        df['AwayTeam']=nha[:,1]
        rawTimes = df['Expected StopSelling Time'].values
        timesStr = [(v.split()[0])+'/2016' for v in rawTimes]
        print(timesStr)
        df['Date'] = pd.to_datetime(timesStr,dayfirst=True)
        df= df[df['Unnamed: 1']=='Eng Premier']
        df["JocH"] =df["Odds"].values
        df["JocD"]= df["Unnamed: 7"].values
        df["JocA"] = df["Unnamed: 8"].values
        df = df[["HomeTeam","AwayTeam","Date","JocH","JocD","JocA"]]
        return df.dropna(subset=['JocD'])
        #TODO: find epl name, -> epl only -> sort name -> return h,a,date,odds

# %%
tg = DataGrapper()
tg.updateOdds(date(2014,8,15),"dataSet/E2014.csv","dataSet/E2014odds.csv")
# Out:
# 95/96 -- 2015-05-24 00:00:00
# get 2015-5-24

# %%
df.to_csv("dataSet/future.csv",index=False)

# %%
from bs4 import BeautifulSoup
import datetime
import re
def getContentSoup (url):
        count = 0
        content=""
        while(count < 10):
            try:
                content = urllib.request.urlopen(url).read().decode('utf-8')
                break
            except:
                print("re-try")
                time.sleep(5)
                count = count+1
            if count ==10:
                raise Exception("error {}".format(url))
        soup = BeautifulSoup(content,'html.parser')
        return soup
def grapMatchInfo(url):

    from bs4 import BeautifulSoup
    import urllib 
    import math
    from datetime import date
    import datetime
    import re
    import time
    def getContentSoup (url):
        count = 0
        content=""
        while(count < 10):
            try:
                content = urllib.request.urlopen(url).read().decode('utf-8')
                break
            except:
                print("re-try")
                sys.stdout.flush()
                time.sleep(5)
                count = count+1
            if count ==10:
                raise Exception("error {}".format(url))
        soup = BeautifulSoup(content,'html.parser')
        return soup
    
    def summary():
        soup = getContentSoup(url)
        temp = soup.find("div","teams").text.split("\n")[1].split(',')[2:]
        tempstr = " ".join("".join(temp).strip().split(" ")[0:3])
        date = datetime.datetime.strptime(tempstr,"%B %d %Y")
        
        poss = [float(e.text[0:-1]) for e in soup.select("div#summary_possessions text")]
        #extract home id
        homeurl = soup.select("a.tabs-primary__tab-link")[1].get('href')
        homeId = -1 
        for m in re.finditer('/statszone/.*?/matches/.*?/team-stats/(\d+?)/OVERALL_01',homeurl,re.M):
            homeId = m.group(1)
        return date , poss,homeId
    def getTeamStat(homeId):
        
        #passing third
        atkthirdUrl = '/team-stats/{}/1_PASS_08'
        soup = getContentSoup(url+atkthirdUrl.format(homeId))
        awayurl=(soup.select("ul#statzone_pitch_team_filter li.last a")[0].get('href'))
        awayId = -1
        for m in re.finditer('/statszone/.*?/matches/.*?/team-stats/(\d+?)/1_PASS_08',awayurl,re.M):
            awayId = m.group(1)
        
        awayName = soup.select("ul#statzone_pitch_team_filter li.last a")[0].text
        homeName = soup.select("ul#statzone_pitch_team_filter li.first a")[0].text
        teamIds = [homeId,awayId]
        headers = ['atk_3rd','atk_3rd_tot','red_goal','red_on','red_tot','chance_goal', 'chance_tot',
                  'successful_tackle','tackle_tot','successful_clearance','clearance_tot','interceptions','blocks']
        headers = ['H_'+ t for t in headers] + ['A_'+t for t in headers]
        data = []
        for tid in teamIds:
            #name
            #attacking third
            soup = getContentSoup(url+atkthirdUrl.format(tid))
            atkThird = [ int(e.text) for e in soup.select("div.title-wrapper span")]
            data +=atkThird

            #red area
            redurl='/team-stats/{}/0_SHOT_055'.format(tid)
            soup= getContentSoup(url+redurl)
            matchs = ['stroke:yellow;stroke-width:3','stroke:blue;stroke-width:3']
            red_values = [0,0,0]
            for e in soup.select("line.pitch-object") :
                style =  e.get('style')
                red_values[2]+=1
                for indx, m in enumerate(matchs):
                    if style == m:
                        red_values[indx] +=1
                        break
            data+=red_values
            #chance created
            soup= getContentSoup(url+'/team-stats/{}/1_PASS_11'.format(tid))
            matchs = ['stroke:yellow;stroke-width:3']
            chance_values = [0,0]
            for e in soup.select("line.pitch-object") :
                style =  e.get('style')
                chance_values[1]+=1
                for indx, m in enumerate(matchs):
                    if style == m:
                        chance_values[indx] +=1
                        break
            data+=chance_values
            
            #def
            soup= getContentSoup(url+'/team-stats/{}/OVERALL_04'.format(tid))
            def_headers = ['successful_tackle','failed_tackle','successful_clearance','failed_clearance','interceptions','blocks']
            def_values = [0 for i in range(len(def_headers))]
            for e in soup.select("image.pitch-object"):
                href =e.get("xlink:href")
                for indx, header  in enumerate(def_headers):
                    if header in href:
                        def_values[indx]+=1
                        break

            def_values[1]+=def_values[0]
            def_values[3]+= def_values[2]
            data+=def_values
      
        
        
        return homeName, awayName, data,headers
        
    date,poss,homeId = summary()
    homeName, awayName, data,headers=  getTeamStat(homeId)
    n_data = np.array(data).reshape(2,len(headers)/2).T
    print(n_data)
    n_headers = np.ravel(np.array(headers).reshape(2,len(headers)/2).T)
    n_headers = np.hstack(["Date","HomeTeam","AwayTeam","H_poss","A_poss",n_headers])
    result = np.hstack([date,np.ravel(np.vstack([[homeName,awayName],poss,n_data]))])

    return result,n_headers

# %%
result,n_headers  = grapMatchInfo('http://www.fourfourtwo.com/statszone/8-2015/matches/803479')
# Out:
# [30, 18, 22, 7, 22, 6]
# [77, 116, 1, 3, 9, 1, 10, 30, 48, 22, 29, 22, 6]
# [19, 5, 22, 12, 20, 6]
# [77, 116, 1, 3, 9, 1, 10, 30, 48, 22, 29, 22, 6, 89, 146, 1, 1, 8, 1, 14, 19, 24, 22, 34, 20, 6]
# [[ 77  89]
#  [116 146]
#  [  1   1]
#  [  3   1]
#  [  9   8]
#  [  1   1]
#  [ 10  14]
#  [ 30  19]
#  [ 48  24]
#  [ 22  22]
#  [ 29  34]
#  [ 22  20]
#  [  6   6]]
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:131: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:133: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
print(result)
print(n_headers)
pd.DataFrame(result.reshape(1,result.shape[0]),columns=n_headers)
# Out:
# [datetime.datetime(2016, 4, 2, 0, 0) 'Liverpool' 'Tottenham Hotspur' '42.2'
#  '57.8' '77' '89' '116' '146' '1' '1' '3' '1' '9' '8' '1' '1' '10' '14'
#  '30' '19' '48' '24' '22' '22' '29' '34' '22' '20' '6' '6']
# ['Date' 'HomeTeam' 'AwayTeam' 'H_poss' 'A_poss' 'H_atk_3rd' 'A_atk_3rd'
#  'H_atk_3rd_tot' 'A_atk_3rd_tot' 'H_red_goal' 'A_red_goal' 'H_red_on'
#  'A_red_on' 'H_red_tot' 'A_red_tot' 'H_chance_goal' 'A_chance_goal'
#  'H_chance_tot' 'A_chance_tot' 'H_successful_tackle' 'A_successful_tackle'
#  'H_tackle_tot' 'A_tackle_tot' 'H_successful_clearance'
#  'A_successful_clearance' 'H_clearance_tot' 'A_clearance_tot'
#  'H_interceptions' 'A_interceptions' 'H_blocks' 'A_blocks']
#                   Date   HomeTeam           AwayTeam H_poss A_poss H_atk_3rd  \
# 0  2016-04-02 00:00:00  Liverpool  Tottenham Hotspur   42.2   57.8        77
#
#   A_atk_3rd H_atk_3rd_tot A_atk_3rd_tot H_red_goal   ...    H_tackle_tot  \
# 0        89           116           146          1   ...              48
#
#   A_tackle_tot H_successful_clearance A_successful_clearance H_clearance_tot  \
# 0           24                     22                     22              29
#
#   A_clearance_tot H_interceptions A_interceptions H_blocks A_blocks
# 0              34              22              20        6        6
#
# [1 rows x 31 columns]

# %%
soup= getContentSoup('http://www.fourfourtwo.com/statszone/8-2015/matches/803479/team-stats/6/OVERALL_04')
def_headers = ['successful_tackle','failed_tackle','successful_clearance','failed_clearance','interceptions','blocks']
def_values = [0 for i in range(len(def_headers))]
for e in soup.select("image.pitch-object"):
    href =e.get("xlink:href")
    print(href)
    for indx, header  in enumerate(def_headers):
        if header in href:
            def_values[indx]+=1
            break

#def_values[1]+=def_values[0]
#def_values[3] += def_values[2]
# Out:
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_tackle.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/interceptions.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/blocks.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/successful_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/failed_clearance.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png
# /sites/fourfourtwo.com/modules/custom/statzone/files/icons/commited.png

# %%
def_values
# Out:
# [19, 5, 22, 12, 20, 6]

# %%
soup= getContentSoup('http://www.fourfourtwo.com/statszone/8-2015/matches/803479/team-stats/14/1_PASS_11')
matchs = ['stroke:yellow;stroke-width:3','stroke:deepskyblue;stroke-width:3']
values = [0,0,0]
for e in soup.select("line.pitch-object") :
    style =  e.get('style')
    print(style)
    values[2]+=1
    for indx, m in enumerate(matchs):
        if style == m:
            values[indx] +=1
            break
# Out:
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:yellow;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3
# stroke:deepskyblue;stroke-width:3

# %%
values
# Out:
# [1, 9, 10]

# %%
import os, http.cookiejar, urllib.request
from cookielib import Cookie, CookieJar

def getReferee():
    cj = CookieJar()
    # Cookie(version, name, value, port, port_specified, domain, 
    # domain_specified, domain_initial_dot, path, path_specified, 
    # secure, discard, comment, comment_url, rest)
    c = Cookie(None, 'asdf', None, '80', '80', 'www.foo.bar', 
           None, None, '/', None, False, False, 'TestCookie', None, None, None)
    cj.set_cookie(c)
    print (cj)
    url = 'http://www.premierleague.com/content/premierleague/en-gb/referees/appointments.html?paramSearchContext=MATCH_WEEK&paramMatchWeek=31'
    return
    req = urllib.request.Request(url)
    req.add_header('Accept-Language','en-US;q=0.6,en;q=0.4')
    content = urllib.request.urlopen(req).read().decode('utf-8')
    print(content)
    #soup= getContentSoup(url)
    #print(soup.prettify())
    dfs = pd.read_html(url)
    dfs[0]["Date"] =datetime.date(2016,4,2)
    dfs[1]["Date"] = datetime.date(2016,4,3)
    print(dfs)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-47-6ceafba8798f> in <module>()
#       1 import os, http.cookiejar, urllib.request
# ----> 2 from cookielib import Cookie, CookieJar
#       3
#       4 def getReferee():
#       5     cj = CookieJar()
#
# ImportError: No module named 'cookielib'

# %%
getReferee()
# Out:
# <!--[if lt IE 7]>      <html lang="zh" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="zh" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="zh" class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]>         <html lang="zh" class="no-js lt-ie10"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="zh"> <!--<![endif]-->
#
#
#
#
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">
#     <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black-translucent">
#     <meta name="HandheldFriendly" content="true">
#     <meta name="MobileOptimized" content="320">
#     <meta name="description" content="">
#     <meta name="author" content="">
#
#
#
#
#
#
#
#
#     <meta property="wb:webmaster" content="873af3d8c5231f13" />
#
#
#
#
#     <title>Premier League | 主頁</title>
#
#
#
#     <link rel="stylesheet" href="/etc/designs/international/exlibs.css" type="text/css">
#
#     <link rel="stylesheet" href="/etc/designs/international/clientlibs.css" type="text/css">
#
#
#    <!--[if lte IE 8]> <link rel="stylesheet" href="/etc/designs/international/IE8libs.css" type="text/css">
#   <![endif]-->
#    <!--[if lte IE 8]> <script type="text/javascript" src="/etc/designs/international/IE8libs.js"></script>
#   <![endif]-->
#
#
#     <script type="text/javascript" src="/etc/designs/international/exlibs.js"></script>
#
#     <script type="text/javascript" src="/etc/designs/international/clientlibs.js"></script>
#
#
#    <!-- Lotame Header Tag -->
#
#    <script type="text/javascript">
#    var cc_client_id=3150;
#    document.write('<scr'+'ipt type="text/javascript" src="http://ad.crwdcntrl.net/5/c='+cc_client_id.toString()+'/pe=y/callback=processauds"></scr'+'ipt>');
#    var adtechCCvals = "";
#    function processauds(adtechccauds) {
#    if (typeof(adtechccauds) != 'undefined'){
#    for (var cci = 0; cci < adtechccauds.Profile.Audiences.Audience.length;cci++){
#    if (cci > 0) adtechCCvals += ":";
#    adtechCCvals +=adtechccauds.Profile.Audiences.Audience[cci].abbr;
#    }
#    }
#    }
#    </script>
#
#
#
#     <script language="javascript">&lt;!--document.write('&lt;scr'+'ipt language="javascript1.1" src="http://adserver.adtech.de/addyn/3.0/327.0/3052915/0/0/ADTECH;loc=100;target=_blank;sub1=[subst];key=key1+key2+key3+key4;grp=[group];KVabbr='+window.adtechCCvals+';misc='+new Date().getTime()+';rdclick="&gt;&lt;/scri'+'pt&gt;');//--&gt;
#     </script>
#
#     <script src="http://tags.crwdcntrl.net/c/3688/cc.js?ns=_cc3688" id="LOTCC_3688"></script>
#
#     <script type="text/javascript" src="/etc/designs/international/clientlibs/js/lotame.js"></script>
#
#     <!-- end of Lotame Header Tag -->
# </head>
#
#
# <body>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="header" widget="pinning">
#     <div id="masthead">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="cookie-prompt"
# 	data-widget = "languagecookie"
# 	data-pageLocale = "zh_HK"
# 	data-translation = "{&#034;en_GB&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;English&#034;,
# 			&#034;in_ID&#034;:&#034;Indonesian&#034;,
# 			&#034;es_ES&#034;:&#034;Spanish&#034;,
# 			&#034;zh_CN&#034;:&#034;Simplified Chinese&#034;,
# 			&#034;zh_HK&#034;:&#034;Traditional Chinese&#034;,
# 			&#034;th_TH&#034;:&#034;Thai&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;You are currently visiting the English language version of premierleague.com&#034;,
# 			&#034;prompt&#034;:&#034;Would you like to make this your default Barclays Premier league site?&#034;,
# 			&#034;btnYes&#034;:&#034;yes&#034;,
# 			&#034;btnNo&#034;:&#034;no&#034;,
# 			&#034;currentState&#034;:&#034;Your current default language is&#034;,
# 			&#034;english&#034;:&#034;English&#034;
# 		}
# 	},&#034;in_ID&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;Bahasa Inggris&#034;,
# 			&#034;in_ID&#034;:&#034;Bahasa Indonesia&#034;,
# 			&#034;es_ES&#034;:&#034;Bahasa Spanyol&#034;,
# 			&#034;zh_CN&#034;:&#034;Huruf Tionghoa Disederhanakan&#034;,
# 			&#034;zh_HK&#034;:&#034;Bahasa Tionghoa Tradisional&#034;,
# 			&#034;th_TH&#034;:&#034;Bahasa Thailand&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;Halaman Barclays Premier league?&#034;,
# 			&#034;prompt&#034;:&#034;Halaman Barclays Premier league?&#034;,
# 			&#034;btnYes&#034;:&#034;ya&#034;,
# 			&#034;btnNo&#034;:&#034;Tidak&#034;,
# 			&#034;currentState&#034;:&#034;Bahasa yang anda gunakan saat ini adalah&#034;,
# 			&#034;english&#034;:&#034;Bahasa Inggris&#034;
# 		}
# 	},&#034;es_ES&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;Inglés&#034;,
# 			&#034;in_ID&#034;:&#034;Indonesio&#034;,
# 			&#034;es_ES&#034;:&#034;Español&#034;,
# 			&#034;zh_CN&#034;:&#034;Chino simplificado&#034;,
# 			&#034;zh_HK&#034;:&#034;Chino tradicional&#034;,
# 			&#034;th_TH&#034;:&#034;Tailandés&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;Está visitando en estos momentos la versión inglesa de premierleague.com&#034;,
# 			&#034;prompt&#034;:&#034;¿Quiere establecerla como la página por defecto de la Barclays Premier league?&#034;,
# 			&#034;btnYes&#034;:&#034;sí&#034;,
# 			&#034;btnNo&#034;:&#034;no&#034;,
# 			&#034;currentState&#034;:&#034;Tu idioma actual por defecto es&#034;,
# 			&#034;english&#034;:&#034;inglesa&#034;
# 		}
# 	},&#034;zh_CN&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;英语&#034;,
# 			&#034;in_ID&#034;:&#034;印度尼西亚语&#034;,
# 			&#034;es_ES&#034;:&#034;西班牙语&#034;,
# 			&#034;zh_CN&#034;:&#034;简体汉语&#034;,
# 			&#034;zh_HK&#034;:&#034;繁体汉语&#034;,
# 			&#034;th_TH&#034;:&#034;泰语&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;您正在浏览premierleague.com&#034;,
# 			&#034;prompt&#034;:&#034;英语界面，您是否将此界面设置为默认?&#034;,
# 			&#034;btnYes&#034;:&#034;是&#034;,
# 			&#034;btnNo&#034;:&#034;否&#034;,
# 			&#034;currentState&#034;:&#034;目前您的默认语言为&#034;,
# 			&#034;english&#034;:&#034;英语&#034;
# 		}
# 	},&#034;zh_HK&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;英文&#034;,
# 			&#034;in_ID&#034;:&#034;印尼文&#034;,
# 			&#034;es_ES&#034;:&#034;西班牙文&#034;,
# 			&#034;zh_CN&#034;:&#034;簡體中文&#034;,
# 			&#034;zh_HK&#034;:&#034;繁體中文&#034;,
# 			&#034;th_TH&#034;:&#034;泰文&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;你現正訪問英文版的 premierleague.com&#034;,
# 			&#034;prompt&#034;:&#034;請問你想將它設為預設英超網站嗎?&#034;,
# 			&#034;btnYes&#034;:&#034;是&#034;,
# 			&#034;btnNo&#034;:&#034;不是&#034;,
# 			&#034;currentState&#034;:&#034;現時預設的語言為&#034;,
# 			&#034;english&#034;:&#034;英文&#034;
# 		}
# 	},&#034;th_TH&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;อังกฤษ&#034;,
# 			&#034;in_ID&#034;:&#034;อินโดนีเซีย&#034;,
# 			&#034;es_ES&#034;:&#034;สเปน&#034;,
# 			&#034;zh_CN&#034;:&#034;จีนกลาง&#034;,
# 			&#034;zh_HK&#034;:&#034;จีนดั้งเดิม&#034;,
# 			&#034;th_TH&#034;:&#034;ไทย&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;ขณะนี้คุณกำลังเยี่ยมชม premierleague.com&#034;,
# 			&#034;prompt&#034;:&#034;เป็นภาษาอังกฤษ คุณต้องการให้มันเป็นภาษาเริ่มต้นสำหรับการใช้งานเว็บไซต์ Barclays Premier league หรือไม่?&#034;,
# 			&#034;btnYes&#034;:&#034;ใช่&#034;,
# 			&#034;btnNo&#034;:&#034;ไม่&#034;,
# 			&#034;currentState&#034;:&#034;ภาษาเริ่มต้นของคุณในปัจจุบันคือ&#034;,
# 			&#034;english&#034;:&#034;อังกฤษ&#034;
# 		}
# 	},&#034;pt_BR&#034;: {
# 		&#034;language&#034;: {
# 			&#034;en_GB&#034;:&#034;Inglês&#034;,
# 			&#034;in_ID&#034;:&#034;Indonésio&#034;,
# 			&#034;es_ES&#034;:&#034;Espanhol&#034;,
# 			&#034;zh_CN&#034;:&#034;Chinês Simplificado&#034;,
# 			&#034;zh_HK&#034;:&#034;Chinês Tradicional&#034;,
# 			&#034;th_TH&#034;:&#034;Tailandês&#034;,
# 			&#034;pt_BR&#034;:&#034;Portuguese&#034;
# 		},
# 		&#034;sentences&#034;: {
# 			&#034;heading&#034;:&#034;Você está visitando a versão em inglês da premierleague.com.&#034;,
# 			&#034;prompt&#034;:&#034;Você gostaria de fazer do site da Barclays Premier League sua página inicial?&#034;,
# 			&#034;btnYes&#034;:&#034;sim&#034;,
# 			&#034;btnNo&#034;:&#034;não&#034;,
# 			&#034;currentState&#034;:&#034;Seu idioma padrão atual é&#034;,
# 			&#034;english&#034;:&#034;inglês&#034;
# 		}
# 	}}" >
#
# 	<div class="container">
# 		<h3 class="heading"></h3>
# 		<p class="prompt"></p>
#
# 		<button class="btn yes"></button>
# 		<button class="btn no"></button>
# 		<p class="currentState"></p>
#
# 	</div>
# </div>
#
#         <div class="banner">
#             <div class="banner-inner">
#               <div class="parsys iparsys bannersys"><div class="section"><div class="parbase bannerad">
#
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript">
#         /*
#          *  Perform JS required for responsive leaderboard ads.
#          */
#         $PL.perform = $PL.perform || {};
#         $PL.perform.getViewPort = function() {
#             var screenWidth,
#                 screenHeight;
#             if ( typeof window.innerWidth == 'number' ) {
#                 screenWidth = window.innerWidth;
#                 screenHeight = window.innerHeight;
#             } else if ( document.documentElement && ( document.documentElement.clientWidth || document.documentElement.clientHeight ) ) {
#                 screenWidth = document.documentElement.clientWidth;
#                 screenHeight = document.documentElement.clientHeight;
#             } else if( document.body && ( document.body.clientWidth || document.body.clientHeight ) ) {
#                 screenWidth = document.body.clientWidth;
#                 screenHeight = document.body.clientHeight;
#             }
#             return { width: screenWidth, height: screenHeight };
#         }
#
#         $PL.perform.getTagInfo = function() {
#             window.groupId = window.groupId == undefined ? Math.round( Math.random() * 1000 ) : window.groupId;
#             var viewPort = $PL.perform.getViewPort();
#             var alias = viewPort.width <= 568 ? 'mobile' : 'display' ;
#             var domain = alias == 'mobile' ? 'a' : ( alias == 'tablet' ? 'a' : 'adserver' );
#             return { domain: domain, alias: alias, groupId: groupId, viewPort: viewPort };
#         }
#
#         $PL.perform.localeAlias = function() {
#           var aliasJson = {
#             'en_GB': 'premierleagueindonesiaroslb_display',
#             'in_ID': 'premierleagueindonesiaroslb_display',
#             'pt_BR': 'premierleaguebrazilroslb_display',
#             'zh_HK': 'premierleaguechinesetraditionalroslb_display',
#             'zh_CN': 'premierleaguechinesesimplifiedroslb_display',
#             'th_TH': 'premierleaguethailandroslb_display',
#             'es_ES': 'premierleaguespainroslb_display',
#           }
#           return aliasJson['zh_HK'];
#         }
#     </script>
#
#     <script type="text/javascript">
#         ( function() {
#             var info = $PL.perform.getTagInfo();
#             var alias = $PL.perform.localeAlias();
#                 alias = alias !== '' ? 'alias=' + ( alias.split("_") ? alias.split("_")[ 0 ] : alias ) + '_' + info.alias : '';
#             document.write('<scr'+'ipt language="javascript1.1" src="http://' + info.domain + '.adtech.de/addyn/3.0/327.0/5192435/0/-1/ADTECH;' + alias + ';loc=100;kvlayout=insertlayoutidentifier;target=_blank;grp=' + info.groupId + ';misc=' + new Date().getTime() + '"></scri'+'pt>');
#         })();
#     </script>
#
#
#
#
# <noscript>
#     <img src="http://adserver.adtech.de/adserv|3.0|327|4806545|0|225|ADTECH;cookie=info;loc=300" border="0" width="728" height="90"/>
# </noscript>
#       </div>
# </div><div class="section"><div class="new"></div>
# </div><div class="iparys_inherited"><div class="parsys iparsys bannersys"></div>
# </div>
# </div>
#
#             </div>
#         </div>
#
#         <div class="sitehead">
#
#             <div class="utils">
#                 <div class="logo">
#                     <a href="/zh-hk.html" title="首頁">
#                     <span>Barclays Premier League</span>
#                     </a>
#                 </div>
#
#                 <div class="links clearfix siteutils">
#                     <div class="clublogos">
#
#
#
#     <ul>
#
#             <li class="logo0">
#                 <a title="AFC Bournemouth" target="_blank" href="http://www.afcb.co.uk/">
#                     <span>AFC Bournemouth</span>
#                 </a>
#             </li>
#
#             <li class="logo1">
#                 <a title="Arsenal" target="_blank" href="http://www.arsenal.com/home">
#                     <span>Arsenal</span>
#                 </a>
#             </li>
#
#             <li class="logo2">
#                 <a title="Aston Villa" target="_blank" href="http://www.avfc.co.uk/">
#                     <span>Aston Villa</span>
#                 </a>
#             </li>
#
#             <li class="logo3">
#                 <a title="Chelsea" target="_blank" href="http://www.chelseafc.com/?WT.mc_id=premierleague-ctvo">
#                     <span>Chelsea</span>
#                 </a>
#             </li>
#
#             <li class="logo4">
#                 <a title="Crystal Palace" target="_blank" href="http://www.cpfc.co.uk/">
#                     <span>Crystal Palace</span>
#                 </a>
#             </li>
#
#             <li class="logo5">
#                 <a title="Everton" target="_blank" href="http://www.evertonfc.com/">
#                     <span>Everton</span>
#                 </a>
#             </li>
#
#             <li class="logo6">
#                 <a title="Leicester City" target="_blank" href="http://www.lcfc.com/">
#                     <span>Leicester City</span>
#                 </a>
#             </li>
#
#             <li class="logo7">
#                 <a title="Liverpool" target="_blank" href="http://www.liverpoolfc.tv/">
#                     <span>Liverpool</span>
#                 </a>
#             </li>
#
#             <li class="logo8">
#                 <a title="Manchester City" target="_blank" href="http://www.mcfc.co.uk/">
#                     <span>Manchester City</span>
#                 </a>
#             </li>
#
#             <li class="logo9">
#                 <a title="Manchester United" target="_blank" href="http://www.manutd.com/">
#                     <span>Manchester United</span>
#                 </a>
#             </li>
#
#             <li class="logo10">
#                 <a title="Newcastle United" target="_blank" href="http://www.nufc.co.uk/">
#                     <span>Newcastle United</span>
#                 </a>
#             </li>
#
#             <li class="logo11">
#                 <a title="Norwich City" target="_blank" href="http://www.canaries.co.uk/">
#                     <span>Norwich City</span>
#                 </a>
#             </li>
#
#             <li class="logo12">
#                 <a title="Southampton" target="_blank" href="http://www.saintsfc.co.uk/">
#                     <span>Southampton</span>
#                 </a>
#             </li>
#
#             <li class="logo13">
#                 <a title="Stoke City" target="_blank" href="http://www.stokecityfc.com/">
#                     <span>Stoke City</span>
#                 </a>
#             </li>
#
#             <li class="logo14">
#                 <a title="Sunderland" target="_blank" href="http://www.safc.com/">
#                     <span>Sunderland</span>
#                 </a>
#             </li>
#
#             <li class="logo15">
#                 <a title="Swansea City" target="_blank" href="http://www.swanseacity.net/">
#                     <span>Swansea City</span>
#                 </a>
#             </li>
#
#             <li class="logo16">
#                 <a title="Tottenham Hotspur" target="_blank" href="http://www.tottenhamhotspur.com/home/">
#                     <span>Tottenham Hotspur</span>
#                 </a>
#             </li>
#
#             <li class="logo17">
#                 <a title="Watford" target="_blank" href="http://www.watfordfc.com/">
#                     <span>Watford</span>
#                 </a>
#             </li>
#
#             <li class="logo18">
#                 <a title="West Bromwich Albion" target="_blank" href="http://www.wba.co.uk/">
#                     <span>West Bromwich Albion</span>
#                 </a>
#             </li>
#
#             <li class="logo19">
#                 <a title="West Ham United" target="_blank" href="http://www.whufc.com/">
#                     <span>West Ham United</span>
#                 </a>
#             </li>
#
#
#     </ul>
#
#
#
#                     </div>
#                     <div class="siteutilshead">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <ul class="primary" data-widget="languagecontrol" data-currentLocale="zh_HK">
#     <h2 class="zh_HK"><span></span></h2>
#
#   	<li class="login">
#         <a class="my-login" href="http://users.premierleague.com">登入/註冊</a>
#         <a class="my-account" href="http://users.premierleague.com">我的帳戶</a>
#     </li>
#     <li class="languages">
#
#
#
#
#
#
#
# <form action="#">
#     <p>
#         <select class="dropdown">
#
#
#
#
#
#
#
#
#
#
#
#
#                     <option value="zh_HK">繁體中文</option>
#
#
#
#
#
#
#
#                     <option value="en_GB">English</option>
#
#
#
#                     <option value="pt_BR">Português</option>
#
#
#
#                     <option value="in_ID">Indonesia</option>
#
#
#
#                     <option value="es_ES">Español</option>
#
#
#
#                     <option value="th_TH">ภาษาไทย</option>
#
#
#
#
#
#                     <option value="zh_CN">简体中文</option>
#
#
#         </select>
#     </p>
# </form>
#
#
#     </li>
#   	<li class="fpl"><a href="http://hk.fantasy.premierleague.com">Fantasy Premier League</a></li>
# </ul>
#
#
#                     </div>
#                 </div>
#
#                 <h2 class="barclayslogolong">Barclays Premier League</h2>
#
#                 <div class="mobile-nav">
#                   <ul>
#                     <li><a href="/zh-hk/matchday/matches.html" class="">賽程</a></li>
#                     <li><a href="/zh-hk/matchday/results.html" class="">分數</a></li>
#                     <li><a href="/zh-hk/matchday/league-table.html" class="">積分榜</a></li>
#                   </ul>
#                 </div>
#
#             </div>
#         </div>
#     </div><!--/#masthead -->
#
#     <nav class="navbar navbar-default" role="navigation">
#         <div class="container-fluid">
#             <div class="navbar-header">
#                 <button type="button" class="navbar-toggle" data-toggle="collapse" data-target="#navbar">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 </button>
#             </div>
#         </div>
#     </nav>
#
#     <div id="nav-container" data-widget="languagecontrol" data-currentLocale="zh_HK">
#         <div class="collapse navbar-collapse" id="navbar">
#             <ul class="nav navbar-nav">
#                 <div class="left-col">
#                     <li ><a href="/zh-hk.html" class="highlight">首頁</a></li>
#                     <li ><a href="/zh-hk/news.html" class="">新聞</a></li>
#                     <li class="hidden-mobile"><a href="/zh-hk/matchday/matches.html" class="">賽程</a></li>
#                     <li class="hidden-mobile"><a href="/zh-hk/matchday/results.html" class="">分數</a></li>
#                     <li class="hidden-mobile"><a href="/zh-hk/matchday/league-table.html" class="">積分榜</a></li>
#                     <li ><a href="/zh-hk/players/index.html" class="">數據</a></li>
#                 </div>
#                 <div class="right-col">
#                     <li><a href="/zh-hk/clubs.html" class="">球會</a></li>
#                     <li><a href="/zh-hk/matchday/broadcast-schedules.html" class="">電視廣播商列表</a></li>
#                     <li><a href="/zh-hk/videos.html" class="">影片</a></li>
#                 </div>
#
#                 <li class="fantasy"><a href="http://hk.fantasy.premierleague.com">Fantasy Premier League<span></span></a> </li>
#
#                 <li class="languages">
#
#
#
#
#
#
#
# <form action="#">
#     <p>
#         <select class="dropdown">
#
#
#
#
#
#
#
#
#
#
#
#
#                     <option value="zh_HK">繁體中文</option>
#
#
#
#
#
#
#
#                     <option value="en_GB">English</option>
#
#
#
#                     <option value="pt_BR">Português</option>
#
#
#
#                     <option value="in_ID">Indonesia</option>
#
#
#
#                     <option value="es_ES">Español</option>
#
#
#
#                     <option value="th_TH">ภาษาไทย</option>
#
#
#
#
#
#                     <option value="zh_CN">简体中文</option>
#
#
#         </select>
#     </p>
# </form>
#
#
#                 </li>
#             </ul>
#         </div>
#     </div>
#
# </div>
#
#
#
# <!--div class="col-sm-12"-->
# <div id="news" class="wrapper">
#     <div class="container clearfix">
#         <div class="parsys news"><div class="latestnewfeatures section">
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div class="headerList clearfix" data-widget="newsheader">
#
#
#
#
#
#
#                 <div class="news-item-level-1 news-item">
#                     <a href="/zh-hk/news/news/2015-16/april/010416-colin-trainor-on-arsenal-expected-goals.html">
#                         <div class="news-caption">
#                             <div class="news-title">
#                                 <h3>後勁不繼阻礙阿仙奴的奪冠之路</h3>
#                             </div>
#                             <div class="news-desc news-desc-hidden">
#                                 <p>分析顧問哥連崔諾認為基奧特獲得了足夠的供給，但其他人在門前表現不佳 </p>
#                             </div>
#                         </div>
#
#
#                         <img src="/content/dam/premierleague/site-content/News/2015-16/February/790-ars-che-1516-sanchez-miss-200216.jpg/_jcr_content/renditions/original" alt="分析顧問哥連崔諾認為基奧特獲得了足夠的供給，但其他人在門前表現不佳"/>
#
#                     </a>
#                 </div>
#
#
#                 <div class="news-item-level-2 news-item">
#                     <a href="/zh-hk/news/news/2015-16/april/010416-fpl-scout-differential-norwich-city-timm-klose.html">
#                         <div class="news-caption">
#                             <div class="news-title">
#                                 <h3>FPL球探號外：經理們應考慮添姆高路斯</h3>
#                             </div>
#                             <div class="news-desc news-desc-hidden">
#                                 <p>這名諾域治後衛最近的狀態處於聯賽頂尖，而且他的數據在FPL當中亦具有一定潛力 </p>
#                             </div>
#                         </div>
#
#
#                         <img src="/content/dam/premierleague/site-content/News/2015-16/March/790-fpl-scout-nor-mci-1516-timm-klose-header-kelechi-iheanacho.jpg/_jcr_content/renditions/original" alt="這名諾域治後衛最近的狀態處於聯賽頂尖，而且他的數據在FPL當中亦具有一定潛力"/>
#
#                     </a>
#                 </div>
#
#
#                 <div class="news-item-level-3 news-item">
#                     <a href="/zh-hk/news/news/2015-16/mar/300316-david-sumpter-analysis-on-liverpool-vs-spurs.html">
#                         <div class="news-caption">
#                             <div class="news-title">
#                                 <h3>熱刺出色的把握力有助於他們面對晏菲路一役</h3>
#                             </div>
#                             <div class="news-desc news-desc-hidden">
#                                 <p>大衛森普特為我們分析星期日 </p>
#                             </div>
#                         </div>
#
#
#                         <img src="/content/dam/premierleague/site-content/News/2015-16/February/790-mci-tot-1516-christian-eriksen-goal.jpg/_jcr_content/renditions/original" alt="大衛森普特為我們分析星期日"/>
#
#                     </a>
#                 </div>
#
#
#
#
# <a class="btn btn-link" href="/zh-hk/news.html">更多新聞<span class="arrow"></span></a>
# </div></div>
# </div>
#
#     </div>
# </div>
#
# <div id="body" class="wrapper homepage">
#     <div class="container clearfix">
#         <div class="page-row main">
# <div class="parsys row"><div class="latestnewfeatures section">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <div class="col-sm-7 secondary-list clearfix">
#
#
#
#
#
#
#                 <div class="news-list-item clearfix">
#                     <a href="/zh-hk/news/news/2015-16/mar/300316-matchweek32-man-utd-vs-everton-fixture-focus1300316-matchweek32-man-utd-vs-everton-fixture-focus.html">
#
#
#                             <img src="/content/dam/premierleague/site-content/News/2015-16/August/790-eve-mun-1516-schneiderlin-goal.jpg/_jcr_content/renditions/cq5dam.web.200.200.jpeg" class="thumb" alt="雖然曼聯之前狀態低迷，但這名荷蘭領隊帶領球隊在面對「拖肥糖」前重回正軌"/>
#
#
#                         <div class="caption">
#                             <h3>雲高爾期望能連續三次擊敗愛華頓</h3>
#                             <p>雖然曼聯之前狀態低迷，但這名荷蘭領隊帶領球隊在面對「拖肥糖」前重回正軌 </p>
#                         </div>
#
#                     </a>
#                 </div>
#
#
#
#                 <div class="news-list-item clearfix">
#                     <a href="/zh-hk/news/news/2015-16/mar/290316-fpl-scout-gamechanger-double-gameweek-strategy-chips.html">
#
#
#                             <img src="/content/dam/premierleague/site-content/News/2015-16/December/790-eve-cry-1516-bolasie.jpg/_jcr_content/renditions/cq5dam.web.200.200.jpeg" class="thumb" alt="愛華頓和水晶宮的賽程調整讓玩家考慮使用「重置卡」和「錦囊」"/>
#
#
#                         <div class="caption">
#                             <h3>夢幻聯賽：賽程調整讓「錦囊」更好使</h3>
#                             <p>愛華頓和水晶宮的賽程調整讓玩家考慮使用「重置卡」和「錦囊」 </p>
#                         </div>
#
#                     </a>
#                 </div>
#
#
#
#                 <div class="news-list-item clearfix">
#                     <a href="/zh-hk/news/news/2015-16/mar/290316-matchweek32-aston-villa-vs-chelsea-fixture-focus.html">
#
#
#                             <img src="/content/dam/premierleague/site-content/News/2015-16/March/790-CHE-AVL-fabregas-grealish-290316.jpg/_jcr_content/renditions/cq5dam.web.200.200.jpeg" class="thumb" alt="中場球員狀態回勇 有望幫助「藍軍」擴大客場不敗紀錄"/>
#
#
#                         <div class="caption">
#                             <h3>回勇的費比加斯率領車路士客征維拉</h3>
#                             <p>中場球員狀態回勇 有望幫助「藍軍」擴大客場不敗紀錄 </p>
#                         </div>
#
#                     </a>
#                 </div>
#
#
#
#                 <div class="news-list-item clearfix">
#                     <a href="/zh-hk/news/news/2015-16/mar/290316-championship-top-six-focus-burnley.html">
#
#
#                             <img src="/content/dam/premierleague/site-content/News/2015-16/March/790-championship-focus-290316-andre-gray-joey-barton-burnley.jpg/_jcr_content/renditions/cq5dam.web.200.200.jpeg" class="thumb" alt="這名英冠神射手讓般尼記者聯想到華迪"/>
#
#
#                         <div class="caption">
#                             <h3>安祖格雷有望帶領般尼迅速回歸英超</h3>
#                             <p>這名英冠神射手讓般尼記者聯想到華迪 </p>
#                         </div>
#
#                     </a>
#                 </div>
#
#
#
#
# <a class="btn btn-link" href="/zh-hk/news.html">更多新聞<span class="arrow"></span></a>
# </div></div>
# <div class="side-stats-table section">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div    data-widget     = "sidestats"
#         data-url        = "/pa-services/api/football/lang_en/i18n/leaguetable/dynamic/tableAndStats.json"
#         data-templateId = "#table-template"
#         data-appendToEl = ".stats"
#         data-poll       = "false"
#
#
#
#         >
#
# <div id="tableHead">
#     <div class="page-title page-title-short clearfix">
#         <span class="logo"></span>
#         <span class="btn btn-fake live">直播</span>
#     </div>
# </div>
# <ul class="statsNav">
#   <li class="active"><a href="#table" data-toggle="tab">積分榜</a></li>
#   <li><a href="#top-scorers" data-toggle="tab">神射手</a></li>
#
# </ul>
#
# <div class="stats tab-content">
#
#     <script id="table-template" type="text/x-handlebars-template">
#     <div class="tab-pane active" id="table">
#         <table class="leaguetable">
#         <thead>
#             <tr>
#                 <th colspan="2">排名</th>
#                 <th>球會</th>
#                 <th>場數</th>
#                 <th>分數</th>
#             </tr>
#         </thead>
#         <tbody>
#         {{#each abstractCacheWebRootElement.leagueTable.entries}}
#             <tr>
#                 <td>{{rank}}</td>
#                 <td class="movement"><span class="bullet {{movement}}"></span></td>
#                 <td class="club"><a href="/content/international/zh-hk/clubs/profile.html/{{clubURLName}}">{{displayTeamName}}</a></td>
#                 <td>{{total.played}}</td>
#                 <td>{{total.points}}</td>
#             </tr>
#         {{/each}}
#         </tbody>
#         </table>
#     <div id="tableFooter" class="side-league-table">
#         <a href="/content/international/zh-hk/matchday/league-table.html" class="btn moreStats">完整積分榜 <span class="arrow"></span></a>
#     </div>
#     </div>
#
#     <div class="tab-pane" id="top-scorers">
#         <table class="top-scorers leaguetable">
#         <thead>
#             <tr>
#                 <th>排名</th>
#                 <th>球員</th>
#                 <th>入球</th>
#             </tr>
#         </thead>
#         <tbody>
#         {{#each abstractCacheWebRootElement.totalScorers.stats.0.values}}
#             <tr>
#                 <td class="pos">{{rank}}</td>
#                 <td class="name">{{deviceName displayPlayerMobileName displayPlayerDesktopName}}</td>
#                 <td>{{value}}</td>
#             </tr>
#         {{/each}}
#         </tbody>
#         </table>
#     <div id="tableFooter" class="stats">
#         <a href="/content/international/zh-hk/players/index.html" class="btn moreStats">更多數據 <span class="arrow"></span></a>
#         <img src="/etc/designs/mobile/images/logo_EA_Sports.png"  width="115"/>
#     </div>
#     </div>
#
#     </script>
#
# </div>
# </div>
# </div>
# <div class="parbase bannerad section">
#
#
#
#
#
#
#
#
#
#
#
#     <script type="text/javascript">
#         $.browser.init();
#         if($.browser.isDesktop) {
#           if (window.adgroupid == undefined) {
#               window.adgroupid = Math.round(Math.random() * 1000);
#           }
#           document.write('<scr'+'ipt type="text/javascript" src="http://adserver.adtech.de/addyn|3.0|327|4806546|0|168|ADTECH;cookie=info;loc=100;target=_blank;sub1=[subst];grp='+window.adgroupid+';KVabbr='+window.adtechCCvals+';misc='+new Date().getTime()+'"></scri'+'pt>');
#         }
#     </script>
#
#
#
#
# <noscript>
#     <img src="http://adserver.adtech.de/adserv|3.0|327|4806546|0|168|ADTECH;cookie=info;loc=300" border="0" width="120" height="600"/>
# </noscript>
#       </div>
# <div class="homepageplayer section">
#
#
#
#
#
#
#
#
#
#
#
# <div id="templatetitle" class="page-title clearfix">
# 	<h1><span class="logo"></span>影片</h1>
# </div>
# <div id="mainplayer" data-widget="mainplayer" ajax="/content/premierleague-ajax/videosearch.ajax?paramSearchType={searchType}&amp;paramId={id}&amp;locale={locale}">
#
# 	<script type="text/javascript" src="/etc/designs/premierleague/video.js"></script>
# <script type="text/javascript" src="/etc/designs/brightcove/exlibs.js"></script>
# <script type="text/javascript" src="/etc/designs/brightcove/brightcoveExperiences.js"></script>
#
#
# 	<div id="mainplayer-image" class="mainplayer-image">
#
# 		<div id="main-video-img" class="mainplayer-imagewrapper">
# 			<img alt="" src="http://brightcove.vo.llnwd.net/v1/unsecured/media/2508689025001/201604/2822/2508689025001_4826379561001_video-still-for-video-4826374745001.jpg?pubId=2508689025001">
# 		</div>
# 		<div class="mainplayer-details">
# 			<h4 class="video-name">Happy birthday Teddy Sheringham!</h4>
# 			<p class="video-desc">To mark Sheringham's 50th birthday on Saturday, we celebrate with BPL goals of his at Nott'm Forest, Spurs, Man Utd, Portsmouth and West Ham</p>
# 			<p class="video-date">Saturday 2 April 2016</p>
# 			<a class="mainplayer-play btn" title="Happy birthday Teddy Sheringham!" onclick="playVideo(4826374745001);return false;">
# 			    播放影片
# 			</a>
# 		</div>
#     </div>
#
# 	<div id="b743debb8ef847c6be17c7caadcd6a97" class="mainplayer-video">
# 		<script type="text/javascript">
# 			BCLSettings.playerId = '2522850455001';
# 			BCLSettings.playerKey = 'AQ~~,AAACSBmEp-k~,k6M0BLQIXJ_fOxXUjJd4CUhd7yHzmz9-';
# 			BCLSettings.mobilePlayerId = '3357974728001';
# 			BCLSettings.mobilePlayerKey = 'AQ~~,AAACSBmEp-k~,k6M0BLQIXJ_hpbKW5kLOsGpPqElgbyH_';
# 			BCLSettings.width = 564;
# 			BCLSettings.height = 432;
# 			BCLSettings.videoRandomId = 'b743debb8ef847c6be17c7caadcd6a97';
# 	    </script>
#     </div>
#
#     <div class="mainplayer-playlist">
#     	<div class="horizontal-videos ">
#
#
# 			        <li>
# 				        <a title="FPL Gameweek 32: FIFA 16 Transfer tips" onclick="showVideoOverlay(4826236838001,'zh_HK');return false;">
# 				            <div class="video-image-container">
# 				            	<img alt="" src="http://brightcove.vo.llnwd.net/v1/unsecured/media/2508689025001/201604/158/2508689025001_4826164880001_video-still-for-video-4826236838001.jpg?pubId=2508689025001">
# 				            	<div class="play-box"><span class="play-arrow"></span></div>
# 				            </div>
# 				            <div class="video-details">
# 				            	<h4 class="video-name">FPL Gameweek 32: FIFA 16 Transfer tips</h4>
# 				            </div>
# 				        </a>
# 			        </li>
#
#
#
# 			        <li>
# 				        <a title="Key battle: Antonio v Bolasie" onclick="showVideoOverlay(4824722336001,'zh_HK');return false;">
# 				            <div class="video-image-container">
# 				            	<img alt="" src="http://brightcove.vo.llnwd.net/v1/unsecured/media/2508689025001/201603/854/2508689025001_4824728915001_video-still-for-video-4824722336001.jpg?pubId=2508689025001">
# 				            	<div class="play-box"><span class="play-arrow"></span></div>
# 				            </div>
# 				            <div class="video-details">
# 				            	<h4 class="video-name">Key battle: Antonio v Bolasie</h4>
# 				            </div>
# 				        </a>
# 			        </li>
#
#
#
# 			        <li>
# 				        <a title="Fixture Flashback: Matchweek 32" onclick="showVideoOverlay(4824565522001,'zh_HK');return false;">
# 				            <div class="video-image-container">
# 				            	<img alt="" src="http://brightcove.vo.llnwd.net/v1/unsecured/media/2508689025001/201603/3466/2508689025001_4824662303001_video-still-for-video-4824565522001.jpg?pubId=2508689025001">
# 				            	<div class="play-box"><span class="play-arrow"></span></div>
# 				            </div>
# 				            <div class="video-details">
# 				            	<h4 class="video-name">Fixture Flashback: Matchweek 32</h4>
# 				            </div>
# 				        </a>
# 			        </li>
#
#
#
# 			        <li>
# 				        <a title="On this day in 1996: Liverpool 4-3 Newcastle" onclick="showVideoOverlay(4826532164001,'zh_HK');return false;">
# 				            <div class="video-image-container">
# 				            	<img alt="" src="http://brightcove.vo.llnwd.net/v1/unsecured/media/2508689025001/201604/3410/2508689025001_4826379598001_video-still-for-video-4826532164001.jpg?pubId=2508689025001">
# 				            	<div class="play-box"><span class="play-arrow"></span></div>
# 				            </div>
# 				            <div class="video-details">
# 				            	<h4 class="video-name">On this day in 1996: Liverpool 4-3 Newcastle</h4>
# 				            </div>
# 				        </a>
# 			        </li>
#
#
# 		</div>
# 	</div>
# </div>
# <div class="more-less-news">
# 	<button class="arrow-link btn" onclick="document.location.href='/content/international/zh-hk/videos.html';return false;">
# 		更多影片
# 		<span class="arrow"></span>
# 	</button>
# </div></div>
# </div>
#  </div>
#
#     </div>
# </div>
#
# <div id="social" class="wrapper">
#     <div class="container clearfix">
#         <div class="parsys social"><div class="socialnetwork section">
#
#
#
#
#
#
#
#
#
# <div class="page-title page-title-short clearfix">
# 	<span class="logo"></span><h1>社交</h1>
# </div>
#
#
#     <div data-widget="socialfeed" data-locale="zh_HK">
#
#
#         <div class="facebook-feed">
#             <div id="fb-container">
#                 <fb:like-box href="http://facebook.com/premierleague"  show_faces="false" border_color="#999999" stream="true" header="false">
#                 </fb:like-box>
#             </div>
#
#             <div id="fb-root"></div>
#         </div>
#
#
#         <script type="text/javascript" src="http://w.sharethis.com/button/buttons.js"></script>
#         <script type="text/javascript"> stLight.options({ publisher:'c42f5e69-5de0-4112-8137-445557383944', doNotHash: true, doNotCopy: true, hashAddressBar: false });</script>
#         <script>(function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/en_GB/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));</script>
#         <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");</script>
#
#         <ul class="social-links">
#         <li class="fb clearfix">
#             <div class="logo"></div>
#                 <span>
#                     <a class="facebook-url" href="http://facebook.com/premierleague" target="_blank">
#                       facebook.com/premierleague
#                     </a>
#                 </span>
#             <div class="fb-like-container">
#                 <div class="fb-like" data-href="http://facebook.com/premierleague" data-width="100" data-layout="button_count" data-show-faces="false" data-send="false" target="_blank"></div>
#             </div>
#         </li>
#         <li class="twitter clearfix">
#             <div class="logo"></div>
#             <span>
#                 <a href="https://twitter.com/premierleague" target="_blank">
#                     @premierleague
#                 </a>
#             </span>
#             <div class="twitter-follow-container">
#                 <a href="https://twitter.com/premierleague" class="twitter-follow-button" data-show-count="false" data-show-screen-name="false" target="_blank"></a>
#                 <div class="twitter_box"><span id="followers">11.2M</span></div>
#             </div>
#         </li>
#
#
#
#             <li class="weibo clearfix">
#                 <div class="logo-weibo"></div>
#                 <span>
#                     <a href="http://www.weibo.com/premierleague" target="_blank">
#                       weibo.com/premierleague
#                     </a>
#                 </span>
#                 <script src="http://tjs.sjs.sinajs.cn/open/api/js/wb.js" type="text/javascript" charset="utf-8"></script>
#                 <wb:follow-button uid="3690518992" type="red_2" width="136" height="24" ></wb:follow-button>
#             </li>
#
#         </ul>
#     </div>
#
#
#
# </div>
# </div>
#
#     </div>
# </div>
#
#
#
#
# <div class="parsys iparsys footer-container"><div class="section"><div class="footer parsys">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="container">
#     <div class="hide-mobile tagline-container">
#         <div class="tagline">
#
#             <a href="https://www.spiritofthegame.barclays.com" target="_blank">
#               <div class="parbase tagImage image">
#                <img title="Barclays" alt="Barclays" class="cq-dd-image" src="http://www.premierleague.com/content/dam/premierleague/footer/tag-footer-img-2.png" width="130" height="40"/>
#                </div>
#             </a>
#             <h2>
#                 <a href="https://www.spiritofthegame.barclays.com" target="_blank">
#                 Click to win Barclays Premier League Tickets #SpiritOfTheGame
#                 </a>
#             </h2>
#
#
#         </div>
#     </div>
#     <div class="footer-sponsors">
#         <div class="logo1">
#             <div class="logo image1">
#
#
#
#
#
#             <a href="http://www.barclays.com" target="_blank">
#
#             <img src="/content/dam/premierleague/footer/sponsors-barclays-i18n.png" alt="" title=""/>
#         </a></div>
#
#         </div>
#         <ul class="clearfix">
#             <li class="logo2">
#                 <div class="logo image2">
#
#
#
#
#
#             <a href="http://www.easports.com/fifa" target="_blank">
#
#             <img src="/content/dam/premierleague/footer/sponsor_ea_mobile.png" alt="" title=""/>
#         </a></div>
#
#             </li>
#             <li class="logo3">
#                 <div class="logo image3">
#
#
#
#
#
#             <a href="http://www.nike.com/?flp=c/football/" target="_blank">
#
#             <img src="/content/dam/premierleague/footer/sponsor_nike.jpg" alt="" title=""/>
#         </a></div>
#
#             </li>
#             <li class="logo4">
#                 <div class="logo image4">
#
#
#
#
#
#             <a href="http://www.facebook.com/CarlsbergUK" target="_blank">
#
#             <img src="/content/dam/premierleague/footer/sponsor_carlsberg.png" alt="" title=""/>
#         </a></div>
#
#             </li>
#             <li class="logo5">
#                 <div class="logo image5">
#
#
#
#
#
#             <a href="http://www.toppsfootball.co.uk" target="_blank">
#
#             <img src="/content/dam/premierleague/footer/sponsor_topps.jpg" alt="" title=""/>
#         </a></div>
#
#             </li>
#         </ul>
#     </div>
#
#     <div class="ad">
#         <div class="banner-ad parbase bannerad">
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
#   if (window.adgroupid == undefined) {
#       window.adgroupid = Math.round(Math.random() * 1000);
#   }
#   document.write('<scr'+'ipt type="text/javascript" src="http://adserver.adtech.de/addyn|3.0|327|4806544|0|170|ADTECH;cookie=info;loc=100;target=_blank;sub1=[subst];grp='+window.adgroupid+';KVabbr='+window.adtechCCvals+';misc='+new Date().getTime()+'"></scri'+'pt>');
# </script>
#
#
#
#
# <noscript>
#     <img src="http://adserver.adtech.de/adserv|3.0|327|4806544|0|170|ADTECH;cookie=info;loc=300" border="0" width="300" height="250"/>
# </noscript>
#       </div>
#
#     </div>
#
#     <ul class="footer-links upper">
#         <li>
#             <a href="/zh-hk/toolbar/about-premier-league.html">關於英超</a> <span class="hide-mobile">|</span>
#         </li>
#         <li>
#             <a href="/zh-hk/toolbar/terms-conditions.html">服務條款</a> <span class="hide-mobile">|</span>
#         </li>
#         <li>
#             <a href="/zh-hk/toolbar/privacy-policy.html">私隱政策</a> <span class="hide-mobile">|</span>
#         </li>
#         <li>
#             <a id="fullLink" href="/zh-hk/toolbar/cookie-policy.html">Cookie 政策</a>
#         </li>
#
#
#
#
#
#             <div class="align-right">
#                 <li class="facebook">
#                     <a href="https://www.facebook.com/premierleague" target="blank">
#
#                         <span class="hide-desktop">Facebook</span>
#                     </a>
#                 </li>
#                 <li class="twitter">
#                     <a href="https://twitter.com/premierleague" target="blank">
#
#                         <span class="hide-desktop">Twitter</span>
#                     </a>
#                 </li>
#
#
#
#                      <li class="weibo">
#                          <a href="http://www.weibo.com/premierleague" target="blank">
#                             <span class="hide-desktop">Weibo</span>
#                          </a>
#                      </li>
#
#             </div>
#
#
#
#
#     </ul>
#
#     <ul class="footer-links lower">
#         <li class="hide-mobile copyright-item">
#             <span class="copyright">&copy; Premier League 2015</span>
#         </li>
#
#         <li class="hide-mobile official align-right">
#             <span class="zh_HK"></span>
#         </li>
#
#         <li class="hide-desktop official">
#             <span class="zh_HK"></span>
#         </li>
#         <li class="hide-desktop"><span class="copyright">&copy; Premier League 2015</span></li>
#     </ul>
# </div>
#
#
#
#
#
#
#
#
#
# <!-- GA Base Tag 20120807 -->
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', "UA-33785302-1"]);
#   _gaq.push(['_setDomainName', 'premierleague.com']);
#   _gaq.push(['_addIgnoredRef', 'premierleague.com']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# <!-- End GA Base Tag -->
#
# <!-- Dynamic Exit, Download, Mailto GA Extension -->
# <script language="javascript" type="text/javascript" src="/etc/designs/premierleague/clientlibs/js/ga_extensions.js"></script>
#
# </div>
# </div><div class="section"><div class="new"></div>
# </div><div class="iparys_inherited"><div class="parsys iparsys footer-container"></div>
# </div>
# </div>
#
#
#
# </body>
#
# </html>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-d91afa0c801b> in <module>()
# ----> 1 getReferee()
#
# <ipython-input-43-be47f59447f1> in getReferee()
#       7     #soup= getContentSoup(url)
#       8     #print(soup.prettify())
# ----> 9     dfs = pd.read_html(url)
#      10     dfs[0]["Date"] =datetime.date(2016,4,2)
#      11     dfs[1]["Date"] = datetime.date(2016,4,3)
#
# /home/y/anaconda3/lib/python3.5/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     864     _validate_header_arg(header)
#     865     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 866                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /home/y/anaconda3/lib/python3.5/site-packages/pandas/io/html.py in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     726             break
#     727     else:
# --> 728         raise_with_traceback(retained)
#     729
#     730     ret = []
#
# /home/y/anaconda3/lib/python3.5/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     746         if traceback == Ellipsis:
#     747             _, _, traceback = sys.exc_info()
# --> 748         raise exc.with_traceback(traceback)
#     749 else:
#     750     # this version of raise is a syntax error in Python 3
#
# ValueError: No tables found

# %%
from IPython.parallel import Client
import time
from IPython.display import clear_output
import sys
def getYearMatch(year):
    
    listurl ='http://www.fourfourtwo.com/statszone/results/8-{}'.format(year)
    baseurl = 'http://www.fourfourtwo.com'
    soup = getContentSoup(listurl)
    tot_links = [e.get('href') for e in  (soup.select("td.link-to-match a"))]
    dates = []
    h_names = []
    a_names =[]
    posses = []
    h_atks = []
    a_atks=[]
    h_ins=[]
    a_ins=[]
    def workerFunc(args):
        import sys
        links =args[0]
        grapMatchInfo = args[1]
        print("start working")
        dates = []
        h_names = []
        a_names =[]
        posses = []
        h_atks = []
        a_atks=[]
        h_ins=[]
        a_ins=[]
        for indx, link in enumerate(links):
            print("task: {}/{}".format(indx,len(links)))
            sys.stdout.flush()
            try:
                date ,homeName, awayName ,poss, h_atkThird, a_atkThird, h_interception,a_interception = grapMatchInfo(baseurl + link)
                print("{} {} {}".format(date,homeName,awayName))
                dates.append(date)
                h_names.append(homeName)
                a_names.append(awayName)
                posses.append(poss)
                h_atks.append(h_atkThird)
                a_atks.append(a_atkThird)
                h_ins.append(h_interception)
                a_ins.append(a_interception)
            except Exception as e:
                print(e)
                print("error")
                break
            
        print("finish")
        return [dates,h_names,a_names,posses,h_atks,a_atks,h_ins,a_ins]
    def finishCallback(returnArgs):
        print("complete")
        dates = []
        h_names = []
        a_names =[]
        posses = []
        h_atks = []
        a_atks=[]
        h_ins=[]
        a_ins=[]
        for args in returnArgs:
            dates=dates+args[0]
            h_names = h_names + args[1]
            a_names = a_names + args[2]
            posses = posses+args[3]
            h_atks=h_atks + args[4]
            a_atks = a_atks + args[5]
            h_ins = h_ins + args[6]
            a_ins = a_ins + args[7]
        return dates,h_names,a_names,posses,h_atks,a_atks,h_ins,a_ins
        
    n_work = 4
    pool = Client()
    print(pool.ids)
    each_n = int(len(tot_links)/n_work)
    works = [tot_links[i*each_n:(i+1)*each_n] for i in range(n_work)]
    works[0].append(tot_links[4*each_n:])
    results = []
    for i in range(n_work):
        results.append(pool[i].apply_async(f=workerFunc,args=[works[i],grapMatchInfo,getContentSoup]))
    def wait_watching_stdout(ars, dt=5, truncate=500):
        while True:
            allReady = True 
            printed = False
            for ar in ars:
                if not ar.ready():
                    allReady = False
                    stdouts = ar.metadata['stdout']
                    if not any(stdouts):
                        continue
                    if printed == False:
                        clear_output()
                        printed = True
                    # clear_output doesn't do much in terminal environments
                    print ('-' * 30)
                    print ("%.3fs elapsed" % ar.elapsed)
                    print ("")
                    print(ar._targets)
                    #print ("[ stdout %2i ]" % (ar._targets))
                    print(ar.metadata['stdout'][-truncate:])
                    sys.stdout.flush()
            if allReady == True:
                return
            time.sleep(dt)      
    wait_watching_stdout(results)
    returnArgs = [ e.get() for e in results]
    pool.close()
    return finishCallback(returnArgs)
# Out:
# /home/y/anaconda3/lib/python3.5/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
from IPython.parallel import Client
import time
from IPython.display import clear_output
import sys
def getYearMatch(year):
    
    listurl ='http://www.fourfourtwo.com/statszone/results/8-{}'.format(year)
    baseurl = 'http://www.fourfourtwo.com'
    soup = getContentSoup(listurl)
    tot_links = [e.get('href') for e in  (soup.select("td.link-to-match a"))]
    results =[]
    n_header=None
    print("start working")
    for indx, link in enumerate(tot_links):
        clear_output()
        print("task: {}/{}".format(indx,len(tot_links)))
        sys.stdout.flush()
        try:
            result,n_headers = grapMatchInfo(baseurl + link)
            print("{} {} {}".format(result[0],result[1],result[2]))
            results.append(result)
            n_header = n_headers
        except Exception as e:
            print(e)
            print("error")
            break
            
        print("finish")
    
 
    return results,n_header

# %%
results,n_header= getYearMatch(2015)
# Out:
# task: 310/311
# [[121  75]
#  [174 110]
#  [  0   2]
#  [  2   4]
#  [  6  12]
#  [  0   0]
#  [  8  12]
#  [ 16  22]
#  [ 29  36]
#  [ 10  23]
#  [ 17  33]
#  [ 13  12]
#  [  5   2]]
# 2015-08-08 00:00:00 Chelsea Swansea City
# finish

# %%
# Out:
# [array([datetime.datetime(2016, 4, 2, 0, 0), 'Aston Villa', 'Chelsea',
#         '41.4', '58.6', '101', '83', '136', '119', '0', '4', '1', '2', '6',
#         '7', '0', '2', '11', '6', '24', '19', '32', '31', '9', '14', '15',
#         '23', '21', '8', '0', '4'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'West Ham United',
#         'Crystal Palace', '66.4', '33.6', '75', '41', '118', '81', '1', '2',
#         '1', '2', '9', '10', '0', '0', '13', '6', '12', '18', '21', '34',
#         '25', '17', '34', '23', '9', '14', '3', '6'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Bournemouth',
#         'Manchester City', '45.8', '54.2', '77', '145', '110', '187', '0',
#         '4', '1', '2', '6', '10', '0', '3', '6', '13', '18', '26', '32',
#         '38', '15', '10', '20', '16', '17', '15', '0', '3'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Norwich City',
#         'Newcastle United', '41.3', '58.7', '81', '93', '132', '131', '3',
#         '2', '2', '2', '8', '10', '3', '1', '12', '12', '11', '11', '16',
#         '17', '20', '22', '31', '33', '5', '12', '1', '2'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Stoke City', 'Swansea City',
#         '47.2', '52.8', '75', '86', '125', '125', '1', '0', '1', '1', '5',
#         '6', '2', '2', '8', '10', '16', '12', '24', '19', '18', '18', '26',
#         '26', '18', '16', '4', '2'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Arsenal', 'Watford', '69.1',
#         '30.9', '238', '56', '284', '99', '4', '0', '5', '2', '14', '4',
#         '2', '0', '14', '5', '15', '19', '17', '27', '21', '20', '30', '27',
#         '25', '19', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Sunderland',
#         'West Bromwich Albion', '56.5', '43.5', '101', '51', '159', '105',
#         '0', '0', '5', '0', '13', '1', '0', '0', '16', '2', '17', '13',
#         '24', '24', '37', '23', '48', '36', '14', '19', '1', '6'], dtype=object),
#  array([datetime.datetime(2016, 4, 2, 0, 0), 'Liverpool',
#         'Tottenham Hotspur', '42.2', '57.8', '77', '89', '116', '146', '1',
#         '1', '3', '1', '9', '8', '1', '1', '10', '14', '30', '19', '48',
#         '24', '22', '22', '29', '34', '22', '20', '6', '6'], dtype=object),
#  array([datetime.datetime(2016, 3, 20, 0, 0), 'Southampton', 'Liverpool',
#         '49.2', '50.8', '114', '111', '163', '164', '2', '1', '1', '5', '9',
#         '10', '3', '2', '13', '12', '18', '11', '32', '20', '23', '21',
#         '33', '26', '22', '12', '4', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 20, 0, 0), 'Newcastle United',
#         'Sunderland', '59.9', '40.1', '74', '72', '116', '124', '1', '1',
#         '3', '2', '9', '7', '1', '0', '12', '10', '24', '25', '35', '40',
#         '25', '23', '31', '38', '9', '6', '3', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 20, 0, 0), 'Tottenham Hotspur',
#         'Bournemouth', '62.8', '37.2', '108', '49', '150', '78', '3', '0',
#         '1', '0', '9', '2', '2', '0', '13', '2', '20', '20', '40', '26',
#         '18', '26', '29', '31', '15', '17', '0', '2'], dtype=object),
#  array([datetime.datetime(2016, 3, 20, 0, 0), 'Manchester City',
#         'Manchester United', '54.5', '45.5', '134', '68', '175', '105', '0',
#         '1', '3', '1', '21', '3', '0', '1', '22', '5', '21', '26', '35',
#         '46', '22', '16', '30', '25', '24', '17', '1', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'Everton', 'Arsenal', '53.9',
#         '46.1', '85', '126', '138', '163', '0', '2', '1', '0', '5', '8',
#         '0', '2', '5', '8', '23', '21', '42', '29', '11', '23', '15', '38',
#         '17', '30', '4', '1'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'Crystal Palace',
#         'Leicester City', '55.9', '44.1', '72', '98', '123', '154', '0',
#         '1', '1', '2', '7', '6', '0', '1', '12', '6', '15', '28', '28',
#         '46', '18', '39', '32', '52', '19', '21', '2', '2'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'West Bromwich Albion',
#         'Norwich City', '50.1', '49.9', '89', '72', '158', '140', '0', '1',
#         '0', '0', '5', '4', '0', '1', '8', '6', '17', '20', '28', '26',
#         '33', '41', '38', '53', '24', '6', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'Watford', 'Stoke City',
#         '52.1', '47.9', '88', '78', '158', '126', '1', '1', '2', '2', '6',
#         '3', '1', '2', '6', '8', '19', '18', '27', '32', '9', '29', '20',
#         '45', '18', '11', '1', '1'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'Chelsea', 'West Ham United',
#         '59.4', '40.6', '103', '58', '150', '98', '1', '1', '2', '2', '16',
#         '9', '0', '1', '14', '9', '18', '20', '23', '35', '13', '23', '19',
#         '30', '15', '18', '5', '6'], dtype=object),
#  array([datetime.datetime(2016, 3, 19, 0, 0), 'Swansea City', 'Aston Villa',
#         '53.8', '46.2', '83', '100', '112', '149', '1', '0', '0', '2', '3',
#         '8', '1', '0', '7', '7', '19', '27', '33', '34', '42', '18', '53',
#         '28', '25', '32', '6', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 14, 0, 0), 'Leicester City',
#         'Newcastle United', '49.9', '50.1', '95', '83', '133', '136', '1',
#         '0', '0', '0', '7', '8', '1', '0', '9', '10', '21', '26', '35',
#         '32', '16', '24', '21', '30', '24', '16', '5', '6'], dtype=object),
#  array([datetime.datetime(2016, 3, 13, 0, 0), 'Aston Villa',
#         'Tottenham Hotspur', '37.8', '62.2', '72', '107', '125', '146', '0',
#         '2', '1', '4', '8', '11', '0', '2', '6', '15', '23', '21', '31',
#         '32', '18', '26', '28', '38', '29', '14', '5', '4'], dtype=object),
#  array([datetime.datetime(2016, 3, 12, 0, 0), 'Norwich City',
#         'Manchester City', '33.9', '66.1', '67', '202', '118', '255', '0',
#         '0', '0', '2', '2', '6', '0', '0', '3', '9', '27', '21', '38', '24',
#         '43', '32', '60', '40', '13', '14', '7', '1'], dtype=object),
#  array([datetime.datetime(2016, 3, 12, 0, 0), 'Stoke City', 'Southampton',
#         '60.6', '39.4', '109', '67', '163', '108', '1', '2', '1', '2', '5',
#         '6', '1', '2', '10', '9', '21', '20', '30', '32', '11', '36', '19',
#         '47', '10', '10', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 12, 0, 0), 'Bournemouth', 'Swansea City',
#         '44.0', '56.0', '68', '84', '111', '129', '3', '2', '0', '2', '8',
#         '8', '2', '1', '9', '8', '19', '29', '31', '38', '23', '20', '27',
#         '26', '25', '20', '1', '2'], dtype=object),
#  array([datetime.datetime(2016, 3, 6, 0, 0), 'Crystal Palace', 'Liverpool',
#         '38.5', '61.5', '75', '143', '129', '180', '1', '2', '3', '2', '9',
#         '9', '0', '0', '7', '13', '13', '23', '21', '32', '14', '23', '19',
#         '36', '20', '12', '8', '4'], dtype=object),
#  array([datetime.datetime(2016, 3, 6, 0, 0), 'West Bromwich Albion',
#         'Manchester United', '46.6', '53.4', '87', '97', '152', '141', '1',
#         '0', '0', '0', '6', '3', '1', '0', '9', '4', '19', '28', '33', '35',
#         '19', '11', '31', '21', '21', '17', '3', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Tottenham Hotspur', 'Arsenal',
#         '51.8', '48.2', '85', '74', '132', '126', '1', '2', '4', '1', '12',
#         '5', '2', '2', '19', '7', '30', '25', '41', '34', '19', '25', '22',
#         '34', '18', '23', '4', '8'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Manchester City',
#         'Aston Villa', '71.2', '28.8', '251', '51', '302', '77', '4', '0',
#         '5', '1', '16', '2', '3', '0', '19', '0', '17', '23', '23', '32',
#         '3', '22', '4', '34', '22', '21', '1', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Newcastle United',
#         'Bournemouth', '49.3', '50.7', '82', '77', '128', '129', '1', '2',
#         '1', '2', '7', '11', '1', '2', '12', '11', '26', '20', '45', '35',
#         '20', '30', '29', '35', '17', '26', '6', '6'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Swansea City', 'Norwich City',
#         '55.8', '44.2', '85', '93', '128', '146', '1', '0', '1', '2', '7',
#         '7', '1', '0', '8', '6', '20', '15', '29', '23', '32', '30', '39',
#         '40', '20', '23', '2', '2'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Chelsea', 'Stoke City',
#         '48.7', '51.3', '115', '93', '155', '139', '0', '1', '5', '2', '11',
#         '12', '1', '0', '16', '13', '18', '21', '36', '32', '13', '15',
#         '20', '22', '17', '18', '4', '4'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Southampton', 'Sunderland',
#         '65.1', '34.9', '120', '51', '170', '105', '1', '1', '4', '1', '10',
#         '7', '1', '1', '11', '6', '10', '12', '19', '22', '33', '29', '45',
#         '43', '14', '14', '4', '7'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Everton', 'West Ham United',
#         '41.5', '58.5', '64', '131', '101', '159', '2', '3', '3', '2', '8',
#         '10', '2', '3', '7', '14', '19', '23', '26', '33', '28', '19', '35',
#         '29', '15', '16', '5', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 5, 0, 0), 'Watford', 'Leicester City',
#         '50.2', '49.8', '65', '85', '108', '136', '0', '1', '3', '3', '6',
#         '10', '0', '0', '8', '10', '27', '26', '39', '39', '21', '23', '25',
#         '28', '23', '20', '1', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 2, 0, 0), 'Arsenal', 'Swansea City',
#         '62.6', '37.4', '170', '66', '220', '96', '1', '1', '2', '0', '12',
#         '3', '1', '1', '14', '9', '28', '19', '37', '32', '9', '27', '18',
#         '37', '17', '9', '4', '6'], dtype=object),
#  array([datetime.datetime(2016, 3, 2, 0, 0), 'West Ham United',
#         'Tottenham Hotspur', '34.9', '65.1', '69', '98', '130', '154', '1',
#         '0', '0', '1', '5', '4', '1', '0', '10', '8', '19', '32', '23',
#         '43', '23', '16', '34', '22', '29', '17', '1', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 2, 0, 0), 'Stoke City',
#         'Newcastle United', '55.3', '44.7', '97', '65', '140', '109', '0',
#         '0', '1', '2', '3', '4', '1', '0', '9', '4', '29', '18', '43', '27',
#         '20', '22', '29', '31', '16', '16', '1', '2'], dtype=object),
#  array([datetime.datetime(2016, 3, 2, 0, 0), 'Liverpool', 'Manchester City',
#         '49.5', '50.5', '122', '101', '179', '152', '2', '0', '1', '0', '4',
#         '2', '3', '0', '9', '4', '34', '27', '53', '40', '20', '26', '24',
#         '29', '22', '19', '1', '1'], dtype=object),
#  array([datetime.datetime(2016, 3, 2, 0, 0), 'Manchester United', 'Watford',
#         '61.2', '38.8', '113', '50', '150', '102', '0', '0', '1', '2', '6',
#         '9', '0', '0', '10', '8', '21', '26', '30', '43', '6', '19', '10',
#         '26', '21', '16', '4', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 1, 0, 0), 'Norwich City', 'Chelsea',
#         '47.0', '53.0', '125', '110', '186', '146', '1', '1', '1', '0', '7',
#         '7', '1', '2', '10', '10', '13', '22', '26', '37', '16', '20', '19',
#         '33', '16', '19', '4', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 1, 0, 0), 'Sunderland', 'Crystal Palace',
#         '59.2', '40.8', '86', '57', '139', '101', '1', '2', '1', '3', '6',
#         '12', '2', '1', '13', '11', '17', '13', '27', '22', '16', '20',
#         '23', '26', '14', '19', '4', '4'], dtype=object),
#  array([datetime.datetime(2016, 3, 1, 0, 0), 'Aston Villa', 'Everton',
#         '46.8', '53.2', '113', '81', '157', '112', '1', '3', '1', '3', '7',
#         '9', '1', '3', '11', '8', '19', '20', '25', '29', '16', '35', '20',
#         '47', '17', '10', '3', '5'], dtype=object),
#  array([datetime.datetime(2016, 3, 1, 0, 0), 'Bournemouth', 'Southampton',
#         '45.4', '54.6', '86', '77', '124', '129', '2', '0', '1', '1', '4',
#         '4', '1', '0', '6', '6', '12', '13', '18', '20', '26', '31', '33',
#         '43', '10', '9', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 3, 1, 0, 0), 'Leicester City',
#         'West Bromwich Albion', '65.0', '35.0', '110', '41', '165', '95',
#         '1', '1', '3', '1', '16', '5', '1', '1', '13', '7', '23', '14',
#         '30', '25', '12', '30', '17', '48', '25', '24', '2', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 28, 0, 0), 'Manchester United',
#         'Arsenal', '38.9', '61.1', '80', '117', '107', '167', '2', '2', '0',
#         '3', '3', '10', '2', '1', '3', '8', '24', '14', '35', '20', '24',
#         '12', '30', '20', '15', '17', '3', '1'], dtype=object),
#  array([datetime.datetime(2016, 2, 28, 0, 0), 'Tottenham Hotspur',
#         'Swansea City', '57.2', '42.8', '136', '38', '198', '80', '2', '1',
#         '6', '2', '19', '4', '0', '0', '22', '5', '11', '18', '14', '23',
#         '19', '38', '26', '52', '21', '19', '3', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'West Ham United',
#         'Sunderland', '52.8', '47.2', '90', '56', '145', '114', '1', '0',
#         '0', '3', '5', '6', '0', '0', '5', '9', '17', '26', '24', '39',
#         '16', '20', '25', '29', '23', '15', '3', '0'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'Stoke City', 'Aston Villa',
#         '55.3', '44.7', '97', '95', '149', '138', '2', '1', '0', '0', '7',
#         '3', '1', '1', '8', '3', '10', '15', '15', '24', '16', '20', '20',
#         '41', '16', '20', '0', '2'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'Watford', 'Bournemouth',
#         '47.2', '52.8', '65', '72', '116', '115', '0', '0', '1', '2', '6',
#         '6', '0', '0', '8', '7', '14', '20', '27', '29', '21', '36', '28',
#         '43', '16', '12', '4', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'Southampton', 'Chelsea',
#         '34.6', '65.4', '62', '226', '110', '267', '1', '2', '0', '0', '2',
#         '7', '0', '2', '6', '14', '14', '13', '29', '17', '22', '26', '34',
#         '34', '18', '7', '3', '2'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'Leicester City',
#         'Norwich City', '58.8', '41.2', '100', '78', '160', '134', '1', '0',
#         '0', '1', '6', '5', '0', '0', '9', '9', '14', '17', '22', '27', '6',
#         '47', '13', '60', '18', '14', '3', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 27, 0, 0), 'West Bromwich Albion',
#         'Crystal Palace', '46.1', '53.9', '94', '73', '138', '112', '3',
#         '2', '2', '0', '7', '11', '2', '1', '7', '8', '14', '11', '22',
#         '20', '31', '10', '37', '18', '10', '14', '5', '1'], dtype=object),
#  array([datetime.datetime(2016, 2, 14, 0, 0), 'Arsenal', 'Leicester City',
#         '72.1', '27.9', '234', '52', '284', '96', '2', '1', '4', '1', '22',
#         '3', '2', '0', '19', '6', '17', '37', '26', '53', '12', '25', '18',
#         '39', '15', '26', '0', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 14, 0, 0), 'Aston Villa', 'Liverpool',
#         '39.3', '60.7', '73', '130', '107', '181', '0', '3', '1', '3', '3',
#         '7', '0', '4', '5', '7', '19', '24', '28', '34', '17', '12', '24',
#         '17', '34', '20', '1', '1'], dtype=object),
#  array([datetime.datetime(2016, 2, 14, 0, 0), 'Manchester City',
#         'Tottenham Hotspur', '46.0', '54.0', '128', '92', '185', '136', '1',
#         '2', '1', '0', '14', '3', '1', '1', '12', '3', '26', '33', '40',
#         '45', '22', '25', '27', '39', '18', '16', '1', '8'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Sunderland',
#         'Manchester United', '34.1', '65.9', '48', '139', '96', '174', '0',
#         '1', '2', '3', '12', '8', '0', '0', '11', '9', '16', '17', '21',
#         '24', '34', '16', '46', '21', '22', '14', '5', '7'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Swansea City', 'Southampton',
#         '54.4', '45.6', '92', '77', '150', '123', '0', '1', '1', '2', '7',
#         '7', '0', '1', '9', '12', '11', '11', '13', '14', '24', '48', '30',
#         '64', '21', '16', '5', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Bournemouth', 'Stoke City',
#         '65.2', '34.8', '135', '48', '188', '81', '1', '1', '1', '1', '7',
#         '4', '1', '2', '7', '7', '15', '16', '23', '23', '8', '22', '11',
#         '35', '11', '25', '1', '5'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Crystal Palace', 'Watford',
#         '53.9', '46.1', '75', '77', '120', '129', '1', '2', '1', '2', '5',
#         '5', '1', '0', '8', '7', '18', '30', '25', '43', '21', '26', '26',
#         '39', '18', '22', '2', '2'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Everton',
#         'West Bromwich Albion', '75.9', '24.1', '243', '40', '304', '70',
#         '0', '1', '3', '0', '16', '4', '0', '1', '25', '5', '14', '17',
#         '20', '32', '15', '52', '18', '70', '12', '16', '1', '15'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Norwich City',
#         'West Ham United', '48.4', '51.6', '92', '91', '150', '133', '1',
#         '1', '1', '3', '6', '6', '0', '1', '6', '6', '21', '14', '36', '23',
#         '21', '18', '28', '26', '10', '23', '0', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 13, 0, 0), 'Chelsea', 'Newcastle United',
#         '54.9', '45.1', '140', '58', '189', '77', '4', '0', '0', '1', '7',
#         '5', '4', '1', '11', '7', '21', '14', '28', '22', '12', '15', '21',
#         '16', '12', '23', '5', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 7, 0, 0), 'Bournemouth', 'Arsenal',
#         '50.7', '49.3', '114', '98', '154', '144', '0', '2', '2', '3', '6',
#         '6', '0', '2', '12', '8', '22', '19', '29', '30', '20', '23', '25',
#         '37', '19', '26', '3', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 7, 0, 0), 'Chelsea', 'Manchester United',
#         '49.3', '50.7', '107', '119', '156', '154', '1', '1', '4', '2',
#         '12', '9', '0', '1', '12', '13', '23', '20', '34', '32', '15', '20',
#         '32', '36', '8', '13', '3', '5'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Manchester City',
#         'Leicester City', '65.9', '34.1', '217', '55', '259', '105', '1',
#         '3', '2', '3', '16', '12', '1', '3', '17', '12', '14', '27', '28',
#         '39', '24', '24', '31', '41', '21', '18', '2', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Swansea City',
#         'Crystal Palace', '58.4', '41.6', '111', '64', '156', '111', '0',
#         '1', '0', '0', '11', '7', '0', '1', '10', '10', '25', '22', '35',
#         '28', '31', '27', '42', '38', '16', '25', '3', '7'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Stoke City', 'Everton',
#         '65.5', '34.5', '172', '46', '221', '78', '0', '3', '2', '3', '8',
#         '13', '0', '1', '11', '12', '13', '25', '24', '39', '4', '27', '9',
#         '42', '15', '14', '5', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Aston Villa', 'Norwich City',
#         '48.3', '51.7', '87', '91', '133', '152', '1', '0', '0', '1', '7',
#         '9', '1', '0', '8', '11', '16', '20', '21', '27', '25', '22', '43',
#         '29', '21', '8', '5', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Liverpool', 'Sunderland',
#         '71.3', '28.7', '166', '42', '244', '88', '2', '1', '3', '0', '9',
#         '2', '2', '1', '14', '6', '16', '19', '19', '34', '7', '31', '12',
#         '52', '13', '16', '1', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Tottenham Hotspur', 'Watford',
#         '65.9', '34.1', '139', '42', '196', '81', '1', '0', '7', '0', '19',
#         '1', '1', '0', '21', '2', '14', '23', '22', '40', '14', '32', '19',
#         '43', '21', '27', '1', '8'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Newcastle United',
#         'West Bromwich Albion', '68.9', '31.1', '96', '35', '139', '71',
#         '0', '0', '3', '0', '9', '3', '1', '0', '14', '3', '13', '18', '14',
#         '29', '11', '22', '12', '30', '20', '29', '4', '7'], dtype=object),
#  array([datetime.datetime(2016, 2, 6, 0, 0), 'Southampton',
#         'West Ham United', '35.2', '64.8', '49', '109', '83', '148', '1',
#         '0', '1', '2', '7', '10', '1', '0', '6', '14', '19', '19', '26',
#         '21', '40', '21', '50', '24', '17', '5', '10', '2'], dtype=object),
#  array([datetime.datetime(2016, 2, 3, 0, 0), 'Watford', 'Chelsea', '45.0',
#         '55.0', '81', '120', '128', '157', '0', '0', '2', '2', '7', '9',
#         '0', '0', '10', '8', '20', '22', '32', '34', '20', '20', '21', '28',
#         '29', '21', '5', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 3, 0, 0), 'Everton', 'Newcastle United',
#         '55.8', '44.2', '114', '63', '161', '93', '2', '0', '1', '2', '9',
#         '3', '1', '0', '10', '6', '30', '21', '41', '34', '20', '15', '31',
#         '22', '15', '14', '1', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'West Ham United',
#         'Aston Villa', '68.0', '32.0', '199', '48', '236', '87', '2', '0',
#         '1', '0', '14', '0', '2', '0', '20', '5', '16', '20', '24', '35',
#         '13', '19', '22', '26', '17', '21', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Leicester City', 'Liverpool',
#         '36.1', '63.9', '72', '127', '128', '184', '1', '0', '1', '1', '3',
#         '5', '1', '0', '5', '11', '16', '30', '28', '42', '31', '22', '47',
#         '31', '32', '11', '8', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Sunderland',
#         'Manchester City', '49.6', '50.4', '90', '93', '161', '136', '0',
#         '1', '1', '0', '6', '4', '0', '0', '6', '5', '33', '21', '52', '36',
#         '34', '36', '39', '48', '15', '20', '2', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Arsenal', 'Southampton',
#         '66.7', '33.3', '134', '73', '172', '122', '0', '0', '9', '1', '21',
#         '6', '0', '0', '19', '7', '23', '32', '26', '46', '10', '22', '14',
#         '34', '22', '33', '7', '6'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Norwich City',
#         'Tottenham Hotspur', '45.8', '54.2', '69', '62', '108', '101', '0',
#         '3', '2', '1', '7', '12', '0', '0', '9', '11', '17', '24', '20',
#         '26', '20', '26', '35', '34', '13', '15', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Crystal Palace',
#         'Bournemouth', '50.6', '49.4', '100', '89', '163', '127', '1', '2',
#         '1', '1', '8', '4', '1', '1', '10', '5', '11', '16', '15', '28',
#         '17', '32', '28', '45', '19', '10', '2', '4'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'Manchester United',
#         'Stoke City', '46.9', '53.1', '124', '109', '161', '145', '3', '0',
#         '0', '0', '11', '2', '3', '0', '15', '7', '21', '12', '28', '19',
#         '22', '7', '30', '8', '19', '15', '3', '5'], dtype=object),
#  array([datetime.datetime(2016, 2, 2, 0, 0), 'West Bromwich Albion',
#         'Swansea City', '45.3', '54.7', '99', '85', '158', '129', '1', '1',
#         '2', '2', '13', '9', '0', '0', '12', '12', '14', '10', '19', '20',
#         '16', '37', '21', '52', '27', '26', '6', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 24, 0, 0), 'Everton', 'Swansea City',
#         '59.7', '40.3', '167', '59', '225', '97', '0', '2', '1', '1', '13',
#         '4', '0', '1', '16', '5', '16', '15', '22', '26', '10', '29', '14',
#         '41', '17', '25', '1', '7'], dtype=object),
#  array([datetime.datetime(2016, 1, 24, 0, 0), 'Arsenal', 'Chelsea', '46.6',
#         '53.4', '124', '121', '167', '164', '0', '1', '1', '3', '7', '10',
#         '0', '1', '8', '7', '17', '23', '27', '42', '12', '19', '17', '31',
#         '17', '13', '4', '1'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Norwich City', 'Liverpool',
#         '47.9', '52.1', '86', '91', '147', '142', '3', '5', '1', '1', '5',
#         '8', '3', '3', '5', '9', '20', '22', '30', '35', '21', '25', '34',
#         '34', '14', '13', '4', '1'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'West Bromwich Albion',
#         'Aston Villa', '39.4', '60.6', '54', '138', '100', '177', '0', '0',
#         '0', '0', '2', '6', '0', '0', '4', '12', '17', '21', '26', '27',
#         '29', '25', '38', '38', '23', '15', '4', '1'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Sunderland', 'Bournemouth',
#         '42.7', '57.3', '71', '110', '120', '143', '1', '1', '2', '3', '5',
#         '8', '1', '1', '7', '13', '20', '23', '27', '29', '24', '32', '38',
#         '38', '17', '25', '2', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Watford', 'Newcastle United',
#         '51.3', '48.7', '82', '65', '136', '122', '2', '1', '3', '0', '10',
#         '10', '2', '1', '10', '10', '31', '18', '40', '30', '12', '13',
#         '19', '18', '32', '17', '1', '1'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Manchester United',
#         'Southampton', '55.4', '44.6', '93', '62', '136', '128', '0', '1',
#         '0', '1', '1', '5', '0', '1', '7', '6', '9', '18', '15', '25', '16',
#         '20', '24', '33', '21', '40', '0', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Leicester City',
#         'Stoke City', '45.2', '54.8', '76', '68', '125', '109', '2', '0',
#         '2', '1', '11', '1', '1', '0', '8', '1', '19', '20', '26', '36',
#         '13', '18', '21', '28', '14', '8', '1', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'Crystal Palace',
#         'Tottenham Hotspur', '36.1', '63.9', '57', '139', '106', '191', '0',
#         '1', '2', '5', '7', '8', '0', '3', '5', '21', '22', '17', '37',
#         '24', '18', '40', '25', '45', '27', '7', '7', '5'], dtype=object),
#  array([datetime.datetime(2016, 1, 23, 0, 0), 'West Ham United',
#         'Manchester City', '46.7', '53.3', '76', '114', '133', '167', '2',
#         '2', '0', '1', '7', '10', '1', '0', '8', '12', '23', '16', '36',
#         '29', '19', '32', '27', '37', '11', '18', '9', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 18, 0, 0), 'Swansea City', 'Watford',
#         '56.7', '43.3', '104', '74', '147', '123', '1', '0', '0', '0', '4',
#         '3', '1', '0', '6', '8', '17', '32', '23', '46', '45', '26', '61',
#         '35', '18', '21', '3', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 17, 0, 0), 'Liverpool',
#         'Manchester United', '53.3', '46.7', '107', '73', '173', '125', '0',
#         '1', '1', '0', '7', '4', '0', '0', '16', '5', '36', '26', '49',
#         '38', '7', '31', '14', '37', '14', '23', '1', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 17, 0, 0), 'Stoke City', 'Arsenal',
#         '45.0', '55.0', '65', '97', '110', '143', '0', '0', '3', '2', '7',
#         '4', '0', '0', '9', '7', '9', '11', '25', '19', '15', '25', '20',
#         '35', '19', '21', '3', '6'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Tottenham Hotspur',
#         'Sunderland', '66.6', '33.4', '163', '48', '216', '90', '3', '1',
#         '3', '0', '14', '2', '1', '1', '18', '5', '18', '19', '24', '28',
#         '13', '28', '20', '36', '11', '10', '1', '6'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Manchester City',
#         'Crystal Palace', '52.8', '47.2', '116', '70', '149', '113', '2',
#         '0', '0', '2', '9', '5', '4', '0', '12', '7', '22', '24', '34',
#         '36', '27', '8', '36', '11', '26', '22', '1', '7'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Chelsea', 'Everton', '54.9',
#         '45.1', '150', '65', '195', '105', '3', '2', '2', '1', '8', '6',
#         '3', '2', '10', '8', '26', '18', '40', '31', '14', '30', '16', '39',
#         '21', '15', '2', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Bournemouth', 'Norwich City',
#         '45.4', '54.6', '65', '109', '99', '157', '3', '0', '2', '2', '8',
#         '6', '2', '0', '11', '5', '19', '21', '27', '34', '24', '17', '32',
#         '23', '20', '10', '4', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Southampton',
#         'West Bromwich Albion', '55.8', '44.2', '91', '62', '141', '109',
#         '2', '0', '0', '0', '6', '3', '1', '0', '5', '5', '14', '16', '19',
#         '25', '25', '16', '38', '24', '16', '15', '3', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Newcastle United',
#         'West Ham United', '50.7', '49.3', '82', '78', '112', '112', '1',
#         '1', '5', '2', '13', '6', '2', '0', '20', '8', '24', '23', '32',
#         '30', '17', '10', '23', '20', '22', '16', '2', '5'], dtype=object),
#  array([datetime.datetime(2016, 1, 16, 0, 0), 'Aston Villa',
#         'Leicester City', '56.5', '43.5', '107', '66', '146', '115', '1',
#         '1', '3', '2', '9', '7', '0', '0', '8', '8', '18', '20', '24', '29',
#         '16', '30', '19', '38', '17', '20', '1', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Swansea City', 'Sunderland',
#         '51.2', '48.8', '87', '85', '128', '124', '2', '3', '0', '1', '4',
#         '7', '1', '2', '9', '6', '11', '22', '17', '33', '7', '22', '13',
#         '37', '15', '9', '0', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Manchester City', 'Everton',
#         '55.4', '44.6', '245', '83', '282', '105', '0', '0', '5', '1', '15',
#         '6', '0', '0', '18', '6', '16', '14', '32', '32', '13', '29', '15',
#         '48', '8', '11', '2', '10'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Stoke City', 'Norwich City',
#         '64.4', '35.6', '99', '77', '133', '115', '1', '0', '2', '1', '7',
#         '2', '2', '1', '13', '4', '21', '10', '35', '18', '9', '27', '14',
#         '35', '18', '12', '0', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Southampton', 'Watford',
#         '50.3', '49.7', '108', '41', '166', '85', '2', '0', '2', '0', '10',
#         '1', '2', '0', '8', '3', '22', '10', '28', '16', '25', '25', '32',
#         '33', '26', '26', '3', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Chelsea',
#         'West Bromwich Albion', '61.7', '38.3', '105', '71', '143', '131',
#         '1', '0', '1', '2', '7', '7', '1', '0', '10', '9', '13', '21', '20',
#         '32', '24', '14', '36', '20', '16', '28', '2', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Liverpool', 'Arsenal',
#         '59.5', '40.5', '135', '73', '195', '128', '2', '3', '1', '1', '12',
#         '11', '2', '2', '15', '11', '21', '20', '27', '31', '20', '35',
#         '20', '46', '20', '17', '5', '10'], dtype=object),
#  array([datetime.datetime(2016, 1, 13, 0, 0), 'Tottenham Hotspur',
#         'Leicester City', '61.7', '38.3', '118', '55', '167', '112', '0',
#         '1', '2', '0', '10', '7', '0', '1', '14', '5', '14', '28', '19',
#         '33', '28', '44', '40', '58', '15', '16', '5', '11'], dtype=object),
#  array([datetime.datetime(2016, 1, 12, 0, 0), 'Aston Villa',
#         'Crystal Palace', '51.3', '48.7', '105', '59', '136', '113', '0',
#         '0', '2', '0', '6', '4', '0', '0', '7', '5', '25', '10', '32', '20',
#         '22', '14', '27', '22', '19', '27', '1', '7'], dtype=object),
#  array([datetime.datetime(2016, 1, 12, 0, 0), 'Bournemouth',
#         'West Ham United', '48.7', '51.3', '81', '81', '125', '126', '0',
#         '1', '0', '1', '2', '3', '1', '1', '10', '5', '18', '21', '36',
#         '39', '19', '13', '30', '22', '22', '14', '1', '4'], dtype=object),
#  array([datetime.datetime(2016, 1, 12, 0, 0), 'Newcastle United',
#         'Manchester United', '54.2', '45.8', '90', '112', '132', '138', '3',
#         '2', '2', '1', '10', '8', '1', '1', '10', '10', '27', '22', '37',
#         '29', '12', '20', '17', '32', '23', '13', '2', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 3, 0, 0), 'Crystal Palace', 'Chelsea',
#         '39.8', '60.2', '66', '123', '116', '169', '0', '2', '3', '1', '4',
#         '7', '0', '2', '7', '9', '17', '23', '27', '31', '9', '14', '19',
#         '22', '23', '14', '4', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 3, 0, 0), 'Everton', 'Tottenham Hotspur',
#         '40.8', '59.2', '65', '145', '113', '202', '1', '1', '1', '0', '8',
#         '4', '1', '1', '7', '18', '21', '18', '27', '34', '28', '20', '35',
#         '26', '23', '19', '11', '5'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'West Ham United', 'Liverpool',
#         '35.6', '64.4', '52', '159', '86', '226', '2', '0', '7', '1', '14',
#         '9', '2', '0', '13', '20', '22', '18', '32', '21', '41', '12', '59',
#         '20', '27', '13', '12', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Sunderland', 'Aston Villa',
#         '44.9', '55.1', '60', '92', '111', '132', '2', '1', '2', '2', '7',
#         '5', '2', '1', '11', '7', '21', '14', '34', '19', '21', '16', '34',
#         '26', '14', '14', '0', '3'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Leicester City',
#         'Bournemouth', '53.5', '46.5', '128', '45', '187', '72', '0', '0',
#         '1', '0', '9', '5', '0', '0', '10', '7', '18', '24', '32', '33',
#         '6', '33', '13', '47', '13', '17', '5', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Arsenal', 'Newcastle United',
#         '51.1', '48.9', '115', '69', '148', '100', '1', '0', '2', '6', '12',
#         '11', '1', '0', '14', '11', '19', '20', '36', '33', '12', '13',
#         '15', '20', '18', '24', '4', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Norwich City', 'Southampton',
#         '41.6', '58.4', '71', '107', '121', '161', '1', '0', '0', '3', '6',
#         '8', '1', '0', '6', '9', '9', '19', '11', '27', '45', '20', '50',
#         '23', '11', '15', '1', '2'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'West Bromwich Albion',
#         'Stoke City', '45.7', '54.3', '95', '77', '147', '112', '2', '1',
#         '2', '1', '11', '6', '1', '1', '11', '10', '16', '13', '23', '20',
#         '13', '16', '18', '22', '9', '11', '5', '6'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Manchester United',
#         'Swansea City', '54.7', '45.3', '148', '59', '187', '100', '2', '1',
#         '3', '2', '16', '8', '2', '1', '14', '6', '19', '16', '25', '31',
#         '5', '19', '7', '31', '16', '16', '2', '8'], dtype=object),
#  array([datetime.datetime(2016, 1, 2, 0, 0), 'Watford', 'Manchester City',
#         '48.5', '51.5', '88', '116', '140', '153', '0', '2', '3', '1', '6',
#         '8', '0', '2', '6', '15', '18', '28', '28', '45', '15', '34', '21',
#         '44', '26', '18', '3', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 30, 0, 0), 'Sunderland', 'Liverpool',
#         '42.3', '57.7', '48', '103', '103', '167', '0', '1', '2', '2', '3',
#         '10', '0', '1', '6', '14', '13', '16', '21', '25', '26', '23', '47',
#         '35', '15', '12', '4', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 29, 0, 0), 'Leicester City',
#         'Manchester City', '39.3', '60.7', '56', '118', '98', '161', '0',
#         '0', '2', '4', '5', '14', '0', '0', '9', '15', '14', '18', '22',
#         '27', '26', '33', '44', '37', '20', '22', '7', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Norwich City',
#         'Aston Villa', '48.2', '51.8', '63', '71', '107', '112', '2', '0',
#         '0', '1', '4', '2', '1', '0', '5', '5', '20', '20', '34', '29',
#         '18', '25', '24', '32', '15', '13', '1', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'West Bromwich Albion',
#         'Newcastle United', '51.7', '48.3', '117', '61', '162', '85', '1',
#         '0', '2', '2', '17', '7', '1', '0', '15', '5', '20', '15', '25',
#         '25', '12', '33', '21', '52', '16', '17', '2', '11'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Everton', 'Stoke City',
#         '51.3', '48.7', '121', '57', '162', '84', '3', '4', '0', '0', '10',
#         '6', '3', '2', '13', '5', '19', '21', '31', '41', '15', '22', '18',
#         '33', '16', '15', '2', '6'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Crystal Palace',
#         'Swansea City', '53.6', '46.4', '79', '66', '137', '102', '0', '0',
#         '2', '0', '6', '1', '0', '0', '7', '2', '12', '11', '15', '19', '8',
#         '26', '16', '45', '20', '17', '2', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Watford',
#         'Tottenham Hotspur', '37.5', '62.5', '51', '100', '116', '150', '1',
#         '1', '0', '1', '5', '5', '1', '2', '6', '7', '15', '12', '25', '17',
#         '15', '22', '26', '31', '40', '25', '0', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Arsenal', 'Bournemouth',
#         '51.4', '48.6', '117', '112', '152', '144', '2', '0', '3', '1',
#         '11', '4', '2', '0', '11', '8', '18', '20', '29', '27', '11', '24',
#         '11', '30', '23', '13', '4', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'Manchester United',
#         'Chelsea', '66.8', '33.2', '145', '34', '174', '65', '0', '0', '1',
#         '3', '4', '6', '0', '0', '10', '7', '21', '26', '31', '31', '8',
#         '27', '12', '33', '15', '14', '0', '5'], dtype=object),
#  array([datetime.datetime(2015, 12, 28, 0, 0), 'West Ham United',
#         'Southampton', '49.1', '50.9', '49', '121', '92', '179', '2', '0',
#         '2', '1', '9', '7', '0', '0', '8', '8', '23', '21', '33', '27',
#         '36', '22', '46', '31', '18', '20', '3', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Stoke City',
#         'Manchester United', '41.5', '58.5', '43', '92', '76', '138', '1',
#         '0', '0', '3', '3', '6', '1', '0', '7', '6', '24', '16', '31', '28',
#         '18', '6', '31', '13', '23', '11', '2', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Bournemouth',
#         'Crystal Palace', '55.2', '44.8', '81', '67', '124', '131', '0',
#         '0', '1', '0', '5', '6', '0', '0', '7', '6', '26', '18', '36', '32',
#         '31', '17', '41', '31', '20', '24', '4', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Liverpool',
#         'Leicester City', '64.8', '35.2', '109', '59', '178', '127', '1',
#         '0', '2', '1', '13', '5', '1', '0', '22', '6', '18', '21', '25',
#         '30', '38', '36', '52', '50', '14', '19', '1', '10'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Tottenham Hotspur',
#         'Norwich City', '59.8', '40.2', '82', '72', '117', '112', '2', '0',
#         '6', '1', '12', '7', '2', '0', '12', '10', '18', '18', '22', '27',
#         '12', '20', '22', '34', '21', '18', '1', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Manchester City',
#         'Sunderland', '66.4', '33.6', '152', '51', '194', '91', '3', '1',
#         '3', '2', '12', '9', '3', '0', '12', '7', '15', '20', '22', '36',
#         '18', '17', '22', '26', '11', '15', '0', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Chelsea', 'Watford', '62.4',
#         '37.6', '152', '46', '199', '73', '2', '1', '0', '0', '10', '7',
#         '1', '0', '10', '5', '21', '29', '28', '35', '8', '18', '14', '28',
#         '5', '15', '5', '6'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Swansea City',
#         'West Bromwich Albion', '55.5', '44.5', '80', '78', '123', '131',
#         '1', '0', '1', '3', '5', '7', '0', '0', '6', '6', '15', '14', '20',
#         '22', '21', '9', '39', '12', '16', '24', '3', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Aston Villa',
#         'West Ham United', '59.1', '40.9', '112', '50', '152', '86', '1',
#         '0', '4', '1', '9', '6', '0', '1', '10', '6', '18', '21', '27',
#         '30', '19', '36', '31', '54', '15', '9', '2', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Newcastle United',
#         'Everton', '40.9', '59.1', '80', '139', '117', '176', '0', '1', '1',
#         '5', '7', '11', '0', '0', '7', '13', '23', '18', '45', '26', '25',
#         '12', '32', '19', '11', '15', '8', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 26, 0, 0), 'Southampton', 'Arsenal',
#         '35.2', '64.8', '56', '120', '96', '159', '3', '0', '0', '4', '9',
#         '7', '3', '0', '9', '7', '22', '11', '31', '20', '14', '18', '23',
#         '21', '15', '16', '0', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 21, 0, 0), 'Arsenal', 'Manchester City',
#         '37.3', '62.7', '72', '161', '114', '196', '1', '0', '2', '3', '6',
#         '11', '2', '1', '8', '17', '20', '19', '29', '31', '20', '22', '33',
#         '29', '24', '18', '6', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 20, 0, 0), 'Watford', 'Liverpool',
#         '35.1', '64.9', '57', '85', '128', '133', '3', '0', '2', '2', '5',
#         '7', '1', '0', '4', '7', '28', '19', '36', '25', '16', '19', '25',
#         '32', '18', '10', '4', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 20, 0, 0), 'Swansea City',
#         'West Ham United', '72.7', '27.3', '117', '56', '165', '85', '0',
#         '0', '1', '1', '11', '6', '0', '0', '14', '8', '18', '13', '22',
#         '22', '17', '29', '23', '45', '14', '26', '3', '11'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'West Bromwich Albion',
#         'Bournemouth', '32.6', '67.4', '62', '176', '104', '205', '1', '1',
#         '1', '1', '5', '7', '1', '1', '6', '13', '10', '12', '24', '17',
#         '11', '25', '20', '35', '18', '11', '4', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Stoke City',
#         'Crystal Palace', '58.4', '41.6', '100', '41', '145', '77', '1',
#         '1', '2', '1', '11', '8', '0', '0', '19', '7', '17', '16', '27',
#         '25', '14', '20', '19', '30', '12', '12', '2', '11'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Everton', 'Leicester City',
#         '67.4', '32.6', '91', '38', '154', '86', '2', '3', '1', '1', '10',
#         '7', '1', '1', '9', '5', '13', '30', '21', '50', '19', '25', '21',
#         '40', '8', '35', '0', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Manchester United',
#         'Norwich City', '70.4', '29.6', '185', '42', '249', '65', '1', '1',
#         '0', '0', '6', '2', '1', '2', '7', '5', '17', '15', '27', '24', '4',
#         '53', '7', '74', '17', '15', '0', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Chelsea', 'Sunderland',
#         '67.2', '32.8', '150', '36', '187', '84', '3', '1', '2', '1', '11',
#         '7', '1', '0', '11', '5', '17', '27', '28', '43', '17', '25', '20',
#         '35', '15', '18', '2', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Southampton',
#         'Tottenham Hotspur', '51.0', '49.0', '88', '63', '136', '107', '0',
#         '2', '3', '2', '8', '8', '0', '2', '10', '9', '24', '20', '36',
#         '25', '8', '18', '16', '26', '27', '14', '3', '5'], dtype=object),
#  array([datetime.datetime(2015, 12, 19, 0, 0), 'Newcastle United',
#         'Aston Villa', '47.2', '52.8', '86', '68', '152', '104', '1', '1',
#         '3', '3', '8', '5', '1', '1', '8', '8', '26', '22', '35', '30',
#         '26', '14', '34', '19', '12', '30', '0', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 14, 0, 0), 'Leicester City', 'Chelsea',
#         '34.4', '65.6', '59', '111', '117', '156', '2', '1', '1', '2', '5',
#         '8', '2', '1', '7', '7', '26', '14', '37', '29', '20', '26', '38',
#         '34', '19', '18', '5', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 13, 0, 0), 'Aston Villa', 'Arsenal',
#         '45.7', '54.3', '96', '89', '128', '129', '0', '2', '0', '2', '7',
#         '7', '0', '1', '13', '6', '16', '18', '23', '27', '9', '16', '19',
#         '22', '15', '9', '1', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 13, 0, 0), 'Tottenham Hotspur',
#         'Newcastle United', '58.3', '41.7', '111', '56', '170', '99', '1',
#         '2', '2', '2', '7', '8', '1', '1', '16', '8', '18', '25', '21',
#         '29', '22', '20', '32', '25', '13', '19', '1', '5'], dtype=object),
#  array([datetime.datetime(2015, 12, 13, 0, 0), 'Liverpool',
#         'West Bromwich Albion', '70.4', '29.6', '206', '42', '274', '92',
#         '1', '2', '2', '0', '12', '3', '2', '2', '22', '3', '17', '9', '22',
#         '22', '6', '37', '12', '46', '11', '23', '0', '9'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'Norwich City', 'Everton',
#         '41.4', '58.6', '107', '106', '151', '153', '1', '1', '0', '2', '5',
#         '11', '0', '1', '7', '9', '18', '11', '27', '11', '25', '20', '35',
#         '29', '8', '7', '2', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'Crystal Palace',
#         'Southampton', '43.8', '56.2', '53', '98', '106', '151', '1', '0',
#         '3', '2', '9', '9', '1', '0', '9', '11', '17', '14', '24', '28',
#         '36', '37', '43', '49', '10', '7', '4', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'West Ham United',
#         'Stoke City', '46.8', '53.2', '74', '74', '117', '111', '0', '0',
#         '6', '3', '13', '9', '0', '0', '17', '8', '15', '21', '21', '30',
#         '28', '18', '39', '27', '16', '13', '5', '9'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'Manchester City',
#         'Swansea City', '53.0', '47.0', '139', '64', '170', '93', '2', '1',
#         '1', '4', '8', '10', '1', '1', '9', '9', '15', '16', '22', '24',
#         '19', '12', '25', '17', '19', '9', '3', '3'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'Sunderland', 'Watford',
#         '47.2', '52.8', '84', '80', '148', '127', '0', '1', '1', '4', '8',
#         '9', '0', '1', '10', '11', '8', '19', '19', '30', '19', '23', '28',
#         '31', '17', '18', '4', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 12, 0, 0), 'Bournemouth',
#         'Manchester United', '43.5', '56.5', '72', '96', '97', '133', '1',
#         '1', '1', '4', '6', '9', '1', '0', '8', '2', '27', '23', '45', '37',
#         '31', '13', '39', '21', '14', '10', '3', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 7, 0, 0), 'Everton', 'Crystal Palace',
#         '62.0', '38.0', '173', '73', '226', '108', '1', '1', '1', '3', '8',
#         '9', '1', '1', '13', '11', '24', '25', '37', '39', '20', '32', '26',
#         '45', '12', '25', '1', '7'], dtype=object),
#  array([datetime.datetime(2015, 12, 6, 0, 0), 'Newcastle United',
#         'Liverpool', '39.8', '60.2', '68', '114', '127', '176', '1', '0',
#         '0', '1', '4', '5', '1', '0', '5', '9', '26', '26', '36', '35',
#         '16', '11', '28', '13', '18', '12', '2', '1'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Stoke City',
#         'Manchester City', '46.5', '53.5', '66', '95', '108', '153', '2',
#         '0', '1', '3', '6', '5', '2', '0', '7', '8', '17', '27', '28', '53',
#         '13', '6', '23', '10', '41', '20', '1', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Southampton', 'Aston Villa',
#         '63.1', '36.9', '127', '46', '179', '85', '1', '1', '1', '0', '17',
#         '5', '1', '1', '18', '7', '25', '12', '31', '19', '5', '25', '11',
#         '40', '10', '22', '3', '7'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Swansea City',
#         'Leicester City', '59.0', '41.0', '67', '84', '117', '141', '0',
#         '3', '2', '1', '8', '10', '0', '3', '8', '13', '20', '19', '26',
#         '32', '27', '19', '31', '25', '28', '24', '6', '0'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Watford', 'Norwich City',
#         '50.4', '49.6', '81', '67', '137', '140', '2', '0', '5', '0', '9',
#         '4', '1', '0', '10', '5', '11', '9', '19', '20', '31', '31', '41',
#         '46', '15', '10', '2', '2'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Arsenal', 'Sunderland',
#         '72.5', '27.5', '183', '48', '239', '90', '3', '0', '2', '3', '10',
#         '6', '2', '0', '14', '8', '20', '13', '25', '22', '18', '26', '25',
#         '35', '16', '20', '1', '6'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'West Bromwich Albion',
#         'Tottenham Hotspur', '35.4', '64.6', '69', '103', '117', '143', '1',
#         '1', '2', '1', '6', '4', '1', '1', '5', '8', '15', '15', '29', '22',
#         '13', '18', '18', '28', '25', '14', '4', '4'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Manchester United',
#         'West Ham United', '62.6', '37.4', '133', '38', '172', '71', '0',
#         '0', '1', '1', '13', '5', '0', '0', '14', '7', '18', '27', '26',
#         '39', '9', '30', '12', '38', '11', '25', '2', '9'], dtype=object),
#  array([datetime.datetime(2015, 12, 5, 0, 0), 'Chelsea', 'Bournemouth',
# ...
#         '37.1', '201', '67', '244', '94', '1', '0', '1', '2', '8', '4', '1',
#         '0', '19', '5', '23', '21', '40', '36', '14', '17', '18', '23',
#         '11', '19', '3', '10'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Swansea City', 'Everton',
#         '47.8', '52.2', '59', '115', '94', '158', '0', '0', '2', '1', '7',
#         '11', '0', '0', '9', '13', '21', '17', '31', '25', '19', '11', '24',
#         '16', '13', '27', '8', '3'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Stoke City',
#         'Leicester City', '54.3', '45.7', '75', '79', '124', '131', '2',
#         '2', '0', '1', '5', '7', '1', '1', '8', '10', '32', '15', '43',
#         '30', '15', '28', '19', '36', '14', '28', '1', '2'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Bournemouth', 'Sunderland',
#         '52.8', '47.2', '104', '56', '144', '102', '1', '0', '1', '1', '7',
#         '3', '1', '0', '12', '5', '23', '25', '37', '42', '13', '14', '18',
#         '19', '13', '18', '4', '6'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Newcastle United', 'Watford',
#         '58.2', '41.8', '116', '78', '156', '127', '1', '2', '2', '1', '9',
#         '7', '1', '2', '11', '12', '19', '29', '28', '44', '7', '14', '10',
#         '28', '21', '18', '3', '3'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Aston Villa',
#         'West Bromwich Albion', '59.8', '40.2', '88', '63', '134', '109',
#         '0', '1', '0', '3', '3', '7', '0', '0', '7', '9', '30', '15', '38',
#         '27', '24', '35', '38', '41', '20', '29', '2', '5'], dtype=object),
#  array([datetime.datetime(2015, 9, 19, 0, 0), 'Manchester City',
#         'West Ham United', '72.3', '27.7', '226', '37', '274', '66', '0',
#         '1', '6', '0', '18', '4', '1', '2', '22', '5', '19', '20', '32',
#         '37', '17', '43', '18', '66', '13', '17', '0', '10'], dtype=object),
#  array([datetime.datetime(2015, 9, 14, 0, 0), 'West Ham United',
#         'Newcastle United', '39.3', '60.7', '87', '90', '126', '134', '1',
#         '0', '1', '4', '9', '6', '1', '0', '12', '8', '18', '17', '26',
#         '27', '20', '13', '30', '24', '33', '18', '5', '4'], dtype=object),
#  array([datetime.datetime(2015, 9, 13, 0, 0), 'Sunderland',
#         'Tottenham Hotspur', '43.6', '56.4', '61', '98', '102', '139', '0',
#         '1', '1', '2', '6', '8', '0', '1', '10', '13', '22', '26', '31',
#         '34', '21', '25', '33', '37', '13', '15', '5', '5'], dtype=object),
#  array([datetime.datetime(2015, 9, 13, 0, 0), 'Leicester City',
#         'Aston Villa', '49.1', '50.9', '95', '56', '140', '89', '3', '0',
#         '0', '2', '9', '5', '3', '1', '16', '9', '32', '28', '41', '53',
#         '12', '24', '17', '33', '16', '18', '4', '6'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Everton', 'Chelsea', '38.2',
#         '61.8', '77', '156', '109', '199', '2', '0', '4', '1', '9', '9',
#         '3', '1', '11', '12', '23', '21', '30', '30', '31', '11', '47',
#         '16', '7', '11', '7', '0'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Norwich City', 'Bournemouth',
#         '47.8', '52.2', '100', '82', '146', '118', '2', '1', '1', '1', '7',
#         '5', '2', '1', '9', '7', '21', '13', '26', '20', '10', '13', '17',
#         '18', '19', '18', '2', '0'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Crystal Palace',
#         'Manchester City', '42.1', '57.9', '51', '161', '90', '208', '0',
#         '1', '2', '4', '5', '12', '0', '0', '7', '16', '17', '15', '21',
#         '26', '21', '16', '33', '23', '21', '18', '5', '2'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'West Bromwich Albion',
#         'Southampton', '34.6', '65.4', '70', '147', '122', '182', '0', '0',
#         '1', '3', '5', '10', '0', '0', '7', '14', '20', '12', '26', '18',
#         '20', '17', '31', '24', '9', '18', '5', '3'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Arsenal', 'Stoke City',
#         '68.6', '31.4', '169', '39', '217', '72', '2', '0', '8', '1', '23',
#         '2', '2', '0', '24', '6', '18', '16', '26', '28', '10', '21', '14',
#         '33', '25', '15', '3', '8'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Watford', 'Swansea City',
#         '38.9', '61.1', '84', '94', '132', '147', '1', '0', '4', '1', '9',
#         '3', '1', '0', '11', '7', '17', '8', '23', '13', '20', '31', '29',
#         '40', '25', '8', '1', '4'], dtype=object),
#  array([datetime.datetime(2015, 9, 12, 0, 0), 'Manchester United',
#         'Liverpool', '55.7', '44.3', '114', '59', '158', '100', '3', '1',
#         '0', '2', '3', '6', '2', '0', '6', '5', '23', '23', '33', '29',
#         '24', '16', '26', '29', '27', '12', '1', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 30, 0, 0), 'Southampton', 'Norwich City',
#         '61.9', '38.1', '116', '48', '158', '89', '3', '0', '4', '0', '17',
#         '3', '2', '0', '18', '5', '16', '14', '20', '24', '14', '20', '20',
#         '30', '15', '11', '2', '1'], dtype=object),
#  array([datetime.datetime(2015, 8, 30, 0, 0), 'Swansea City',
#         'Manchester United', '35.1', '64.9', '41', '139', '94', '186', '2',
#         '1', '0', '2', '4', '7', '2', '1', '7', '10', '14', '15', '23',
#         '22', '29', '16', '34', '20', '21', '18', '1', '1'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Newcastle United', 'Arsenal',
#         '25.7', '74.3', '40', '241', '60', '293', '0', '0', '0', '6', '1',
#         '14', '0', '0', '1', '16', '21', '21', '26', '25', '27', '8', '35',
#         '15', '13', '15', '7', '0'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Chelsea', 'Crystal Palace',
#         '64.2', '35.8', '177', '61', '229', '100', '1', '2', '4', '2', '17',
#         '9', '1', '1', '18', '10', '16', '17', '20', '30', '13', '38', '23',
#         '47', '9', '9', '2', '8'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Bournemouth',
#         'Leicester City', '56.2', '43.8', '82', '70', '127', '119', '1',
#         '1', '0', '1', '2', '4', '0', '0', '2', '3', '16', '30', '28', '36',
#         '24', '12', '30', '21', '21', '29', '0', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Aston Villa', 'Sunderland',
#         '62.6', '37.4', '116', '33', '155', '72', '2', '1', '2', '1', '14',
#         '4', '1', '1', '18', '5', '20', '32', '25', '47', '21', '30', '29',
#         '40', '14', '22', '1', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Manchester City', 'Watford',
#         '59.4', '40.6', '191', '68', '229', '92', '2', '0', '2', '0', '8',
#         '3', '2', '0', '15', '4', '15', '30', '23', '43', '14', '16', '18',
#         '26', '11', '19', '5', '5'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Stoke City',
#         'West Bromwich Albion', '48.7', '51.3', '67', '115', '94', '143',
#         '0', '1', '1', '1', '3', '8', '0', '1', '8', '10', '18', '19', '27',
#         '33', '17', '24', '25', '29', '6', '18', '4', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Liverpool',
#         'West Ham United', '63.1', '36.9', '162', '51', '213', '89', '0',
#         '3', '0', '1', '4', '8', '0', '1', '12', '6', '12', '25', '21',
#         '27', '12', '20', '21', '31', '11', '20', '3', '5'], dtype=object),
#  array([datetime.datetime(2015, 8, 29, 0, 0), 'Tottenham Hotspur',
#         'Everton', '50.5', '49.5', '119', '90', '150', '118', '0', '0', '5',
#         '1', '10', '4', '0', '0', '18', '6', '25', '17', '33', '22', '14',
#         '15', '20', '25', '13', '6', '1', '6'], dtype=object),
#  array([datetime.datetime(2015, 8, 24, 0, 0), 'Arsenal', 'Liverpool',
#         '66.0', '34.0', '231', '82', '290', '132', '0', '0', '2', '6', '10',
#         '11', '0', '0', '15', '12', '23', '25', '32', '39', '22', '27',
#         '27', '41', '27', '22', '3', '5'], dtype=object),
#  array([datetime.datetime(2015, 8, 23, 0, 0), 'West Bromwich Albion',
#         'Chelsea', '43.6', '56.4', '93', '121', '132', '168', '2', '3', '2',
#         '0', '8', '10', '2', '2', '12', '13', '13', '9', '20', '15', '10',
#         '19', '16', '26', '15', '9', '3', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 23, 0, 0), 'Everton', 'Manchester City',
#         '45.3', '54.7', '80', '154', '116', '194', '0', '2', '0', '4', '5',
#         '9', '0', '2', '8', '13', '21', '17', '31', '33', '16', '17', '28',
#         '22', '11', '17', '4', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 23, 0, 0), 'Watford', 'Southampton',
#         '51.5', '48.5', '94', '86', '151', '131', '0', '0', '0', '4', '6',
#         '8', '0', '0', '10', '12', '16', '15', '21', '26', '15', '24', '16',
#         '39', '14', '28', '0', '6'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'Manchester United',
#         'Newcastle United', '69.6', '30.4', '203', '46', '248', '80', '0',
#         '0', '3', '0', '9', '5', '0', '0', '15', '6', '17', '20', '27',
#         '34', '19', '32', '25', '45', '15', '20', '3', '9'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'Crystal Palace',
#         'Aston Villa', '50.3', '49.7', '97', '78', '136', '106', '2', '0',
#         '3', '2', '10', '6', '2', '0', '14', '9', '15', '13', '24', '19',
#         '15', '22', '21', '27', '11', '18', '3', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'West Ham United',
#         'Bournemouth', '45.6', '54.4', '71', '103', '131', '162', '3', '4',
#         '1', '2', '6', '9', '1', '2', '7', '11', '20', '17', '32', '24',
#         '11', '29', '16', '38', '27', '10', '2', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'Norwich City', 'Stoke City',
#         '42.5', '57.5', '79', '67', '120', '99', '1', '1', '5', '0', '10',
#         '4', '1', '1', '14', '5', '22', '15', '27', '21', '19', '12', '22',
#         '19', '10', '15', '1', '5'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'Sunderland', 'Swansea City',
#         '39.3', '60.7', '36', '82', '75', '117', '1', '1', '1', '3', '4',
#         '10', '1', '1', '6', '18', '25', '9', '35', '21', '14', '23', '18',
#         '31', '14', '20', '4', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 22, 0, 0), 'Leicester City',
#         'Tottenham Hotspur', '33.8', '66.2', '72', '126', '103', '164', '1',
#         '1', '1', '2', '7', '12', '1', '1', '8', '16', '19', '11', '30',
#         '22', '12', '34', '21', '43', '21', '8', '4', '6'], dtype=object),
#  array([datetime.datetime(2015, 8, 17, 0, 0), 'Liverpool', 'Bournemouth',
#         '55.4', '44.6', '101', '90', '149', '126', '1', '0', '1', '1', '8',
#         '8', '1', '0', '11', '13', '24', '22', '36', '34', '28', '20', '39',
#         '25', '16', '14', '5', '5'], dtype=object),
#  array([datetime.datetime(2015, 8, 16, 0, 0), 'Crystal Palace', 'Arsenal',
#         '40.7', '59.3', '82', '171', '123', '221', '0', '1', '2', '4', '6',
#         '16', '1', '1', '7', '16', '18', '27', '25', '36', '23', '31', '40',
#         '38', '19', '12', '8', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 16, 0, 0), 'Manchester City', 'Chelsea',
#         '49.3', '50.7', '126', '147', '157', '190', '2', '0', '4', '3',
#         '11', '5', '3', '0', '17', '7', '17', '20', '29', '34', '18', '19',
#         '26', '29', '5', '15', '3', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'Southampton', 'Everton',
#         '55.4', '44.6', '114', '93', '159', '129', '0', '2', '2', '1', '14',
#         '7', '0', '3', '13', '7', '18', '14', '24', '19', '15', '28', '22',
#         '39', '13', '16', '4', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'West Ham United',
#         'Leicester City', '70.4', '29.6', '108', '56', '156', '99', '1',
#         '2', '2', '3', '7', '7', '1', '1', '8', '7', '15', '25', '21', '34',
#         '17', '27', '23', '45', '4', '16', '2', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'Swansea City',
#         'Newcastle United', '66.1', '33.9', '125', '31', '158', '59', '2',
#         '0', '1', '1', '7', '1', '2', '0', '18', '2', '19', '19', '26',
#         '26', '11', '13', '18', '20', '16', '13', '0', '7'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'Sunderland', 'Norwich City',
#         '43.9', '56.1', '35', '144', '84', '199', '1', '3', '0', '1', '3',
#         '9', '0', '2', '4', '11', '31', '15', '46', '21', '15', '33', '24',
#         '37', '17', '11', '8', '1'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'Tottenham Hotspur',
#         'Stoke City', '52.9', '47.1', '58', '88', '103', '132', '2', '2',
#         '3', '4', '7', '11', '2', '1', '8', '11', '16', '19', '25', '28',
#         '11', '12', '17', '16', '16', '16', '2', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 15, 0, 0), 'Watford',
#         'West Bromwich Albion', '64.7', '35.3', '133', '49', '182', '88',
#         '0', '0', '1', '0', '7', '4', '0', '0', '14', '4', '15', '24', '19',
#         '33', '19', '31', '24', '45', '21', '20', '1', '2'], dtype=object),
#  array([datetime.datetime(2015, 8, 14, 0, 0), 'Aston Villa',
#         'Manchester United', '45.5', '54.5', '52', '105', '97', '143', '0',
#         '1', '1', '0', '4', '5', '0', '1', '4', '8', '22', '24', '27', '36',
#         '7', '31', '14', '38', '19', '21', '3', '1'], dtype=object),
#  array([datetime.datetime(2015, 8, 10, 0, 0), 'West Bromwich Albion',
#         'Manchester City', '31.1', '68.9', '71', '212', '98', '247', '0',
#         '2', '1', '3', '4', '11', '0', '2', '6', '14', '17', '10', '24',
#         '17', '15', '14', '24', '22', '16', '14', '10', '1'], dtype=object),
#  array([datetime.datetime(2015, 8, 9, 0, 0), 'Newcastle United',
#         'Southampton', '55.9', '44.1', '92', '72', '134', '115', '2', '2',
#         '0', '2', '6', '10', '1', '2', '7', '12', '13', '18', '20', '28',
#         '20', '23', '25', '40', '15', '34', '3', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 9, 0, 0), 'Arsenal', 'West Ham United',
#         '62.1', '37.9', '179', '46', '213', '96', '0', '1', '5', '1', '15',
#         '4', '0', '1', '16', '7', '12', '21', '24', '43', '12', '20', '20',
#         '30', '18', '12', '2', '8'], dtype=object),
#  array([datetime.datetime(2015, 8, 9, 0, 0), 'Stoke City', 'Liverpool',
#         '46.8', '53.2', '51', '82', '96', '132', '0', '0', '0', '2', '4',
#         '4', '0', '1', '4', '5', '25', '19', '35', '24', '12', '23', '16',
#         '36', '13', '13', '4', '2'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Manchester United',
#         'Tottenham Hotspur', '50.1', '49.9', '106', '52', '143', '98', '0',
#         '0', '1', '3', '5', '8', '0', '0', '4', '7', '22', '26', '28', '28',
#         '24', '13', '30', '20', '19', '29', '3', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Bournemouth', 'Aston Villa',
#         '59.3', '40.7', '134', '73', '184', '102', '0', '1', '2', '1', '8',
#         '4', '0', '1', '9', '3', '14', '24', '24', '27', '13', '30', '20',
#         '44', '16', '28', '2', '2'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Norwich City',
#         'Crystal Palace', '62.9', '37.1', '97', '81', '141', '113', '0',
#         '3', '2', '2', '6', '8', '1', '3', '10', '10', '20', '14', '30',
#         '17', '23', '28', '30', '35', '7', '12', '2', '3'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Leicester City', 'Sunderland',
#         '44.3', '55.7', '67', '57', '112', '91', '4', '2', '3', '3', '15',
#         '7', '2', '2', '18', '9', '19', '19', '24', '25', '19', '13', '22',
#         '17', '18', '11', '2', '4'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Everton', 'Watford', '66.7',
#         '33.3', '128', '71', '195', '117', '1', '2', '3', '1', '6', '5',
#         '2', '1', '8', '8', '14', '25', '25', '31', '20', '42', '27', '55',
#         '11', '37', '3', '2'], dtype=object),
#  array([datetime.datetime(2015, 8, 8, 0, 0), 'Chelsea', 'Swansea City',
#         '52.5', '47.5', '121', '75', '174', '110', '0', '2', '2', '4', '6',
#         '12', '0', '0', '8', '12', '16', '22', '29', '36', '10', '23', '17',
#         '33', '13', '12', '5', '2'], dtype=object)]

# %%
def getTempMatch():
    
    tot_links = ['/statszone/8-2015/matches/803167',
                 '/statszone/8-2015/matches/803170',
                 '/statszone/8-2015/matches/803168']
                 
    baseurl = 'http://www.fourfourtwo.com'
    dates = []
    h_names = []
    a_names =[]
    posses = []
    h_atks = []
    a_atks=[]
    h_ins=[]
    a_ins=[]
    print("start working")
    for indx, link in enumerate(tot_links):
        clear_output()
        print("task: {}/{}".format(indx,len(tot_links)))
        sys.stdout.flush()
        try:
            date ,homeName, awayName ,poss, h_atkThird, a_atkThird, h_interception,a_interception = grapMatchInfo(baseurl + link)
            print("{} {} {}".format(date,homeName,awayName))
            dates.append(date)
            h_names.append(homeName)
            a_names.append(awayName)
            posses.append(poss)
            h_atks.append(h_atkThird)
            a_atks.append(a_atkThird)
            h_ins.append(h_interception)
            a_ins.append(a_interception)
        except Exception as e:
            print(e)
            print("error")
            break
            
        print("finish")
    
 
    return dates,h_names,a_names,posses,h_atks,a_atks,h_ins,a_ins

# %%
df = pd.DataFrame(results, columns=n_header)

# %%
df.sort(columns="Date",ascending=False)
# Out:
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#           Date              HomeTeam              AwayTeam H_poss A_poss  \
# 0   2016-04-02           Aston Villa               Chelsea   41.4   58.6
# 5   2016-04-02               Arsenal               Watford   69.1   30.9
# 7   2016-04-02             Liverpool     Tottenham Hotspur   42.2   57.8
# 6   2016-04-02            Sunderland  West Bromwich Albion   56.5   43.5
# 1   2016-04-02       West Ham United        Crystal Palace   66.4   33.6
# 4   2016-04-02            Stoke City          Swansea City   47.2   52.8
# 3   2016-04-02          Norwich City      Newcastle United   41.3   58.7
# 2   2016-04-02           Bournemouth       Manchester City   45.8   54.2
# 8   2016-03-20           Southampton             Liverpool   49.2   50.8
# 9   2016-03-20      Newcastle United            Sunderland   59.9   40.1
# 11  2016-03-20       Manchester City     Manchester United   54.5   45.5
# 10  2016-03-20     Tottenham Hotspur           Bournemouth   62.8   37.2
# 12  2016-03-19               Everton               Arsenal   53.9   46.1
# 13  2016-03-19        Crystal Palace        Leicester City   55.9   44.1
# 14  2016-03-19  West Bromwich Albion          Norwich City   50.1   49.9
# 15  2016-03-19               Watford            Stoke City   52.1   47.9
# 16  2016-03-19               Chelsea       West Ham United   59.4   40.6
# 17  2016-03-19          Swansea City           Aston Villa   53.8   46.2
# 18  2016-03-14        Leicester City      Newcastle United   49.9   50.1
# 19  2016-03-13           Aston Villa     Tottenham Hotspur   37.8   62.2
# 22  2016-03-12           Bournemouth          Swansea City   44.0   56.0
# 20  2016-03-12          Norwich City       Manchester City   33.9   66.1
# 21  2016-03-12            Stoke City           Southampton   60.6   39.4
# 24  2016-03-06  West Bromwich Albion     Manchester United   46.6   53.4
# 23  2016-03-06        Crystal Palace             Liverpool   38.5   61.5
# 29  2016-03-05               Chelsea            Stoke City   48.7   51.3
# 32  2016-03-05               Watford        Leicester City   50.2   49.8
# 30  2016-03-05           Southampton            Sunderland   65.1   34.9
# 31  2016-03-05               Everton       West Ham United   41.5   58.5
# 28  2016-03-05          Swansea City          Norwich City   55.8   44.2
# ..         ...                   ...                   ...    ...    ...
# 281 2015-08-24               Arsenal             Liverpool   66.0   34.0
# 282 2015-08-23  West Bromwich Albion               Chelsea   43.6   56.4
# 283 2015-08-23               Everton       Manchester City   45.3   54.7
# 284 2015-08-23               Watford           Southampton   51.5   48.5
# 288 2015-08-22          Norwich City            Stoke City   42.5   57.5
# 290 2015-08-22        Leicester City     Tottenham Hotspur   33.8   66.2
# 289 2015-08-22            Sunderland          Swansea City   39.3   60.7
# 287 2015-08-22       West Ham United           Bournemouth   45.6   54.4
# 286 2015-08-22        Crystal Palace           Aston Villa   50.3   49.7
# 285 2015-08-22     Manchester United      Newcastle United   69.6   30.4
# 291 2015-08-17             Liverpool           Bournemouth   55.4   44.6
# 292 2015-08-16        Crystal Palace               Arsenal   40.7   59.3
# 293 2015-08-16       Manchester City               Chelsea   49.3   50.7
# 297 2015-08-15            Sunderland          Norwich City   43.9   56.1
# 299 2015-08-15               Watford  West Bromwich Albion   64.7   35.3
# 298 2015-08-15     Tottenham Hotspur            Stoke City   52.9   47.1
# 294 2015-08-15           Southampton               Everton   55.4   44.6
# 296 2015-08-15          Swansea City      Newcastle United   66.1   33.9
# 295 2015-08-15       West Ham United        Leicester City   70.4   29.6
# 300 2015-08-14           Aston Villa     Manchester United   45.5   54.5
# 301 2015-08-10  West Bromwich Albion       Manchester City   31.1   68.9
# 302 2015-08-09      Newcastle United           Southampton   55.9   44.1
# 303 2015-08-09               Arsenal       West Ham United   62.1   37.9
# 304 2015-08-09            Stoke City             Liverpool   46.8   53.2
# 305 2015-08-08     Manchester United     Tottenham Hotspur   50.1   49.9
# 306 2015-08-08           Bournemouth           Aston Villa   59.3   40.7
# 307 2015-08-08          Norwich City        Crystal Palace   62.9   37.1
# 308 2015-08-08        Leicester City            Sunderland   44.3   55.7
# 309 2015-08-08               Everton               Watford   66.7   33.3
# 310 2015-08-08               Chelsea          Swansea City   52.5   47.5
#
#     H_atk_3rd A_atk_3rd H_atk_3rd_tot A_atk_3rd_tot H_red_goal   ...     \
# 0         101        83           136           119          0   ...
# 5         238        56           284            99          4   ...
# 7          77        89           116           146          1   ...
# 6         101        51           159           105          0   ...
# 1          75        41           118            81          1   ...
# 4          75        86           125           125          1   ...
# 3          81        93           132           131          3   ...
# 2          77       145           110           187          0   ...
# 8         114       111           163           164          2   ...
# 9          74        72           116           124          1   ...
# 11        134        68           175           105          0   ...
# 10        108        49           150            78          3   ...
# 12         85       126           138           163          0   ...
# 13         72        98           123           154          0   ...
# 14         89        72           158           140          0   ...
# 15         88        78           158           126          1   ...
# 16        103        58           150            98          1   ...
# 17         83       100           112           149          1   ...
# 18         95        83           133           136          1   ...
# 19         72       107           125           146          0   ...
# 22         68        84           111           129          3   ...
# 20         67       202           118           255          0   ...
# 21        109        67           163           108          1   ...
# 24         87        97           152           141          1   ...
# 23         75       143           129           180          1   ...
# 29        115        93           155           139          0   ...
# 32         65        85           108           136          0   ...
# 30        120        51           170           105          1   ...
# 31         64       131           101           159          2   ...
# 28         85        93           128           146          1   ...
# ..        ...       ...           ...           ...        ...   ...
# 281       231        82           290           132          0   ...
# 282        93       121           132           168          2   ...
# 283        80       154           116           194          0   ...
# 284        94        86           151           131          0   ...
# 288        79        67           120            99          1   ...
# 290        72       126           103           164          1   ...
# 289        36        82            75           117          1   ...
# 287        71       103           131           162          3   ...
# 286        97        78           136           106          2   ...
# 285       203        46           248            80          0   ...
# 291       101        90           149           126          1   ...
# 292        82       171           123           221          0   ...
# 293       126       147           157           190          2   ...
# 297        35       144            84           199          1   ...
# 299       133        49           182            88          0   ...
# 298        58        88           103           132          2   ...
# 294       114        93           159           129          0   ...
# 296       125        31           158            59          2   ...
# 295       108        56           156            99          1   ...
# 300        52       105            97           143          0   ...
# 301        71       212            98           247          0   ...
# 302        92        72           134           115          2   ...
# 303       179        46           213            96          0   ...
# 304        51        82            96           132          0   ...
# 305       106        52           143            98          0   ...
# 306       134        73           184           102          0   ...
# 307        97        81           141           113          0   ...
# 308        67        57           112            91          4   ...
# 309       128        71           195           117          1   ...
# 310       121        75           174           110          0   ...
#
#     H_tackle_tot A_tackle_tot H_successful_clearance A_successful_clearance  \
# 0             32           31                      9                     14
# 5             17           27                     21                     20
# 7             48           24                     22                     22
# 6             24           24                     37                     23
# 1             21           34                     25                     17
# 4             24           19                     18                     18
# 3             16           17                     20                     22
# 2             32           38                     15                     10
# 8             32           20                     23                     21
# 9             35           40                     25                     23
# 11            35           46                     22                     16
# 10            40           26                     18                     26
# 12            42           29                     11                     23
# 13            28           46                     18                     39
# 14            28           26                     33                     41
# 15            27           32                      9                     29
# 16            23           35                     13                     23
# 17            33           34                     42                     18
# 18            35           32                     16                     24
# 19            31           32                     18                     26
# 22            31           38                     23                     20
# 20            38           24                     43                     32
# 21            30           32                     11                     36
# 24            33           35                     19                     11
# 23            21           32                     14                     23
# 29            36           32                     13                     15
# 32            39           39                     21                     23
# 30            19           22                     33                     29
# 31            26           33                     28                     19
# 28            29           23                     32                     30
# ..           ...          ...                    ...                    ...
# 281           32           39                     22                     27
# 282           20           15                     10                     19
# 283           31           33                     16                     17
# 284           21           26                     15                     24
# 288           27           21                     19                     12
# 290           30           22                     12                     34
# 289           35           21                     14                     23
# 287           32           24                     11                     29
# 286           24           19                     15                     22
# 285           27           34                     19                     32
# 291           36           34                     28                     20
# 292           25           36                     23                     31
# 293           29           34                     18                     19
# 297           46           21                     15                     33
# 299           19           33                     19                     31
# 298           25           28                     11                     12
# 294           24           19                     15                     28
# 296           26           26                     11                     13
# 295           21           34                     17                     27
# 300           27           36                      7                     31
# 301           24           17                     15                     14
# 302           20           28                     20                     23
# 303           24           43                     12                     20
# 304           35           24                     12                     23
# 305           28           28                     24                     13
# 306           24           27                     13                     30
# 307           30           17                     23                     28
# 308           24           25                     19                     13
# 309           25           31                     20                     42
# 310           29           36                     10                     23
#
#     H_clearance_tot A_clearance_tot H_interceptions A_interceptions H_blocks  \
# 0                15              23              21               8        0
# 5                30              27              25              19        2
# 7                29              34              22              20        6
# 6                48              36              14              19        1
# 1                34              23               9              14        3
# 4                26              26              18              16        4
# 3                31              33               5              12        1
# 2                20              16              17              15        0
# 8                33              26              22              12        4
# 9                31              38               9               6        3
# 11               30              25              24              17        1
# 10               29              31              15              17        0
# 12               15              38              17              30        4
# 13               32              52              19              21        2
# 14               38              53              24               6        2
# 15               20              45              18              11        1
# 16               19              30              15              18        5
# 17               53              28              25              32        6
# 18               21              30              24              16        5
# 19               28              38              29              14        5
# 22               27              26              25              20        1
# 20               60              40              13              14        7
# 21               19              47              10              10        2
# 24               31              21              21              17        3
# 23               19              36              20              12        8
# 29               20              22              17              18        4
# 32               25              28              23              20        1
# 30               45              43              14              14        4
# 31               35              29              15              16        5
# 28               39              40              20              23        2
# ..              ...             ...             ...             ...      ...
# 281              27              41              27              22        3
# 282              16              26              15               9        3
# 283              28              22              11              17        4
# 284              16              39              14              28        0
# 288              22              19              10              15        1
# 290              21              43              21               8        4
# 289              18              31              14              20        4
# 287              16              38              27              10        2
# 286              21              27              11              18        3
# 285              25              45              15              20        3
# 291              39              25              16              14        5
# 292              40              38              19              12        8
# 293              26              29               5              15        3
# 297              24              37              17              11        8
# 299              24              45              21              20        1
# 298              17              16              16              16        2
# 294              22              39              13              16        4
# 296              18              20              16              13        0
# 295              23              45               4              16        2
# 300              14              38              19              21        3
# 301              24              22              16              14       10
# 302              25              40              15              34        3
# 303              20              30              18              12        2
# 304              16              36              13              13        4
# 305              30              20              19              29        3
# 306              20              44              16              28        2
# 307              30              35               7              12        2
# 308              22              17              18              11        2
# 309              27              55              11              37        3
# 310              17              33              13              12        5
#
#     A_blocks
# 0          4
# 5          3
# 7          6
# 6          6
# 1          6
# 4          2
# 3          2
# 2          3
# 8          5
# 9          3
# 11         5
# 10         2
# 12         1
# 13         2
# 14         3
# 15         1
# 16         6
# 17         3
# 18         6
# 19         4
# 22         2
# 20         1
# 21         3
# 24         3
# 23         4
# 29         4
# 32         3
# 30         7
# 31         5
# 28         2
# ..       ...
# 281        5
# 282        3
# 283        4
# 284        6
# 288        5
# 290        6
# 289        3
# 287        3
# 286        3
# 285        9
# 291        5
# 292        3
# 293        4
# 297        1
# 299        2
# 298        4
# 294        4
# 296        7
# 295        3
# 300        1
# 301        1
# 302        3
# 303        8
# 304        2
# 305        4
# 306        2
# 307        3
# 308        4
# 309        2
# 310        2
#
# [311 rows x 31 columns]

# %%
df.to_csv('dataSet/match2015.csv',index=False)
