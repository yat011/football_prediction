# %%
import numpy as np
try:
    from IPython.core.display import clear_output
    have_ipython = True
except ImportError:
    have_ipython = False
import sys
import datetime
# %matplotlib inline
import matplotlib.pyplot as plt

def plotCurve(train_mean, train_std,test_mean,test_std,sizes):
    plt.plot(sizes, train_mean, 
            color='blue', marker='o', 
            markersize=5, 
            label='training accuracy')
    plt.fill_between(sizes, 
                  train_mean + train_std,
                   train_mean - train_std, alpha=0.15, color='blue')

    plt.plot(sizes, test_mean, 
              color='green', linestyle='--', 
              marker='s', markersize=5, 
             label='validation accuracy')
    plt.fill_between(sizes, 
                      test_mean + test_std,
                     test_mean - test_std, 
                    alpha=0.15, color='green')
    plt.xlabel('x_range')
    plt.ylabel('Accuracy')
    plt.show()
def likehoodScore(proba,y):
    return np.sum(proba * y)/proba.shape[0]

def firstNScore(n, pred, y):
    backup = np.array(pred, copy =True)
    for r in range(pred.shape[0]):
        row = backup[r]
        s = np.sort(row)
        for c in range(pred.shape[1]):
            temp = backup[r][c]
            backup[r][c] = False
            for j in range(1,n+1):
                if temp == s[-j]:
                    backup[r][c] = True
                    break
    res = np.sum(np.logical_and(backup,y))/pred.shape[0]
    return res               

def oneHotDecode(self, X_sample):
    result=None
    fiPos = 0
    colIndex = 0
    while colIndex < X_sample.shape[1]:
        if fiPos < len(self.ohe.n_values_) and colIndex == self.ohe.feature_indices_[fiPos]:                
            start = self.ohe.feature_indices_[fiPos]
            end_ = start+ self.ohe.n_values_[fiPos]
            #print("start{} end{}".format(start,end_))
            classes = np.argmax(X_sample[:,start:end_],axis=1).reshape(X_sample.shape[0],1)
            if result is None:
                result = classes
            else:
                result=np.hstack([result,classes])
            colIndex = end_
            fiPos = fiPos +1
        else:
            if result is None:
                result = X_sample[:,colIndex:colIndex+1]
            else:
                result=np.hstack([result, X_sample[:,colIndex:colIndex+1]])
            colIndex = colIndex +1
        
    return result 
def convertToDate(dayStamps):
    res = [] 
    for v in dayStamps:
        res.append(datetime.datetime.fromtimestamp(v*24*60*60))
    return res

#TODO confusion matrix ,e.g. 100 - 90 % precision
def _precisionClassify(df,proba, wins, c =0 ):
    for indx, v in enumerate(proba):
        row = 0
        col = 0
        if wins[indx] == c:
            col = 0
        else:
            col =1
        if v <0.2:
            row =6 
        elif v < 0.3 and  v >=0.2:
            row =5 
        elif v < 0.4 and v >= 0.3:
            row = 4 
        elif v < 0.5 and v >= 0.4:
            row = 3 
        elif v < 0.6 and v >= 0.5:
            row = 2 
        elif v < 0.8 and v >= 0.6:
            row = 1
        df.iloc[row,col] = df.iloc[row,col]+1 
    df[df.columns[2]] = df[df.columns[0]] /(df[df.columns[1]] + df[df.columns[0]])
    return df
    

def precisionMatrix(proba, y):
    rowHeader = ['>80','60-80','50-60','40-50','30-40','20-30','<20']
    df = pd.DataFrame(np.zeros(shape=(7,3)),index=rowHeader, columns=['h_Correct', 'h_Wrong','h_Precent'])
    hproba = proba[:,0]
    wins = np.argmax(y,axis=1)
    df = _precisionClassify(df,hproba,wins)
    temp = pd.DataFrame(np.zeros(shape=(7,3)),index=rowHeader, columns=['d_Correct', 'd_Wrong','d_Precent'])
    dproba = proba[:,1]
    df = df.join(_precisionClassify(temp,dproba,wins,c=1))
    temp = pd.DataFrame(np.zeros(shape=(7,3)),index=rowHeader, columns=['a_Correct', 'a_Wrong','a_Precent'])
    aproba = proba[:,2]
    df = df.join(_precisionClassify(temp,aproba,wins,c=2))
    return df
       
from datetime import date, timedelta
from sklearn.metrics import precision_score


def futureTest(mlp, X,y,numOfWeek = 10,verbose=False):
    decoded = oneHotDecode(c, X)
    dates = convertToDate(X[:,c.dateColumn])
    dates = [d - timedelta(days=2) for d in dates]    
    weeks  = [ v.isocalendar()[1] for v in dates]
    thisWeek = weeks[-1]
    start = -1
    last = X.shape[0]
    index = -1
    w = 0
    sum_proba =None 
    sum_y =None
    sum_train_proba=None
    sum_train_y=None
    while w < numOfWeek:
        if thisWeek != weeks[index]:
            start = X.shape[0] +index+1
            X_train = X[0:start, :]
            X_test = X[start:last,:]
            y_train = y[0:start,:]
            y_test = y[start:last,:]
            mlp.fit(X_train,y_train)
            decoded = oneHotDecode(c,X_test)
            home = np.array([c.inverseTeamMapping(decoded[:,0])]).reshape(X_test.shape[0],1)
            away = np.array([c.inverseTeamMapping(decoded[:,1])]).reshape(X_test.shape[0],1)
            stack = np.hstack([home,away])
            proba = mlp.predict_proba(X_test)
            train_proba =mlp.predict_proba(X_train)
            errorIndx = np.argmax(proba,axis=1) != np.argmax(y_test,axis=1)
            if sum_proba is None:
                sum_proba = proba
                sum_y = y_test
                sum_train_proba = train_proba
                sum_train_y = y_train
            else:
                sum_proba = np.vstack([sum_proba,proba])
                sum_y = np.vstack([sum_y,y_test])
                sum_train_proba = np.vstack([sum_train_proba, train_proba])
                sum_train_y= np.vstack([sum_train_y, y_train])
            if verbose == True:
                print("week{}".format(w))
                print("numOftest {} , score {}".format(X_test.shape[0],mlp.score(X_test,y_test)))
                print(np.hstack([stack[errorIndx],proba[errorIndx],y_test[errorIndx]]))
                print("first2 : {}",firstNScore(2,proba,y_test))
            last = start
            thisWeek = weeks[index]
            w = w+1
        index = index -1
        
    print("summary")
    print("score:")
    score = firstNScore(1,sum_proba,sum_y)
    print(score)
    print("2like")
    like2 = firstNScore(2,sum_proba,sum_y)
    print(precisionMatrix(sum_proba,sum_y))
    y_true= np.argmax(sum_y,axis=1)
    y_pred = np.argmax(sum_proba,axis=1)
    print("sum precision:{}".format(precision_score(y_true,y_pred,average=None)))
    return firstNScore(1,sum_train_proba,sum_train_y), score, like2

# %%
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
class FootballDataHelper:
    def __init__ (self, recentNum=5):
        self.win_mapping = {'H':0, 'D':1,'A':2}
        self.recentNum = recentNum
        self.df = None
        self.teamsData={}
        self.session = 0
        #self.hiddensCount = 2
       
        
    def readFootBallData(self,filename): 
        df = pd.read_csv(filename)
        #df = df.drop(df.columns[range(23,df.shape[1])], axis=1)
        #df = df.drop("Div",axis=1)
        df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)
        df['session'] = pd.Series(np.ones(shape=(df.shape[0],))*self.session, index=df.index)
        self.session = self.session +1
        #df= df.drop('Referee', 1)
        #self.team = df['HomeTeam'].drop_duplicates()
        if self.df is None:
            self.df = df
        else:
            self.df = pd.concat([self.df,df])
            
        self.df = self.df.reset_index(drop=True)
        teams = self.df['HomeTeam'].drop_duplicates()
        teamMap = {}
        for index , v in enumerate(teams):
            teamMap[v] = index
        self.teamsMap = teamMap
        referees = self.df['Referee'].drop_duplicates()
        refereesMap = {}
        for index , v in enumerate(referees):
            refereesMap[v] = index+1

        self.refereesMap = refereesMap
 
    def getTeam(self,dataFrame, teamName):       
        return dataFrame[(dataFrame["HomeTeam"] == teamName) | (dataFrame["AwayTeam"] == teamName)]
 
        
    def previousRecords(self,team, date , recentNum):
        prev = team[( team["Date"] < date)]
        
        if prev.shape[0] < recentNum :
            #print("less than min Num")
            return None
        else:
            return prev.iloc[-recentNum:]
    def readPredict (self, filename):
        df = pd.read_csv(filename)
        df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)

        return df
    
    
  
    def inverseTeamMapping (self, col):
        inverseMap ={}
        for name in self.teamsMap.keys():        
            inverseMap[self.teamsMap[name]] = name
        res =[]
        for idex, v in enumerate(col):
            res.append(inverseMap[v])
        return res


    def readTeamMatch(self, teamName):
        df = pd.read_csv('teams/'+teamName+'.csv')
        df['1'] = pd.to_datetime(df['1'],yearfirst=True)
        #df['1']= (pd.to_numeric(df['1'])/1e9/24/60/60)
        self.teamsData[teamName]=df.sort(['1'],ascending=[False])
        self.teamsById[self.teamsMap[teamName]]=self.teamsData[teamName]
    
    def commonMapping(self, X):
        X['HomeTeam'] = X['HomeTeam'].map(self.teamsMap)
        X['AwayTeam'] = X['AwayTeam'].map(self.teamsMap)
        X['Referee']=X['Referee'].map(self.refereesMap).fillna(0)
        X['HTR'] = X['HTR'].map(self.win_mapping)
        X['FTR'] = X['FTR'].map(self.win_mapping)
        return X
    def initData(self, X, target,encode):
        X  = X.sort_values(by="Date")
        isInput = False
        if target is None:
            target =X      
        else:
            if self.ohe is None:
                raise Exception("Not yet get train data")
            isInput = True
            if encode == True:
                target = self.commonMapping(target)
        y=None
        if encode == True:    
            X =self.commonMapping(X)
            y = []
            for v in target['FTR']:
                y.append(range(3)==v)
        else:
            y = target['FTR'].values
        target_date = (pd.to_numeric(target['Date'])/1e9/24/60/60).values
        return isInput, X,y, target, target_date
   
    def aggregate(self,recents,nonExpand,isInput,encode):
        res =None
        if encode == True:
            if isInput==False:
                self.ohe = OneHotEncoder(categorical_features='all')
                self.ohe.fit(recents)
            res = self.ohe.transform(recents).toarray()
        else:
            res = np.array(recents)
        self.dateColumn = res.shape[1]
        res = np.hstack([res,nonExpand])
        return res
    def _extractFromPrevious(self, prev,teamName):
        homes =  prev['HomeTeam'].values
        ftr = prev['FTR'].values
        homeGoals = prev['FTHG'].values
        awayGoals = prev['FTAG'].values
        homeYellow = prev['HY'].values
        awayYellow = prev['AY'].values
        homeRed = prev['HR'].values
        awayRed =prev['AR'].values
        rankdiffs = (prev['HAccP'].values+1) / (prev['AAccP'].values +1)
        scored = 0
        conceded = 0
        wins = 0
        draw =0
        lose = 0
        yellowCards = 0
        redCards = 0
        moral  = 0
        for i in range(ftr.shape[0]):
            if homes[i] == teamName:
                if ftr[i] == 'H' or ftr[i] == 0:
                    wins = wins+1
                    moral = moral + 3 * 1/rankdiffs[i]
                elif ftr[i] == 'A' or ftr[i] == 2:
                    lose = lose+1
                    moral = moral - 3 * rankdiffs[i]
                else:
                    draw = draw +1
                    moral = moral + 1 * 1/rankdiffs[i]
                scored = scored + homeGoals[i]
                conceded = conceded + awayGoals[i]
                yellowCards = yellowCards + homeYellow[i]
                redCards = redCards + homeRed[i]
                
                
            else:
                if ftr[i] == 'A' or ftr[i] == 2:
                    wins = wins+1
                    moral = moral + 3 * rankdiffs[i]
                elif ftr[i] == 'H' or ftr[i] == 0:
                    lose = lose+1
                    moral = moral - 3 * 1/rankdiffs[i]
                else:
                    draw = draw +1
                    moral = moral + 1 * rankdiffs[i]
                scored = scored + awayGoals[i]
                conceded = conceded + homeGoals[i]
                yellowCards = yellowCards + awayYellow[i]
                redCards = redCards + awayRed[i]
                              
        
        temp = np.array([wins,draw,lose,scored-conceded])
        return temp,moral
    def _getH7RecentMatches(self,x, X,teamName,recentNum,isHome):
        team = self.getTeam(X,teamName)
        homeOrAway = None
        if isHome == True:
            homeOrAway = X[X['HomeTeam']==teamName]
        else:
            homeOrAway = X[X['AwayTeam']==teamName]
        prev = self.previousRecords(team,x['Date'],recentNum)
        prevHomeOrAway = self.previousRecords(homeOrAway,x['Date'],recentNum)
        if prev is None or prevHomeOrAway is None:
            return None,None
        res1,moral= self._extractFromPrevious(prev,teamName)
        #res2= self._extractFromPrevious(prevHomeOrAway,teamName)
        
        return res1,moral
    def getH7(self,removeInsufficient=False, target=None,encode = True):
        #Simple recent win,draw, lose 
        df = self.df
        if removeInsufficient == True:
            df= df[df['Sufficient'] == 1]
        
        
        isInput, X, y,target, target_date = self.initData(df,target,encode)
        resy=[]
        resx=[]
        print("start format")
        recents = X[['HomeTeam','AwayTeam','Referee']].values
        haccp = X['HAccP'].values.reshape(X.shape[0],1)
        aaccp = X['AAccP'].values.reshape(X.shape[0],1)
        homeRecent = np.hstack([X[['HWin','HDraw','HLose']].values,
                                (X['HScore'].values - X['HConcede'].values).reshape(X.shape[0],1)])
        awayRecent = np.hstack([X[['AWin','ADraw','ALose']].values,
                                (X['AScore'].values - X['AConcede'].values).reshape(X.shape[0],1)])
        homeMoral = X['HMoral'].values.reshape(X.shape[0],1)
        awayMoral = X['AMoral'].values.reshape(X.shape[0],1)
        target_date = target_date.reshape(X.shape[0],1)
        nonExpand =np.hstack([target_date,X[['HRestDay','ARestDay']].values,haccp-aaccp,(haccp+1)/(aaccp+1),
                                homeRecent,awayRecent, homeMoral - awayMoral + haccp - aaccp])
        res = self.aggregate(recents,nonExpand,isInput,encode)
        print("finish")
        sys.stdout.flush()
        return res, np.array(y)
    def _getRank(self,x, X,teamName,recentNum):
        team = self.getTeam(X,teamName)
        prev = team[team['Date'] < x['Date']].values      
        for i in range(recentNum):
            pass
    def initRanking(self, n = 20):
        defaultPt = 1
        df = self.df.sort(columns=["Date"],ascending=[False])
        df["HPoints"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["APoints"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HAccP"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["AAccP"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        hpoints= df["HPoints"].values
        apoints=df["APoints"].values
        ftr = df["FTR"].values
        for i in range(df.shape[0]):
            sys.stdout.write("\r progress {}".format(i))
            sys.stdout.flush()
            if ftr[i] == 'H':
                hpoints[i] = 3
                apoints[i] = 0
            elif ftr[i] == 'D':
                hpoints[i] = 1
                apoints[i] = 1
            else :
                hpoints[i] = 0
                apoints[i] = 3
        df["HPoints"]=hpoints
        df["APoints"]=apoints
        for teamName in self.teamsMap.keys():
            print(teamName)
            team  = df[(df['HomeTeam']==teamName) | (df['AwayTeam'] == teamName)] 
            hometeam = team['HomeTeam'].values
            hpoints = team['HPoints'].values
            apoints = team['APoints'].values
            psum = 0
            haccp = team['HAccP'].values
            aaccp = team['AAccP'].values
        
            for  i in range(0,n):
                if i < hpoints.shape[0]:
                    psum = psum + (hpoints[i] if hometeam[i] == teamName else apoints[i] ) 
                else:
                    psum = psum + defaultPt        
                    
        
            for j in range(team.shape[0]):

                if j+n < hpoints.shape[0]:                     
                    psum = psum + (hpoints[j+n] if hometeam[j+n]==teamName else apoints[j+n])
                else:
                    psum = psum + defaultPt 
                
                psum = psum - (hpoints[j] if hometeam[j]==teamName else apoints[j])
                    
                if hometeam[j] == teamName:
                    haccp[j]=psum
                else:
                    aaccp[j]=psum
            team['HAccp']=haccp
            team['AAccP']=aaccp
            #print(team[['HomeTeam','AwayTeam','HAccP','AAccP']])
            df.update(team)
            
            #print(df[['HomeTeam','AwayTeam','HAccP','AAccP']])
        self.df =df
        return df
    def initRecentData(self, n =5):
        df = self.df.sort(columns=["Date"],ascending=[False])
        df["HWin"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["AWin"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HDraw"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["ADraw"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HLose"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["ALose"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HScore"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["AScore"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HConcede"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["AConcede"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HMoral"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["AMoral"] = pd.Series(np.zeros(shape=(df.shape[0],)))
        df["HRestDay"]= pd.Series(np.zeros(shape=(df.shape[0],)))
        df["ARestDay"]= pd.Series(np.zeros(shape=(df.shape[0],)))
        
        df["Sufficient"] = pd.Series(np.ones(shape=(df.shape[0],)))
        
        hscore = df['FTHG'].values
        ascore = df['FTAG'].values
        hconcede = df ['FTAG'].values
        aconcede = df['FTHG'].values
        hwin = df['HWin'].values
        awin = df['AWin'].values
        hlose = df['HLose'].values
        alose = df['ALose'].values
        hdraw = df['HDraw'].values
        adraw = df['ADraw'].values
        hmoral = df['HMoral'].values
        amoral = df['AMoral'].values
        
        rankRatio = (df['HAccP'].values+1) / (df['AAccP'].values +1)
        
        
        ftr = df["FTR"].values
        for i in range(df.shape[0]):
            sys.stdout.write("\r progress {}".format(i))
            sys.stdout.flush()
            if ftr[i] == 'H':
                hwin[i] = 1
                hmoral[i] = 3 * 1/rankRatio[i]
                alose[i]= 1
                amoral[i] = -3 * 1/rankRatio[i]
            elif ftr[i] == 'D':
                hdraw[i] = 1
                hmoral[i] = 1 * 1/rankRatio[i]
                adraw[i] = 1
                amoral[i] = 1 * rankRatio[i]
            else :
                hlose[i] = 1
                hmoral[i] = -3*rankRatio[i]
                awin [i] = 1
                amoral[i] = 3*rankRatio[i]
        
        
        df["HWin"]=hwin
        df["AWin"]=awin
        df["HDraw"]=hdraw
        df["ADraw"]=adraw
        df["HLose"]=hlose
        df["ALose"]=alose
        df["HScore"]=hscore
        df["AScore"]=ascore
        df["HConcede"]=hconcede
        df["AConcede"]=aconcede
        df["HMoral"] = hmoral
        df["AMoral"] = amoral
        
        
        
        for teamName in self.teamsMap.keys():
            print(teamName)
            team  = df[(df['HomeTeam']==teamName) | (df['AwayTeam'] == teamName)] 
            hometeam = team['HomeTeam'].values
            hwin = team["HWin"].values
            awin = team["AWin"].values
            hlose= team["HLose"].values
            alose = team["ALose"].values
            hdraw = team["HDraw"].values
            adraw = team["ADraw"].values
            hscore = team["HScore"].values
            ascore = team["AScore"].values
            hconcede = team["HConcede"].values
            aconcede = team["AConcede"].values
            hmoral = team["HMoral"].values
            amoral = team["AMoral"].values
            hrestday = team["HRestDay"].values
            arestday = team["ARestDay"].values
            matchDate =team['Date'].values
            sufficient = team['Sufficient'].values
            teamMatchesDate = self.teamsData[teamName].sort('1',ascending=False)['1'].values
            
            restday = 0
            winsum =0 
            losesum=0
            drawsum=0
            scoresum =0
            concedesum=0
            moralsum = 0
            #print(team[['HomeTeam','AwayTeam','HWin']])
            for  i in range(0,n):
                if i < team.shape[0]:
                    scoresum = scoresum + (hscore[i] if hometeam[i] == teamName else ascore[i])
                    winsum = winsum + (hwin[i] if hometeam[i] == teamName else awin[i])
                    losesum= losesum + (hlose[i] if hometeam[i] == teamName else alose[i])
                    drawsum= drawsum + (hdraw[i] if hometeam[i] == teamName else adraw[i])
                    concedesum = concedesum+ (hconcede[i] if hometeam[i] == teamName else aconcede[i])
                    moralsum= moralsum+ (hmoral[i] if hometeam[i] == teamName else amoral[i])
                else:
                    # + 0
                    pass
            dateIndx = 0
            for j in range(team.shape[0]):
                while True:
                    if dateIndx >= teamMatchesDate.shape[0]:
                        sufficient[j] = False
                        break
                    if teamMatchesDate[dateIndx] < matchDate[j] :
                        restday = (matchDate[j] - teamMatchesDate[dateIndx])/np.timedelta64(1,'D')
                        break
                    else:
                        dateIndx = dateIndx + 1
                
                if j+n < team.shape[0]:                     
                    scoresum = scoresum + (hscore[j+n] if hometeam[j+n] == teamName else ascore[j+n])
                    winsum = winsum + (hwin[j+n] if hometeam[j+n] == teamName else awin[j+n])
                    losesum= losesum + (hlose[j+n] if hometeam[j+n] == teamName else alose[j+n])
                    drawsum= drawsum + (hdraw[j+n] if hometeam[j+n] == teamName else adraw[j+n])
                    concedesum = concedesum+ (hconcede[j+n] if hometeam[j+n] == teamName else aconcede[j+n])
                    moralsum= moralsum+ (hmoral[j+n] if hometeam[j+n] == teamName else amoral[j+n])
                else:
                    sufficient[j] = False
                    
                
                scoresum = scoresum - (hscore[j] if hometeam[j] == teamName else ascore[j])
                winsum = winsum - (hwin[j] if hometeam[j] == teamName else awin[j])
                losesum= losesum - (hlose[j] if hometeam[j] == teamName else alose[j])
                drawsum= drawsum - (hdraw[j] if hometeam[j] == teamName else adraw[j])
                concedesum = concedesum - (hconcede[j] if hometeam[j] == teamName else aconcede[j])
                moralsum= moralsum - (hmoral[j] if hometeam[j] == teamName else amoral[j])
                    
                if hometeam[j] == teamName:
                    hscore[j] = scoresum
                    hwin[j] = winsum
                    hlose[j] = losesum
                    hdraw[j] = drawsum
                    hconcede[j] = concedesum
                    hmoral[j] = moralsum
                    hrestday[j] = restday
                else:
                    ascore[j] = scoresum
                    awin[j] = winsum
                    alose[j] = losesum
                    adraw[j] = drawsum
                    aconcede[j] = concedesum
                    amoral[j] = moralsum
                    arestday[j] = restday
            team["HWin"]=hwin
            team["AWin"]=awin
            team["HDraw"]=hdraw
            team["ADraw"]=adraw
            team["HLose"]=hlose
            team["ALose"]=alose
            team["HScore"]=hscore
            team["AScore"]=ascore
            team["HConcede"]=hconcede
            team["AConcede"]=aconcede
            team["HMoral"] = hmoral
            team["AMoral"] = amoral
            team['Sufficient'] = sufficient
        
            #print(team[['HomeTeam','AwayTeam','HWin']])
            df.update(team)
            #print(df[['HomeTeam','AwayTeam','HAccP','AAccP']])
        self.df =df
        return df
    def initTeamData(self):
        self.teamsData={}
        self.teamsById={}
        for name in self.teamsMap.keys():
            self.readTeamMatch(name)
# Out:
# /home/y/scikit-learn/sklearn/cross_validation.py:43: DeprecationWarning: This module has been deprecated in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
c = FootballDataHelper()
#c.readFootBallData("E0_1112.csv")
c.readFootBallData("E0_1213.csv")
c.readFootBallData("E0_1314.csv")
c.readFootBallData("E0_1415.csv")
c.readFootBallData("E0 (1).csv")
c.initTeamData()
# Out:
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:77: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
df = c.initRanking()
# Out:
#  progress 1432
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:223: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Stoke
# Aston Villa
# Leicester
# Newcastle
# Tottenham
# Reading
# Arsenal
# Chelsea
# Everton
# Southampton
# Cardiff
# Swansea
# Norwich
# Liverpool
# QPR
# Wigan
# Man City
# West Ham
# Crystal Palace
# Fulham
# Man United
# Burnley
# Watford
# Bournemouth
# West Brom
# Hull
# Sunderland
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df=c.initRecentData(n=5)
# Out:
#  progress 1432
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:284: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:374: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:444: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:445: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:447: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:448: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:450: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:451: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:452: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Stoke
# Aston Villa
# Leicester
# Newcastle
# Tottenham
# Reading
# Arsenal
# Chelsea
# Everton
# Southampton
# Cardiff
# Swansea
# Norwich
# Liverpool
# QPR
# Wigan
# Man City
# West Ham
# Crystal Palace
# Fulham
# Man United
# Burnley
# Watford
# Bournemouth
# West Brom
# Hull
# Sunderland
# /home/y/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:453: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
X,y = c.getH7(removeInsufficient = True)
# Out:
# start format
# finish

# %%
# %matplotlib qt
def plotErrorDate(X_test, X_err, dateCol = 10):
    X_test_date =np.sort(X_test[:,c.dateColumn])
    X_date=[]
    y_date=[]
    for v in X_test_date:
        date = datetime.datetime.fromtimestamp(v*24*60*60)
        if len(X_date) ==0  or X_date[-1] != date:
            X_date.append(date)
            y_date.append(1)
        else:
            y_date[-1] = y_date[-1] +1
    plt.plot_date(X_date,y_date,xdate=True)
    X_err_d = np.sort(X_err[:,c.dateColumn])
    X_err_date=[]
    y_err_date = []
    for v in X_err_d:
        date = datetime.datetime.fromtimestamp(v*24*60*60)
        if len(X_err_date) ==0  or X_err_date[-1] != date:
            X_err_date.append(date)
            y_err_date.append(1)
        else:
            y_err_date[-1] = y_err_date[-1] +1
    plt.plot_date(X_err_date,y_err_date,xdate=True,color='red')
    plt.show()

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.learning_curve import learning_curve
from custom import SoftMaxMLPClassifier
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline
g_hiddenNodes = int(40)
g_alpha = 35 
clf = SoftMaxMLPClassifier(hidden_layer_sizes=[g_hiddenNodes], activation='logistic', algorithm='l-bfgs', alpha=g_alpha, 
              learning_rate_init=0.01,learning_rate='adaptive' ,max_iter=1000,early_stopping = True,verbose = 3)
mlp = Pipeline([ ('scl', StandardScaler()),('clf', clf)])
# Out:
# /home/y/scikit-learn/sklearn/learning_curve.py:23: DeprecationWarning: This module has been deprecated in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
df[['HomeTeam','AwayTeam','Date','HAccP','AAccP','Sufficient']][df['Sufficient']==1]
# Out:
#             HomeTeam        AwayTeam       Date  HAccP  AAccP  Sufficient
# 1432       Leicester       Newcastle 2016-03-14     44     21           1
# 1431     Aston Villa       Tottenham 2016-03-13     12     41           1
# 1430           Stoke     Southampton 2016-03-12     31     28           1
# 1428     Bournemouth         Swansea 2016-03-12     27     23           1
# 1429         Norwich        Man City 2016-03-12     15     32           1
# 1427       West Brom      Man United 2016-03-06     28     31           1
# 1426  Crystal Palace       Liverpool 2016-03-06     18     30           1
# 1421       Newcastle     Bournemouth 2016-03-05     21     24           1
# 1419         Everton        West Ham 2016-03-05     26     32           1
# 1420        Man City     Aston Villa 2016-03-05     32     12           1
# 1425         Watford       Leicester 2016-03-05     27     42           1
# 1422     Southampton      Sunderland 2016-03-05     28     21           1
# 1423         Swansea         Norwich 2016-03-05     20     15           1
# 1424       Tottenham         Arsenal 2016-03-05     41     35           1
# 1418         Chelsea           Stoke 2016-03-05     31     33           1
# 1414       Liverpool        Man City 2016-03-02     30     32           1
# 1417        West Ham       Tottenham 2016-03-02     30     42           1
# 1416           Stoke       Newcastle 2016-03-02     33     22           1
# 1413         Arsenal         Swansea 2016-03-02     38     18           1
# 1415      Man United         Watford 2016-03-02     28     28           1
# 1412      Sunderland  Crystal Palace 2016-03-01     21     20           1
# 1411         Norwich         Chelsea 2016-03-01     15     28           1
# 1410       Leicester       West Brom 2016-03-01     44     27           1
# 1409     Bournemouth     Southampton 2016-03-01     22     31           1
# 1408     Aston Villa         Everton 2016-03-01     12     26           1
# 1407      Man United         Arsenal 2016-02-28     28     41           1
# 1406       Tottenham         Swansea 2016-02-28     42     18           1
# 1405        West Ham      Sunderland 2016-02-27     28     21           1
# 1404       West Brom  Crystal Palace 2016-02-27     24     23           1
# 1403         Watford     Bournemouth 2016-02-27     27     21           1
# ...              ...             ...        ...    ...    ...         ...
# 80       Aston Villa         Norwich 2012-10-27     17     18           1
# 79           Arsenal             QPR 2012-10-27     24     15           1
# 78        Sunderland       Newcastle 2012-10-21     21     22           1
# 77               QPR         Everton 2012-10-21     15     27           1
# 72           Norwich         Arsenal 2012-10-20     16     25           1
# 74         Tottenham         Chelsea 2012-10-20     27     32           1
# 76          West Ham     Southampton 2012-10-20     24     17           1
# 75         West Brom        Man City 2012-10-20     27     28           1
# 71        Man United           Stoke 2012-10-20     28     21           1
# 70         Liverpool         Reading 2012-10-20     19     17           1
# 69            Fulham     Aston Villa 2012-10-20     23     18           1
# 73           Swansea           Wigan 2012-10-20     21     18           1
# 68         Tottenham     Aston Villa 2012-10-07     25     19           1
# 67       Southampton          Fulham 2012-10-07     17     23           1
# 66         Newcastle      Man United 2012-10-07     23     26           1
# 65         Liverpool           Stoke 2012-10-07     19     21           1
# 59           Chelsea         Norwich 2012-10-06     30     17           1
# 60          Man City      Sunderland 2012-10-06     26     22           1
# 61           Swansea         Reading 2012-10-06     21     17           1
# 62         West Brom             QPR 2012-10-06     25     16           1
# 63          West Ham         Arsenal 2012-10-06     25     23           1
# 64             Wigan         Everton 2012-10-06     18     27           1
# 58               QPR        West Ham 2012-10-01     17     23           1
# 57       Aston Villa       West Brom 2012-09-30     19     25           1
# 52        Man United       Tottenham 2012-09-29     27     23           1
# 55             Stoke         Swansea 2012-09-29     19     22           1
# 49           Arsenal         Chelsea 2012-09-29     24     28           1
# 50           Everton     Southampton 2012-09-29     25     18           1
# 53           Norwich       Liverpool 2012-09-29     18     17           1
# 51            Fulham        Man City 2012-09-29     24     24           1
#
# [1348 rows x 6 columns]

# %%
print ("start learning")
sys.stdout.flush()
train_sizes, train_scores, test_scores = learning_curve(estimator=mlp, 
                       X=X, 
                      y=y, 
                      train_sizes=np.linspace(0.1, 1.0, 4), 
                      cv=4,
                     n_jobs=1,verbose=3)
print("finishing")   
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)


print(test_mean)
# Out:
# start learning
# [learning_curve] Training set sizes: [ 101  404  707 1011]
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.433234 -   0.5s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.519288 -   0.4s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.528190 -   0.6s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.528190 -   0.6s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.468843 -   0.1s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.554896 -   0.3s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.569733 -   0.5s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.584570 -   0.7s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.456973 -   0.2s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.537092 -   0.4s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.537092 -   0.7s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.554896 -   0.9s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.409496 -   0.1s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.477745 -   0.3s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.474777 -   0.5s
# [CV] no parameters to be set .........................................
# [CV] ................ no parameters to be set, score=0.471810 -   0.8s
# finishing
# [ 0.4421365   0.52225519  0.52744807  0.53486647]
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    7.6s finished

# %%
learningRes = np.vstack([train_sizes,train_mean,train_std,test_mean,test_std]).T

# %%
learningDf = pd.DataFrame(learningRes,columns=['size','train_mean','train_std','test_mean','test_std'])
print(learningDf)
# Out:
#    size  train_mean  train_std  test_mean  test_std
# 0   101    0.443069   0.012862   0.442136  0.022793
# 1   404    0.535891   0.010574   0.522255  0.028616
# 2   707    0.561881   0.011288   0.527448  0.034117
# 3  1011    0.557864   0.012255   0.534866  0.041510

# %%
# %matplotlib inline
plotCurve(train_mean,train_std,test_mean,test_std,train_sizes)

# %%
from sklearn.cross_validation import StratifiedKFold
def crossValidate(mlp, X,y, fold = 10):
    y_label = np.argmax(y,axis=1)

    kfold = StratifiedKFold(y=y_label, 
                             n_folds=fold,
                            random_state=1)

    scores = []
    train_scores=[]
    firstNScores = []
    for k, (train, test) in enumerate(kfold):

        mlp.fit(X[train], y[train])
        score = mlp.score(X[test], y[test])
        firstNScores.append(firstNScore(2, mlp.predict_proba(X[test]), y[test]))
        train_scores.append(mlp.score(X[train],y[train]))
        scores.append(score)
        print('Fold: %s, Class dist.: %s, Acc: %.3f' % (k+1, 
                    np.bincount(y_label[train]), score))    
        
        
    return train_scores,scores, firstNScores

# %%
def lamda_test(mlp, X, y, lamdas):
    
    train_scores=[]
    test_scores=[]
    for lamda in lamdas:
        clf.set_params(alpha= lamda)
        train_s, test_s, firstNScores = crossValidate(mlp,X,y,fold=8)
      #  train_s, test_s, firstNScores =futureTest(mlp,X,y,numOfWeek=20) 
        train_scores.append(train_s)
        test_scores.append(test_s)
        print("lamda: {}, train: {}, test: {}".format(lamda, 
                    np.mean(train_s), np.mean(test_s)) )
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)
    plotCurve(train_mean,train_std,test_mean,test_std,lamdas)
    return np.array(train_scores),np.array(test_scores)

l_range = []
for i in range(0,10):
    l_range.append(10*i)
train_scores,test_scores = lamda_test(mlp,X,y,np.array(l_range))
#50
# Out:
# Fold: 1, Class dist.: [487 267 343], Acc: 0.415
# Fold: 2, Class dist.: [487 267 344], Acc: 0.449
# Fold: 3, Class dist.: [487 268 344], Acc: 0.414
# Fold: 4, Class dist.: [487 268 344], Acc: 0.420
# Fold: 5, Class dist.: [487 268 344], Acc: 0.414
# Fold: 6, Class dist.: [488 268 344], Acc: 0.436
# Fold: 7, Class dist.: [488 268 344], Acc: 0.365
# Fold: 8, Class dist.: [488 268 344], Acc: 0.378
# lamda: 0, train: 1.0, test: 0.41154453137868974
# Fold: 1, Class dist.: [487 267 343], Acc: 0.560
# Fold: 2, Class dist.: [487 267 344], Acc: 0.570
# Fold: 3, Class dist.: [487 268 344], Acc: 0.573
# Fold: 4, Class dist.: [487 268 344], Acc: 0.541
# Fold: 5, Class dist.: [487 268 344], Acc: 0.490
# Fold: 6, Class dist.: [488 268 344], Acc: 0.551
# Fold: 7, Class dist.: [488 268 344], Acc: 0.481
# Fold: 8, Class dist.: [488 268 344], Acc: 0.436
# lamda: 10, train: 0.6426281239945947, test: 0.5253016175234381
# Fold: 1, Class dist.: [487 267 343], Acc: 0.522
# Fold: 2, Class dist.: [487 267 344], Acc: 0.538
# Fold: 3, Class dist.: [487 268 344], Acc: 0.561
# Fold: 4, Class dist.: [487 268 344], Acc: 0.554
# Fold: 5, Class dist.: [487 268 344], Acc: 0.510
# Fold: 6, Class dist.: [488 268 344], Acc: 0.551
# Fold: 7, Class dist.: [488 268 344], Acc: 0.500
# Fold: 8, Class dist.: [488 268 344], Acc: 0.455
# lamda: 20, train: 0.5740434076687543, test: 0.5238251675283704
# Fold: 1, Class dist.: [487 267 343], Acc: 0.541
# Fold: 2, Class dist.: [487 267 344], Acc: 0.544
# Fold: 3, Class dist.: [487 268 344], Acc: 0.580
# Fold: 4, Class dist.: [487 268 344], Acc: 0.548
# Fold: 5, Class dist.: [487 268 344], Acc: 0.529
# Fold: 6, Class dist.: [488 268 344], Acc: 0.558
# Fold: 7, Class dist.: [488 268 344], Acc: 0.513
# Fold: 8, Class dist.: [488 268 344], Acc: 0.449
# lamda: 30, train: 0.5653992794343203, test: 0.5325582531572237
# Fold: 1, Class dist.: [487 267 343], Acc: 0.522
# Fold: 2, Class dist.: [487 267 344], Acc: 0.544
# Fold: 3, Class dist.: [487 268 344], Acc: 0.567
# Fold: 4, Class dist.: [487 268 344], Acc: 0.561
# Fold: 5, Class dist.: [487 268 344], Acc: 0.529
# Fold: 6, Class dist.: [488 268 344], Acc: 0.571
# Fold: 7, Class dist.: [488 268 344], Acc: 0.494
# Fold: 8, Class dist.: [488 268 344], Acc: 0.481
# lamda: 40, train: 0.5605099153202582, test: 0.5334048907963143
# Fold: 1, Class dist.: [487 267 343], Acc: 0.522
# Fold: 2, Class dist.: [487 267 344], Acc: 0.551
# Fold: 3, Class dist.: [487 268 344], Acc: 0.561
# Fold: 4, Class dist.: [487 268 344], Acc: 0.561
# Fold: 5, Class dist.: [487 268 344], Acc: 0.522
# Fold: 6, Class dist.: [488 268 344], Acc: 0.564
# Fold: 7, Class dist.: [488 268 344], Acc: 0.506
# Fold: 8, Class dist.: [488 268 344], Acc: 0.468
# lamda: 50, train: 0.5562995728811495, test: 0.5318023912976405
# Fold: 1, Class dist.: [487 267 343], Acc: 0.535
# Fold: 2, Class dist.: [487 267 344], Acc: 0.557
# Fold: 3, Class dist.: [487 268 344], Acc: 0.548
# Fold: 4, Class dist.: [487 268 344], Acc: 0.535
# Fold: 5, Class dist.: [487 268 344], Acc: 0.503
# Fold: 6, Class dist.: [488 268 344], Acc: 0.538
# Fold: 7, Class dist.: [488 268 344], Acc: 0.513
# Fold: 8, Class dist.: [488 268 344], Acc: 0.481
# lamda: 60, train: 0.5466300274743889, test: 0.5261989704353485
# Fold: 1, Class dist.: [487 267 343], Acc: 0.522
# Fold: 2, Class dist.: [487 267 344], Acc: 0.563
# Fold: 3, Class dist.: [487 268 344], Acc: 0.516
# Fold: 4, Class dist.: [487 268 344], Acc: 0.529
# Fold: 5, Class dist.: [487 268 344], Acc: 0.535
# Fold: 6, Class dist.: [488 268 344], Acc: 0.526
# Fold: 7, Class dist.: [488 268 344], Acc: 0.506
# Fold: 8, Class dist.: [488 268 344], Acc: 0.481
# lamda: 70, train: 0.5357126583625806, test: 0.5222177581340345
# Fold: 1, Class dist.: [487 267 343], Acc: 0.497
# Fold: 2, Class dist.: [487 267 344], Acc: 0.551
# Fold: 3, Class dist.: [487 268 344], Acc: 0.484
# Fold: 4, Class dist.: [487 268 344], Acc: 0.497
# Fold: 5, Class dist.: [487 268 344], Acc: 0.522
# Fold: 6, Class dist.: [488 268 344], Acc: 0.513
# Fold: 7, Class dist.: [488 268 344], Acc: 0.481
# Fold: 8, Class dist.: [488 268 344], Acc: 0.462
# lamda: 80, train: 0.5205818402963612, test: 0.5007251469760444
# Fold: 1, Class dist.: [487 267 343], Acc: 0.459
# Fold: 2, Class dist.: [487 267 344], Acc: 0.481
# Fold: 3, Class dist.: [487 268 344], Acc: 0.465
# Fold: 4, Class dist.: [487 268 344], Acc: 0.497
# Fold: 5, Class dist.: [487 268 344], Acc: 0.484
# Fold: 6, Class dist.: [488 268 344], Acc: 0.468
# Fold: 7, Class dist.: [488 268 344], Acc: 0.462
# Fold: 8, Class dist.: [488 268 344], Acc: 0.455
# lamda: 90, train: 0.4865758003779218, test: 0.4713259265387555

# %%
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)
alphaRes = np.vstack([l_range,train_mean,train_std,test_mean,test_std]).T
alphaDf = pd.DataFrame(alphaRes,columns=['alpha','train_mean','train_std','test_mean','test_std'])
print(alphaDf)
# Out:
#    alpha  train_mean  train_std  test_mean  test_std
# 0      0    1.000000   0.000000   0.411545  0.025905
# 1     10    0.642628   0.011108   0.525302  0.046871
# 2     20    0.574043   0.006614   0.523825  0.033001
# 3     30    0.565399   0.006586   0.532558  0.036604
# 4     40    0.560510   0.004186   0.533405  0.031343
# 5     50    0.556300   0.005572   0.531802  0.031533
# 6     60    0.546630   0.004557   0.526199  0.023672
# 7     70    0.535713   0.004047   0.522218  0.022113
# 8     80    0.520582   0.007800   0.500725  0.025845
# 9     90    0.486576   0.008019   0.471326  0.013533

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.learning_curve import learning_curve
from custom import SoftMaxMLPClassifier
from sklearn.pipeline import Pipeline
# %matplotlib inline
import matplotlib.pyplot as plt
def testNodeSize(start ,end):
    node_range = range(start,end,5)
    train_means = []
    train_std = []
    test_means =[]
    test_std=[]
    for node in node_range:   
        print("start node:{}".format(node))
        clf = SoftMaxMLPClassifier(hidden_layer_sizes=[node], activation='logistic', algorithm='l-bfgs', alpha=0, 
                  learning_rate_init=0.01,learning_rate='adaptive' ,max_iter=500,early_stopping = True,verbose = 3)
        mlp = Pipeline([('scl', StandardScaler()),('clf', clf)])
        train_scores,test_scores,first2 = crossValidate(mlp,X,y,fold=8)
      #  train_scores,test_scores , first2= futureTest(mlp, X,y,numOfWeek = 10)
        train_means.append(np.mean(train_scores))
        train_std.append(np.std(train_scores))
        test_means.append(np.mean(test_scores))
        test_std.append(np.std(test_scores))
        print("Node {}: train_mean {}  v.s. test_mean {}".format(node,np.mean(train_scores),np.mean(test_scores)))
    plotCurve(np.array(train_means),np.array(train_std),np.array(test_means),np.array(test_std),np.array(node_range))
    return node_range, train_means,train_std,test_means,test_std

# %%
node_range, train_means,train_std,test_means,test_std=testNodeSize(4,X.shape[1] )
# Out:
# start node:4
# Fold: 1, Class dist.: [487 267 343], Acc: 0.440
# Fold: 2, Class dist.: [487 267 344], Acc: 0.525
# Fold: 3, Class dist.: [487 268 344], Acc: 0.503
# Fold: 4, Class dist.: [487 268 344], Acc: 0.465
# Fold: 5, Class dist.: [487 268 344], Acc: 0.408
# Fold: 6, Class dist.: [488 268 344], Acc: 0.455
# Fold: 7, Class dist.: [488 268 344], Acc: 0.423
# Fold: 8, Class dist.: [488 268 344], Acc: 0.391
# Node 4: train_mean 0.7383956371120195  v.s. test_mean 0.4513243719497456
# start node:9
# Fold: 1, Class dist.: [487 267 343], Acc: 0.509
# Fold: 2, Class dist.: [487 267 344], Acc: 0.475
# Fold: 3, Class dist.: [487 268 344], Acc: 0.510
# Fold: 4, Class dist.: [487 268 344], Acc: 0.401
# Fold: 5, Class dist.: [487 268 344], Acc: 0.376
# Fold: 6, Class dist.: [488 268 344], Acc: 0.526
# Fold: 7, Class dist.: [488 268 344], Acc: 0.455
# Fold: 8, Class dist.: [488 268 344], Acc: 0.423
# Node 9: train_mean 0.8771636466479569  v.s. test_mean 0.4593234830294698
# start node:14
# Fold: 1, Class dist.: [487 267 343], Acc: 0.371
# Fold: 2, Class dist.: [487 267 344], Acc: 0.456
# Fold: 3, Class dist.: [487 268 344], Acc: 0.414
# Fold: 4, Class dist.: [487 268 344], Acc: 0.408
# Fold: 5, Class dist.: [487 268 344], Acc: 0.395
# Fold: 6, Class dist.: [488 268 344], Acc: 0.391
# Fold: 7, Class dist.: [488 268 344], Acc: 0.359
# Fold: 8, Class dist.: [488 268 344], Acc: 0.404
# Node 14: train_mean 0.9518885565524242  v.s. test_mean 0.39964650604023455
# start node:19
# Fold: 1, Class dist.: [487 267 343], Acc: 0.447
# Fold: 2, Class dist.: [487 267 344], Acc: 0.494
# Fold: 3, Class dist.: [487 268 344], Acc: 0.408
# Fold: 4, Class dist.: [487 268 344], Acc: 0.408
# Fold: 5, Class dist.: [487 268 344], Acc: 0.395
# Fold: 6, Class dist.: [488 268 344], Acc: 0.404
# Fold: 7, Class dist.: [488 268 344], Acc: 0.436
# Fold: 8, Class dist.: [488 268 344], Acc: 0.397
# Node 19: train_mean 0.9794132926597453  v.s. test_mean 0.42344779207014116
# start node:24
# Fold: 1, Class dist.: [487 267 343], Acc: 0.428
# Fold: 2, Class dist.: [487 267 344], Acc: 0.475
# Fold: 3, Class dist.: [487 268 344], Acc: 0.490
# Fold: 4, Class dist.: [487 268 344], Acc: 0.465
# Fold: 5, Class dist.: [487 268 344], Acc: 0.439
# Fold: 6, Class dist.: [488 268 344], Acc: 0.468
# Fold: 7, Class dist.: [488 268 344], Acc: 0.429
# Fold: 8, Class dist.: [488 268 344], Acc: 0.385
# Node 24: train_mean 0.9926071180321157  v.s. test_mean 0.44741403011608105
# start node:29
# Fold: 1, Class dist.: [487 267 343], Acc: 0.396
# Fold: 2, Class dist.: [487 267 344], Acc: 0.468
# Fold: 3, Class dist.: [487 268 344], Acc: 0.452
# Fold: 4, Class dist.: [487 268 344], Acc: 0.439
# Fold: 5, Class dist.: [487 268 344], Acc: 0.401
# Fold: 6, Class dist.: [488 268 344], Acc: 0.397
# Fold: 7, Class dist.: [488 268 344], Acc: 0.372
# Fold: 8, Class dist.: [488 268 344], Acc: 0.353
# Node 29: train_mean 0.9993171468786223  v.s. test_mean 0.4099211684802758
# start node:34
# Fold: 1, Class dist.: [487 267 343], Acc: 0.409
# Fold: 2, Class dist.: [487 267 344], Acc: 0.487
# Fold: 3, Class dist.: [487 268 344], Acc: 0.446
# Fold: 4, Class dist.: [487 268 344], Acc: 0.427
# Fold: 5, Class dist.: [487 268 344], Acc: 0.408
# Fold: 6, Class dist.: [488 268 344], Acc: 0.429
# Fold: 7, Class dist.: [488 268 344], Acc: 0.429
# Fold: 8, Class dist.: [488 268 344], Acc: 0.372
# Node 34: train_mean 0.9994317147820333  v.s. test_mean 0.42589635142971677
# start node:39
# Fold: 1, Class dist.: [487 267 343], Acc: 0.421
# Fold: 2, Class dist.: [487 267 344], Acc: 0.462
# Fold: 3, Class dist.: [487 268 344], Acc: 0.446
# Fold: 4, Class dist.: [487 268 344], Acc: 0.452
# Fold: 5, Class dist.: [487 268 344], Acc: 0.433
# Fold: 6, Class dist.: [488 268 344], Acc: 0.436
# Fold: 7, Class dist.: [488 268 344], Acc: 0.442
# Fold: 8, Class dist.: [488 268 344], Acc: 0.385
# Node 39: train_mean 0.999317871618827  v.s. test_mean 0.4346799585197192
# start node:44
# Fold: 1, Class dist.: [487 267 343], Acc: 0.459
# Fold: 2, Class dist.: [487 267 344], Acc: 0.500
# Fold: 3, Class dist.: [487 268 344], Acc: 0.439
# Fold: 4, Class dist.: [487 268 344], Acc: 0.452
# Fold: 5, Class dist.: [487 268 344], Acc: 0.376
# Fold: 6, Class dist.: [488 268 344], Acc: 0.429
# Fold: 7, Class dist.: [488 268 344], Acc: 0.397
# Fold: 8, Class dist.: [488 268 344], Acc: 0.391
# Node 44: train_mean 0.9997725202848153  v.s. test_mean 0.4305730172963678
# start node:49
# Fold: 1, Class dist.: [487 267 343], Acc: 0.365
# Fold: 2, Class dist.: [487 267 344], Acc: 0.481
# Fold: 3, Class dist.: [487 268 344], Acc: 0.408
# Fold: 4, Class dist.: [487 268 344], Acc: 0.446
# Fold: 5, Class dist.: [487 268 344], Acc: 0.439
# Fold: 6, Class dist.: [488 268 344], Acc: 0.442
# Fold: 7, Class dist.: [488 268 344], Acc: 0.417
# Fold: 8, Class dist.: [488 268 344], Acc: 0.404
# Node 49: train_mean 1.0  v.s. test_mean 0.42520083447943074
# start node:54
# Fold: 1, Class dist.: [487 267 343], Acc: 0.434
# Fold: 2, Class dist.: [487 267 344], Acc: 0.544
# Fold: 3, Class dist.: [487 268 344], Acc: 0.433
# Fold: 4, Class dist.: [487 268 344], Acc: 0.471
# Fold: 5, Class dist.: [487 268 344], Acc: 0.408
# Fold: 6, Class dist.: [488 268 344], Acc: 0.462
# Fold: 7, Class dist.: [488 268 344], Acc: 0.404
# Fold: 8, Class dist.: [488 268 344], Acc: 0.410
# Node 54: train_mean 1.0  v.s. test_mean 0.4457511247610436
# start node:59
# Fold: 1, Class dist.: [487 267 343], Acc: 0.390
# Fold: 2, Class dist.: [487 267 344], Acc: 0.513
# Fold: 3, Class dist.: [487 268 344], Acc: 0.465
# Fold: 4, Class dist.: [487 268 344], Acc: 0.401
# Fold: 5, Class dist.: [487 268 344], Acc: 0.459
# Fold: 6, Class dist.: [488 268 344], Acc: 0.436
# Fold: 7, Class dist.: [488 268 344], Acc: 0.391
# Fold: 8, Class dist.: [488 268 344], Acc: 0.385
# Node 59: train_mean 1.0  v.s. test_mean 0.42987182007950153
# start node:64
# Fold: 1, Class dist.: [487 267 343], Acc: 0.465
# Fold: 2, Class dist.: [487 267 344], Acc: 0.494
# Fold: 3, Class dist.: [487 268 344], Acc: 0.471
# Fold: 4, Class dist.: [487 268 344], Acc: 0.497
# Fold: 5, Class dist.: [487 268 344], Acc: 0.369
# Fold: 6, Class dist.: [488 268 344], Acc: 0.481
# Fold: 7, Class dist.: [488 268 344], Acc: 0.340
# Fold: 8, Class dist.: [488 268 344], Acc: 0.365
# Node 64: train_mean 1.0  v.s. test_mean 0.4353195931049033
# start node:69
# Fold: 1, Class dist.: [487 267 343], Acc: 0.396
# Fold: 2, Class dist.: [487 267 344], Acc: 0.392
# Fold: 3, Class dist.: [487 268 344], Acc: 0.408
# Fold: 4, Class dist.: [487 268 344], Acc: 0.420
# Fold: 5, Class dist.: [487 268 344], Acc: 0.350
# Fold: 6, Class dist.: [488 268 344], Acc: 0.410
# Fold: 7, Class dist.: [488 268 344], Acc: 0.417
# Fold: 8, Class dist.: [488 268 344], Acc: 0.429
# Node 69: train_mean 1.0  v.s. test_mean 0.4029232104800402
# start node:74
# Fold: 1, Class dist.: [487 267 343], Acc: 0.428
# Fold: 2, Class dist.: [487 267 344], Acc: 0.513
# Fold: 3, Class dist.: [487 268 344], Acc: 0.497
# Fold: 4, Class dist.: [487 268 344], Acc: 0.465
# Fold: 5, Class dist.: [487 268 344], Acc: 0.357
# Fold: 6, Class dist.: [488 268 344], Acc: 0.385
# Fold: 7, Class dist.: [488 268 344], Acc: 0.449
# Fold: 8, Class dist.: [488 268 344], Acc: 0.442
# Node 74: train_mean 1.0  v.s. test_mean 0.4418054433804484
# start node:79
# Fold: 1, Class dist.: [487 267 343], Acc: 0.409
# Fold: 2, Class dist.: [487 267 344], Acc: 0.462
# Fold: 3, Class dist.: [487 268 344], Acc: 0.490
# Fold: 4, Class dist.: [487 268 344], Acc: 0.439
# Fold: 5, Class dist.: [487 268 344], Acc: 0.446
# Fold: 6, Class dist.: [488 268 344], Acc: 0.442
# Fold: 7, Class dist.: [488 268 344], Acc: 0.455
# Fold: 8, Class dist.: [488 268 344], Acc: 0.359
# Node 79: train_mean 1.0  v.s. test_mean 0.4378795978320553
# start node:84
# Fold: 1, Class dist.: [487 267 343], Acc: 0.421
# Fold: 2, Class dist.: [487 267 344], Acc: 0.494
# Fold: 3, Class dist.: [487 268 344], Acc: 0.408
# Fold: 4, Class dist.: [487 268 344], Acc: 0.465
# Fold: 5, Class dist.: [487 268 344], Acc: 0.433
# Fold: 6, Class dist.: [488 268 344], Acc: 0.423
# Fold: 7, Class dist.: [488 268 344], Acc: 0.372
# Fold: 8, Class dist.: [488 268 344], Acc: 0.423
# Node 84: train_mean 1.0  v.s. test_mean 0.42984196698748034
# start node:89
# Fold: 1, Class dist.: [487 267 343], Acc: 0.440
# Fold: 2, Class dist.: [487 267 344], Acc: 0.456
# Fold: 3, Class dist.: [487 268 344], Acc: 0.459
# Fold: 4, Class dist.: [487 268 344], Acc: 0.408
# Fold: 5, Class dist.: [487 268 344], Acc: 0.465
# Fold: 6, Class dist.: [488 268 344], Acc: 0.449
# Fold: 7, Class dist.: [488 268 344], Acc: 0.436
# Fold: 8, Class dist.: [488 268 344], Acc: 0.397
# Node 89: train_mean 1.0  v.s. test_mean 0.43865115599909676

# %%
nodeRes = np.vstack([node_range,train_means,train_std,test_means,test_std]).T
nodeDf = pd.DataFrame(nodeRes,columns=['nodeNum','train_mean','train_std','test_mean','test_std'])
print(nodeDf)
# Out:
#    nodeNum  train_mean  train_std  test_mean  test_std
# 0       10    0.560850   0.004847   0.530981  0.033781
# 1       20    0.560622   0.005201   0.533380  0.034056
# 2       30    0.560281   0.004855   0.532578  0.035481
# 3       40    0.560167   0.004904   0.533380  0.034506
# 4       50    0.560395   0.004944   0.533380  0.034506
# 5       60    0.560394   0.005323   0.533380  0.034506
# 6       70    0.560394   0.005174   0.533380  0.034506
# 7       80    0.560394   0.005455   0.533380  0.034506

# %%
clf.set_params(alpha=g_alpha)
print(clf)
train_score, test_score, first2 = futureTest(mlp,X,y,numOfWeek = 30, verbose=True)
# Out:
# SoftMaxMLPClassifier(activation='logistic', algorithm='l-bfgs', alpha=35,
#            batch_size='auto', beta_1=0.9, beta_2=0.999,
#            early_stopping=True, epsilon=1e-08, hidden_layer_sizes=[40],
#            learning_rate='adaptive', learning_rate_init=0.01,
#            max_iter=1000, momentum=0.9, nesterovs_momentum=True,
#            power_t=0.5, random_state=None, shuffle=True, tol=0.0001,
#            validation_fraction=0.1, verbose=3, warm_start=False)
# week0
# numOftest 5 , score 0.6
# [['Norwich' 'Man City' '0.21608529015479733' '0.2420453057726276'
#   '0.5418694040725751' 'False' 'True' 'False']
#  ['Stoke' 'Southampton' '0.576339120273981' '0.1844373536256032'
#   '0.23922352610041572' 'False' 'False' 'True']]
# first2 : {} 1.0
# week1
# numOftest 10 , score 0.4
# [['Chelsea' 'Stoke' '0.7744118303309667' '0.13042803549000734'
#   '0.09516013417902609' 'False' 'True' 'False']
#  ['Everton' 'West Ham' '0.5023252064021776' '0.2294517730386539'
#   '0.2682230205591686' 'False' 'False' 'True']
#  ['Newcastle' 'Bournemouth' '0.2497573131168697' '0.387824802838769'
#   '0.36241788404436115' 'False' 'False' 'True']
#  ['Southampton' 'Sunderland' '0.5533200829676875' '0.2154618746457062'
#   '0.23121804238660634' 'False' 'True' 'False']
#  ['Tottenham' 'Arsenal' '0.5854102633829574' '0.18784910372570066'
#   '0.2267406328913419' 'False' 'True' 'False']
#  ['West Brom' 'Man United' '0.25805130378391683' '0.2816292605035599'
#   '0.46031943571252326' 'True' 'False' 'False']]
# first2 : {} 0.7
# week2
# numOftest 18 , score 0.5555555555555556
# [['Southampton' 'Chelsea' '0.5110329467742756' '0.18637846844694447'
#   '0.3025885847787799' 'False' 'False' 'True']
#  ['Watford' 'Bournemouth' '0.27672262360762045' '0.2173494368854202'
#   '0.5059279395069594' 'False' 'True' 'False']
#  ['West Brom' 'Crystal Palace' '0.34933233585142387' '0.23770905754096477'
#   '0.41295860660761124' 'True' 'False' 'False']
#  ['Bournemouth' 'Southampton' '0.24664314785017588' '0.2688900126892003'
#   '0.48446683946062374' 'True' 'False' 'False']
#  ['Leicester' 'West Brom' '0.7569964698974266' '0.12568188437696923'
#   '0.11732164572560416' 'False' 'True' 'False']
#  ['Sunderland' 'Crystal Palace' '0.28242384717341384' '0.2328261182584495'
#   '0.4847500345681367' 'False' 'True' 'False']
#  ['Arsenal' 'Swansea' '0.7417873077343963' '0.14523065105683344'
#   '0.11298204120877031' 'False' 'False' 'True']
#  ['West Ham' 'Tottenham' '0.27013149328090685' '0.23538116114811217'
#   '0.49448734557098106' 'True' 'False' 'False']]
# first2 : {} 0.777777777778
# week3
# numOftest 10 , score 0.5
# [['Everton' 'West Brom' '0.7375412879236484' '0.151718497484621'
#   '0.11074021459173052' 'False' 'False' 'True']
#  ['Crystal Palace' 'Watford' '0.5411562658100602' '0.19327226843384782'
#   '0.265571465756092' 'False' 'False' 'True']
#  ['Sunderland' 'Man United' '0.17648126131233155' '0.24087929114951787'
#   '0.5826394475381507' 'True' 'False' 'False']
#  ['Norwich' 'West Ham' '0.3147535032182258' '0.2955654823772248'
#   '0.3896810144045495' 'False' 'True' 'False']
#  ['Man City' 'Tottenham' '0.5468270719765854' '0.1756360818846988'
#   '0.2775368461387158' 'False' 'False' 'True']]
# first2 : {} 0.7
# week4
# numOftest 10 , score 0.5
# [['Liverpool' 'Sunderland' '0.6232622410558905' '0.18881761522039062'
#   '0.1879201437237191' 'False' 'True' 'False']
#  ['Man City' 'Leicester' '0.5429624840122799' '0.17196875653886748'
#   '0.2850687594488527' 'False' 'False' 'True']
#  ['Stoke' 'Everton' '0.47259868921387255' '0.23717297590382397'
#   '0.29022833488230343' 'False' 'False' 'True']
#  ['Swansea' 'Crystal Palace' '0.39605034049395477' '0.2623142476262854'
#   '0.3416354118797599' 'False' 'True' 'False']
#  ['Chelsea' 'Man United' '0.5745887596973459' '0.21404954476809074'
#   '0.21136169553456333' 'False' 'True' 'False']]
# first2 : {} 0.9
# week5
# numOftest 10 , score 0.7
# [['West Brom' 'Swansea' '0.40948371105846487' '0.2460011814304256'
#   '0.34451510751110953' 'False' 'True' 'False']
#  ['Arsenal' 'Southampton' '0.6821063114053331' '0.16140787414254523'
#   '0.15648581445212176' 'False' 'True' 'False']
#  ['Watford' 'Chelsea' '0.34020739148476487' '0.21054499160137086'
#   '0.4492476169138643' 'False' 'True' 'False']]
# first2 : {} 0.8
# week6
# numOftest 10 , score 0.4
# [['Sunderland' 'Bournemouth' '0.28573265187822' '0.27100751426251346'
#   '0.4432598338592666' 'False' 'True' 'False']
#  ['Man United' 'Southampton' '0.5692963296276611' '0.19765374488027074'
#   '0.2330499254920683' 'False' 'False' 'True']
#  ['West Ham' 'Man City' '0.3876884221969145' '0.22745833216118297'
#   '0.3848532456419025' 'False' 'True' 'False']
#  ['West Brom' 'Aston Villa' '0.555637610403021' '0.20003367444096173'
#   '0.24432871515601734' 'False' 'True' 'False']
#  ['Arsenal' 'Chelsea' '0.707187436679888' '0.13870067404966732'
#   '0.15411188927044464' 'False' 'False' 'True']
#  ['Everton' 'Swansea' '0.5935025457049711' '0.18540758456097964'
#   '0.22108986973404918' 'False' 'False' 'True']]
# first2 : {} 0.7
# week7
# numOftest 10 , score 0.5
# [['Aston Villa' 'Leicester' '0.2215840033340427' '0.22464194038813404'
#   '0.5537740562778233' 'False' 'True' 'False']
#  ['Chelsea' 'Everton' '0.6826293066274208' '0.16745665880312624'
#   '0.14991403456945285' 'False' 'True' 'False']
#  ['Newcastle' 'West Ham' '0.31079122015966626' '0.25628435883491135'
#   '0.4329244210054224' 'True' 'False' 'False']
#  ['Liverpool' 'Man United' '0.5397718494314011' '0.20023267427316865'
#   '0.2599954762954302' 'False' 'False' 'True']
#  ['Stoke' 'Arsenal' '0.4350150402183153' '0.21958265589657353'
#   '0.3454023038851112' 'False' 'True' 'False']]
# first2 : {} 0.9
# week8
# numOftest 10 , score 0.1
# [['Aston Villa' 'Crystal Palace' '0.1746853438938215' '0.21600861299587693'
#   '0.6093060431103016' 'True' 'False' 'False']
#  ['Bournemouth' 'West Ham' '0.5196164324563489' '0.24838382320336955'
#   '0.23199974434028153' 'False' 'False' 'True']
#  ['Newcastle' 'Man United' '0.2538851258060223' '0.25353410157942435'
#   '0.49258077261455335' 'False' 'True' 'False']
#  ['Southampton' 'Watford' '0.3343092544488705' '0.26205812729300676'
#   '0.4036326182581227' 'True' 'False' 'False']
#  ['Chelsea' 'West Brom' '0.6928929225744667' '0.15547308032656068'
#   '0.15163399709897274' 'False' 'True' 'False']
#  ['Man City' 'Everton' '0.839502073330041' '0.09551398145604387'
#   '0.06498394521391516' 'False' 'True' 'False']
#  ['Swansea' 'Sunderland' '0.5135622603457871' '0.23400219555231397'
#   '0.25243554410189895' 'False' 'False' 'True']
#  ['Tottenham' 'Leicester' '0.5581399343832839' '0.174846801303405'
#   '0.2670132643133111' 'False' 'False' 'True']
#  ['Liverpool' 'Arsenal' '0.3741259057965949' '0.2214435309136621'
#   '0.40443056328974303' 'False' 'True' 'False']]
# first2 : {} 0.6
# week9
# numOftest 10 , score 0.6
# [['Leicester' 'Bournemouth' '0.533133006153225' '0.1897262183732499'
#   '0.2771407754735251' 'False' 'True' 'False']
#  ['West Brom' 'Stoke' '0.34212358284233807' '0.2474265173565423'
#   '0.4104498998011196' 'True' 'False' 'False']
#  ['Watford' 'Man City' '0.4874206852700324' '0.18331059087340332'
#   '0.32926872385656436' 'False' 'False' 'True']
#  ['Everton' 'Tottenham' '0.38074569023206434' '0.2485991499822552'
#   '0.37065515978568037' 'False' 'True' 'False']]
# first2 : {} 0.8
# week10
# numOftest 20 , score 0.35
# [['Newcastle' 'Everton' '0.40915801528802664' '0.21761687057643553'
#   '0.3732251141355378' 'False' 'False' 'True']
#  ['Aston Villa' 'West Ham' '0.2881896120232916' '0.24652528954916533'
#   '0.4652850984275431' 'False' 'True' 'False']
#  ['Bournemouth' 'Crystal Palace' '0.4030092394018066' '0.23882951249798798'
#   '0.35816124810020544' 'False' 'True' 'False']
#  ['Chelsea' 'Watford' '0.48839470889553754' '0.18222608687548167'
#   '0.32937920422898065' 'False' 'True' 'False']
#  ['Southampton' 'Arsenal' '0.17823970685078278' '0.2222371584010728'
#   '0.5995231347481444' 'True' 'False' 'False']
#  ['Stoke' 'Man United' '0.30908335262343783' '0.22991312138345935'
#   '0.46100352599310296' 'True' 'False' 'False']
#  ['Liverpool' 'Leicester' '0.3596487896670803' '0.23312429670490178'
#   '0.40722691362801794' 'True' 'False' 'False']
#  ['Man United' 'Chelsea' '0.5596640911667947' '0.18856199098813733'
#   '0.25177391784506786' 'False' 'True' 'False']
#  ['Everton' 'Stoke' '0.6640140463684098' '0.17129023721231554'
#   '0.16469571641927463' 'False' 'False' 'True']
#  ['Crystal Palace' 'Swansea' '0.5918061872701657' '0.17072398545679557'
#   '0.2374698272730388' 'False' 'True' 'False']
#  ['Norwich' 'Aston Villa' '0.33020331077851006' '0.27512544264300787'
#   '0.39467124657848207' 'True' 'False' 'False']
#  ['Watford' 'Tottenham' '0.551634288783139' '0.15737534846236345'
#   '0.2909903627544975' 'False' 'False' 'True']
#  ['Leicester' 'Man City' '0.5054530452121011' '0.19979539085027628'
#   '0.2947515639376226' 'False' 'True' 'False']]
# first2 : {} 0.6
# week11
# numOftest 10 , score 0.7
# [['Newcastle' 'Aston Villa' '0.6620787427943553' '0.16224196216848763'
#   '0.17567929503715704' 'False' 'True' 'False']
#  ['Man United' 'Norwich' '0.8598680679155419' '0.08596807396771672'
#   '0.054163858116741286' 'False' 'False' 'True']
#  ['Swansea' 'West Ham' '0.4396290961730328' '0.2229653240141277'
#   '0.33740557981283953' 'False' 'True' 'False']]
# first2 : {} 0.7
# week12
# numOftest 10 , score 0.5
# [['West Ham' 'Stoke' '0.44406346454458134' '0.2281087222687586'
#   '0.32782781318666004' 'False' 'True' 'False']
#  ['Bournemouth' 'Man United' '0.06978240913854193' '0.19905840562059973'
#   '0.7311591852408583' 'True' 'False' 'False']
#  ['Norwich' 'Everton' '0.33295124099754037' '0.25506344311692797'
#   '0.41198531588553167' 'False' 'True' 'False']
#  ['Liverpool' 'West Brom' '0.7306847947246451' '0.1446164934499022'
#   '0.12469871182545277' 'False' 'True' 'False']
#  ['Tottenham' 'Newcastle' '0.8882931699863794' '0.07017605969896046'
#   '0.04153077031466008' 'False' 'False' 'True']]
# first2 : {} 0.6
# week13
# numOftest 10 , score 0.3
# [['Chelsea' 'Bournemouth' '0.7687060125349747' '0.1441659158037716'
#   '0.08712807166125376' 'False' 'False' 'True']
#  ['Man United' 'West Ham' '0.8214345242555989' '0.09304595759117802'
#   '0.08551951815322308' 'False' 'True' 'False']
#  ['Southampton' 'Aston Villa' '0.6237477090989253' '0.17199395929189557'
#   '0.20425833160917906' 'False' 'True' 'False']
#  ['Stoke' 'Man City' '0.32856476159034287' '0.22815807115602685'
#   '0.4432771672536303' 'True' 'False' 'False']
#  ['West Brom' 'Tottenham' '0.19884057976380137' '0.22496400101815645'
#   '0.5761954192180421' 'False' 'True' 'False']
#  ['Newcastle' 'Liverpool' '0.19299405908007902' '0.22565171886956809'
#   '0.5813542220503528' 'True' 'False' 'False']
#  ['Everton' 'Crystal Palace' '0.6187562500397201' '0.17702504017552906'
#   '0.20421870978475073' 'False' 'True' 'False']]
# first2 : {} 0.6
# week14
# numOftest 10 , score 0.3
# [['Aston Villa' 'Watford' '0.5972793493070243' '0.17281829551074318'
#   '0.2299023551822325' 'False' 'False' 'True']
#  ['Bournemouth' 'Everton' '0.03565943428242868' '0.1364860599359765'
#   '0.8278545057815947' 'False' 'True' 'False']
#  ['Leicester' 'Man United' '0.5336992057473904' '0.17522982510028942'
#   '0.2910709691523203' 'False' 'True' 'False']
#  ['Sunderland' 'Stoke' '0.24311379596524443' '0.28478806112260957'
#   '0.4720981429121461' 'True' 'False' 'False']
#  ['Norwich' 'Arsenal' '0.1337125262360608' '0.2049914464445438'
#   '0.6612960273193953' 'False' 'True' 'False']
#  ['Tottenham' 'Chelsea' '0.6995945440886828' '0.1479187181671164'
#   '0.1524867377442007' 'False' 'True' 'False']
#  ['West Ham' 'West Brom' '0.5409499696186378' '0.20629231760593636'
#   '0.2527577127754257' 'False' 'True' 'False']]
# first2 : {} 0.6
# week15
# numOftest 10 , score 0.4
# [['Man City' 'Liverpool' '0.7771785716285309' '0.104215106035495'
#   '0.11860632233597417' 'False' 'False' 'True']
#  ['Southampton' 'Stoke' '0.639875389488194' '0.17009889759044156'
#   '0.1900257129213645' 'False' 'False' 'True']
#  ['Swansea' 'Bournemouth' '0.8106266065126237' '0.10232238517318261'
#   '0.08705100831419355' 'False' 'True' 'False']
#  ['West Brom' 'Arsenal' '0.13797386101178338' '0.20288503673753053'
#   '0.659141102250686' 'True' 'False' 'False']
#  ['Watford' 'Man United' '0.5312555943098883' '0.1855283451257702'
#   '0.28321606056434157' 'False' 'False' 'True']
#  ['Crystal Palace' 'Sunderland' '0.5864738782743226' '0.17923806665717093'
#   '0.2342880550685064' 'False' 'False' 'True']]
# first2 : {} 0.9
# week16
# numOftest 10 , score 0.3
# [['Bournemouth' 'Newcastle' '0.6434252394250899' '0.1683140201674038'
#   '0.18826074040750623' 'False' 'False' 'True']
#  ['Norwich' 'Swansea' '0.34347901526805347' '0.23847220375521344'
#   '0.4180487809767331' 'True' 'False' 'False']
#  ['West Ham' 'Everton' '0.5698777234157855' '0.2125477452283967'
#   '0.21757453135581786' 'False' 'True' 'False']
#  ['Stoke' 'Chelsea' '0.3533798084728281' '0.2121281551667912'
#   '0.4344920363603806' 'True' 'False' 'False']
#  ['Arsenal' 'Tottenham' '0.7011422491689566' '0.14323797906161634'
#   '0.1556197717694271' 'False' 'True' 'False']
#  ['Aston Villa' 'Man City' '0.09072771312315965' '0.19807642429817948'
#   '0.711195862578661' 'False' 'True' 'False']
#  ['Liverpool' 'Crystal Palace' '0.5224070522772508' '0.1989446486183418'
#   '0.2786482991044073' 'False' 'False' 'True']]
# first2 : {} 0.8
# week17
# numOftest 10 , score 0.7
# [['Chelsea' 'Liverpool' '0.6973579297449822' '0.1452997311281725'
#   '0.15734233912684525' 'False' 'False' 'True']
#  ['Crystal Palace' 'Man United' '0.2143153705987419' '0.22527200495333072'
#   '0.5604126244479274' 'False' 'True' 'False']
#  ['Newcastle' 'Stoke' '0.49054045868873164' '0.22145693096720329'
#   '0.28800261034406516' 'False' 'True' 'False']]
# first2 : {} 0.9
# week18
# numOftest 8 , score 0.5
# [['Norwich' 'West Brom' '0.39702930950666876' '0.23556141884658366'
#   '0.36740927164674747' 'False' 'False' 'True']
#  ['West Ham' 'Chelsea' '0.3755498095475783' '0.2001738963943908'
#   '0.424276294058031' 'True' 'False' 'False']
#  ['Liverpool' 'Southampton' '0.5909269549407278' '0.17714994078437227'
#   '0.23192310427490004' 'False' 'True' 'False']
#  ['Man United' 'Man City' '0.4959232006510503' '0.1792264209502553'
#   '0.3248503783986944' 'False' 'True' 'False']]
# first2 : {} 0.75
# week19
# numOftest 8 , score 0.375
# [['Southampton' 'Leicester' '0.8140254505794441' '0.09730246194591673'
#   '0.0886720874746392' 'False' 'True' 'False']
#  ['Everton' 'Man United' '0.43981461412402706' '0.21321829880795037'
#   '0.34696708706802265' 'False' 'False' 'True']
#  ['Crystal Palace' 'West Ham' '0.5974813275050722' '0.16826072535915026'
#   '0.23425794713577763' 'False' 'False' 'True']
#  ['Tottenham' 'Liverpool' '0.6903137804138609' '0.14027263492411138'
#   '0.16941358466202774' 'False' 'True' 'False']
#  ['Swansea' 'Stoke' '0.42861965605152713' '0.2390845072364041'
#   '0.3322958367120688' 'False' 'False' 'True']]
# first2 : {} 0.875
# week20
# numOftest 9 , score 0.4444444444444444
# [['Chelsea' 'Southampton' '0.6748862475392845' '0.16674195241881998'
#   '0.15837180004189547' 'False' 'False' 'True']
#  ['Norwich' 'Leicester' '0.5257282114865127' '0.191495138882257'
#   '0.2827766496312302' 'False' 'False' 'True']
#  ['Sunderland' 'West Ham' '0.2896302316866057' '0.25698193721111007'
#   '0.4533878311022843' 'False' 'True' 'False']
#  ['Everton' 'Liverpool' '0.6190720087198959' '0.1713462173771197'
#   '0.20958177390298435' 'False' 'True' 'False']
#  ['Swansea' 'Tottenham' '0.27688777500046474' '0.2365077649296118'
#   '0.48660446006992353' 'False' 'True' 'False']]
# first2 : {} 0.555555555556
# week21
# numOftest 8 , score 0.625
# [['West Ham' 'Norwich' '0.6316265718062376' '0.1756235127590434'
#   '0.19274991543471906' 'False' 'True' 'False']
#  ['Leicester' 'Arsenal' '0.4817930832417685' '0.18208374663223595'
#   '0.3361231701259956' 'False' 'False' 'True']
#  ['Newcastle' 'Chelsea' '0.20432306914879175' '0.22264177558036974'
#   '0.5730351552708386' 'False' 'True' 'False']]
# first2 : {} 0.875
# week22
# numOftest 8 , score 0.25
# [['Aston Villa' 'West Brom' '0.43260530080121495' '0.21874284663813381'
#   '0.34865185256065123' 'False' 'False' 'True']
#  ['Man City' 'West Ham' '0.8794085033620296' '0.07594144895475108'
#   '0.044650047683219465' 'False' 'False' 'True']
#  ['Swansea' 'Everton' '0.3972023613224041' '0.2767690899798913'
#   '0.32602854869770465' 'False' 'True' 'False']
#  ['Stoke' 'Leicester' '0.41054030303713007' '0.21285119770565475'
#   '0.37660849925721523' 'False' 'True' 'False']
#  ['Chelsea' 'Arsenal' '0.3814779103050879' '0.22827128337441238'
#   '0.39025080632049974' 'True' 'False' 'False']
#  ['Liverpool' 'Norwich' '0.717733324615439' '0.1410549057955942'
#   '0.1412117695889667' 'False' 'True' 'False']]
# first2 : {} 0.5
# week23
# numOftest 8 , score 0.75
# [['Everton' 'Chelsea' '0.36196559240156934' '0.21974611115697934'
#   '0.4182882964414513' 'True' 'False' 'False']
#  ['West Brom' 'Southampton' '0.32628329902021946' '0.23473751011929553'
#   '0.4389791908604851' 'False' 'True' 'False']]
# first2 : {} 0.875
# week24
# numOftest 8 , score 0.25
# [['Aston Villa' 'Sunderland' '0.3653541553147734' '0.23263953380000693'
#   '0.40200631088521965' 'False' 'True' 'False']
#  ['Chelsea' 'Crystal Palace' '0.6836707824042626' '0.1601277912383962'
#   '0.15620142635734124' 'False' 'False' 'True']
#  ['Liverpool' 'West Ham' '0.7429393090438686' '0.13806336862315402'
#   '0.11899732233297727' 'False' 'False' 'True']
#  ['Stoke' 'West Brom' '0.7464631283515817' '0.1381263602088055'
#   '0.11541051143961288' 'False' 'False' 'True']
#  ['Tottenham' 'Everton' '0.634253226941127' '0.1720674321370578'
#   '0.19367934092181524' 'False' 'True' 'False']
#  ['Swansea' 'Man United' '0.3018305555778011' '0.22907492770426804'
#   '0.4690945167179309' 'True' 'False' 'False']]
# first2 : {} 0.375
# week25
# numOftest 8 , score 0.375
# [['Man United' 'Newcastle' '0.9039487896386607' '0.05982880750423398'
#   '0.03622240285710519' 'False' 'True' 'False']
#  ['Leicester' 'Tottenham' '0.5913402606463427' '0.17106124338107895'
#   '0.23759849597257826' 'False' 'True' 'False']
#  ['Sunderland' 'Swansea' '0.22761826534757884' '0.2325643940716344'
#   '0.5398173405807868' 'False' 'True' 'False']
#  ['Norwich' 'Stoke' '0.33874109149822423' '0.23758937031097738'
#   '0.4236695381907984' 'False' 'True' 'False']
#  ['Arsenal' 'Liverpool' '0.6778897542872397' '0.15643421739847574'
#   '0.16567602831428457' 'False' 'True' 'False']]
# first2 : {} 0.625
# week26
# numOftest 8 , score 0.625
# [['Tottenham' 'Stoke' '0.6342650895553678' '0.17202701855873306'
#   '0.19370789188589918' 'False' 'True' 'False']
#  ['Southampton' 'Everton' '0.5818875975685665' '0.1908369485174513'
#   '0.22727545391398232' 'False' 'False' 'True']
#  ['Sunderland' 'Norwich' '0.5862635165440111' '0.18577479465185529'
#   '0.2279616888041336' 'False' 'False' 'True']]
# first2 : {} 0.875
# week27
# numOftest 8 , score 0.5
# [['Chelsea' 'Swansea' '0.8191952894533794' '0.10359402041355316'
#   '0.0772106901330673' 'False' 'True' 'False']
#  ['Arsenal' 'West Ham' '0.8868940701569947' '0.07104073452990185'
#   '0.04206519531310358' 'False' 'False' 'True']
#  ['Newcastle' 'Southampton' '0.5000430113804659' '0.20221006627285315'
#   '0.2977469223466809' 'False' 'True' 'False']
#  ['Stoke' 'Liverpool' '0.4662308897826664' '0.20680992675835638'
#   '0.3269591834589772' 'False' 'False' 'True']]
# first2 : {} 0.75
# week28
# numOftest 10 , score 0.6
# [['Hull' 'Man United' '0.16917625115373858' '0.21943923767966722'
#   '0.6113845111665941' 'False' 'True' 'False']
#  ['Aston Villa' 'Burnley' '0.5362953161299634' '0.1981629268438327'
#   '0.2655417570262039' 'False' 'False' 'True']
#  ['Everton' 'Tottenham' '0.42998658557020103' '0.21716547555733096'
#   '0.35284793887246796' 'False' 'False' 'True']
#  ['Stoke' 'Liverpool' '0.3774633875950952' '0.22147747889807162'
#   '0.40105913350683314' 'True' 'False' 'False']]
# first2 : {} 1.0
# week29
# numOftest 11 , score 0.36363636363636365
# [['Liverpool' 'Crystal Palace' '0.6748020274629726' '0.15753463814149213'
#   '0.1676633343955353' 'False' 'False' 'True']
#  ['Sunderland' 'Leicester' '0.4529411578733066' '0.212036351808673'
#   '0.3350224903180204' 'False' 'True' 'False']
#  ['Burnley' 'Stoke' '0.41276504707023653' '0.22326417001817864'
#   '0.3639707829115849' 'False' 'True' 'False']
#  ['West Ham' 'Everton' '0.45244440325021695' '0.21334695336836615'
#   '0.3342086433814169' 'False' 'False' 'True']
#  ['Man United' 'Arsenal' '0.29912128434798546' '0.22412312122576328'
#   '0.4767555944262512' 'False' 'True' 'False']
#  ['West Brom' 'Chelsea' '0.20803729522975548' '0.22318792322092457'
#   '0.56877478154932' 'True' 'False' 'False']
#  ['Arsenal' 'Sunderland' '0.7153165658885297' '0.14334289824842614'
#   '0.14134053586304407' 'False' 'True' 'False']]
# first2 : {} 0.636363636364
# summary
# score:
# 0.464406779661
# 2like
#        h_Correct  h_Wrong  h_Precent  d_Correct  d_Wrong  d_Precent  \
# >80           14       10   0.583333          0        0        NaN
# 60-80         42       34   0.552632          0        0        NaN
# 50-60         21       36   0.368421          0        0        NaN
# 40-50         14       21   0.400000          0        0        NaN
# 30-40         19       22   0.463415          0        2   0.000000
# 20-30          5       36   0.121951         42      104   0.287671
# <20            6       15   0.285714         38      109   0.258503
#
#        a_Correct  a_Wrong  a_Precent
# >80            0        1   0.000000
# 60-80          6        6   0.500000
# 50-60         18       11   0.620690
# 40-50         14       30   0.318182
# 30-40         16       34   0.320000
# 20-30         22       44   0.333333
# <20           18       75   0.193548
# sum precision:[ 0.47263682  0.          0.4516129 ]

# %%
# Out:
# /home/y/scikit-learn/sklearn/metrics/classification.py:1098: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# array([ 0.56491228,  0.        ,  0.54862843])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.learning_curve import learning_curve
from custom import SoftMaxMLPClassifier
from sklearn.pipeline import Pipeline
# %matplotlib inline
import matplotlib.pyplot as plt
def testRecentNum(start, end):
    recent_range = range(start,end)
    train_means = []
    train_std = []
    test_means =[]
    test_std=[]
    first2_mean=[]
    for recent in recent_range:
        print("start recent:{}".format(recent))
        X,y = c.getH7(recent)
        clf = SoftMaxMLPClassifier(hidden_layer_sizes=[g_alpha], activation='logistic', algorithm='l-bfgs', alpha=g_alpha, 
                  learning_rate_init=0.01,learning_rate='adaptive' ,max_iter=500,early_stopping = True,verbose = 3)
        mlp = Pipeline([('scl', StandardScaler()),('clf', clf)])
        train_scores,test_scores, first2 = crossValidate(mlp,X,y,fold=10)
        #train_scores,test_scores, first2 = futureTest(mlp, X,y,numOfWeek = 15)
        train_means.append(np.mean(train_scores))
        train_std.append(np.std(train_scores))
        test_means.append(np.mean(test_scores))
        test_std.append(np.std(test_scores))
        first2_mean.append(np.mean(first2))
        print("recent {}: train_mean {}  v.s. test_mean {} , first2_mean {}".format(
                recent,np.mean(train_scores),np.mean(test_scores),np.mean(first2)))
    plotCurve(np.array(train_means),np.array(train_std),np.array(test_means),np.array(test_std),np.array(recent_range))
    return train_means,train_std,test_means,test_std,first2_mean

# %%
train_means,train_std,test_means,test_std,first2_mean=testRecentNum(1 ,15)
# Out:
# start recent:1
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [554 314 389], Acc: 0.532
# Fold: 2, Class dist.: [554 314 389], Acc: 0.532
# Fold: 3, Class dist.: [554 314 389], Acc: 0.546
# Fold: 4, Class dist.: [554 314 390], Acc: 0.557
# Fold: 5, Class dist.: [554 314 390], Acc: 0.543
# Fold: 6, Class dist.: [554 314 390], Acc: 0.514
# Fold: 7, Class dist.: [555 314 390], Acc: 0.511
# Fold: 8, Class dist.: [555 314 390], Acc: 0.525
# Fold: 9, Class dist.: [555 314 390], Acc: 0.475
# Fold: 10, Class dist.: [555 315 390], Acc: 0.486
# recent 1: train_mean 0.5517397415529908  v.s. test_mean 0.5220513405583185 , first2_mean 0.7603244144475618
# start recent:2
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [542 300 385], Acc: 0.558
# Fold: 2, Class dist.: [542 300 385], Acc: 0.514
# Fold: 3, Class dist.: [542 300 385], Acc: 0.536
# Fold: 4, Class dist.: [543 300 385], Acc: 0.540
# Fold: 5, Class dist.: [543 301 385], Acc: 0.500
# Fold: 6, Class dist.: [543 301 385], Acc: 0.522
# Fold: 7, Class dist.: [543 301 385], Acc: 0.544
# Fold: 8, Class dist.: [543 301 385], Acc: 0.500
# Fold: 9, Class dist.: [543 301 386], Acc: 0.452
# Fold: 10, Class dist.: [543 301 386], Acc: 0.474
# recent 2: train_mean 0.5572640942516806  v.s. test_mean 0.5140944034089534 , first2_mean 0.7479846492001364
# start recent:3
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [530 294 373], Acc: 0.545
# Fold: 2, Class dist.: [530 294 373], Acc: 0.507
# Fold: 3, Class dist.: [530 294 373], Acc: 0.552
# Fold: 4, Class dist.: [530 294 373], Acc: 0.530
# Fold: 5, Class dist.: [530 294 373], Acc: 0.560
# Fold: 6, Class dist.: [530 294 374], Acc: 0.511
# Fold: 7, Class dist.: [530 294 374], Acc: 0.541
# Fold: 8, Class dist.: [530 295 374], Acc: 0.515
# Fold: 9, Class dist.: [530 295 374], Acc: 0.470
# Fold: 10, Class dist.: [531 295 374], Acc: 0.504
# recent 3: train_mean 0.5616470677406641  v.s. test_mean 0.5235326708435252 , first2_mean 0.7617636583976539
# start recent:4
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [513 284 364], Acc: 0.546
# Fold: 2, Class dist.: [513 284 364], Acc: 0.508
# Fold: 3, Class dist.: [513 284 364], Acc: 0.569
# Fold: 4, Class dist.: [513 284 364], Acc: 0.554
# Fold: 5, Class dist.: [513 284 364], Acc: 0.538
# Fold: 6, Class dist.: [513 284 365], Acc: 0.512
# Fold: 7, Class dist.: [513 285 365], Acc: 0.547
# Fold: 8, Class dist.: [513 285 365], Acc: 0.523
# Fold: 9, Class dist.: [513 285 365], Acc: 0.492
# Fold: 10, Class dist.: [513 285 365], Acc: 0.508
# recent 4: train_mean 0.5649361210857612  v.s. test_mean 0.529732502236136 , first2_mean 0.7590878428741801
# start recent:5
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [501 275 353], Acc: 0.551
# Fold: 2, Class dist.: [501 275 353], Acc: 0.488
# Fold: 3, Class dist.: [501 275 353], Acc: 0.591
# Fold: 4, Class dist.: [501 275 354], Acc: 0.571
# Fold: 5, Class dist.: [501 275 354], Acc: 0.524
# Fold: 6, Class dist.: [501 275 354], Acc: 0.524
# Fold: 7, Class dist.: [501 276 354], Acc: 0.528
# Fold: 8, Class dist.: [502 276 354], Acc: 0.532
# Fold: 9, Class dist.: [502 276 354], Acc: 0.452
# Fold: 10, Class dist.: [502 276 354], Acc: 0.508
# recent 5: train_mean 0.5637815824386981  v.s. test_mean 0.5268904362761105 , first2_mean 0.7658925932645516
# start recent:6
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [486 268 348], Acc: 0.561
# Fold: 2, Class dist.: [486 268 348], Acc: 0.504
# Fold: 3, Class dist.: [486 268 348], Acc: 0.561
# Fold: 4, Class dist.: [486 268 348], Acc: 0.577
# Fold: 5, Class dist.: [486 268 348], Acc: 0.537
# Fold: 6, Class dist.: [486 268 348], Acc: 0.512
# Fold: 7, Class dist.: [486 268 348], Acc: 0.537
# Fold: 8, Class dist.: [486 268 349], Acc: 0.525
# Fold: 9, Class dist.: [486 269 349], Acc: 0.463
# Fold: 10, Class dist.: [486 269 349], Acc: 0.446
# recent 6: train_mean 0.561722875082476  v.s. test_mean 0.5222298959204197 , first2_mean 0.7566707201416955
# start recent:7
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [471 261 340], Acc: 0.521
# Fold: 2, Class dist.: [471 262 340], Acc: 0.575
# Fold: 3, Class dist.: [471 262 340], Acc: 0.558
# Fold: 4, Class dist.: [471 262 340], Acc: 0.558
# Fold: 5, Class dist.: [472 262 340], Acc: 0.521
# Fold: 6, Class dist.: [472 262 340], Acc: 0.538
# Fold: 7, Class dist.: [472 262 340], Acc: 0.546
# Fold: 8, Class dist.: [472 262 340], Acc: 0.529
# Fold: 9, Class dist.: [472 262 341], Acc: 0.466
# Fold: 10, Class dist.: [472 262 341], Acc: 0.492
# recent 7: train_mean 0.561516238852003  v.s. test_mean 0.5304408723848132 , first2_mean 0.7585897835811731
# start recent:8
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [457 252 333], Acc: 0.508
# Fold: 2, Class dist.: [457 253 334], Acc: 0.552
# Fold: 3, Class dist.: [457 253 334], Acc: 0.560
# Fold: 4, Class dist.: [457 253 334], Acc: 0.543
# Fold: 5, Class dist.: [457 253 334], Acc: 0.526
# Fold: 6, Class dist.: [457 253 334], Acc: 0.509
# Fold: 7, Class dist.: [457 253 334], Acc: 0.543
# Fold: 8, Class dist.: [457 253 334], Acc: 0.534
# Fold: 9, Class dist.: [458 253 334], Acc: 0.461
# Fold: 10, Class dist.: [458 253 334], Acc: 0.487
# recent 8: train_mean 0.5620683560878843  v.s. test_mean 0.5223542042538052 , first2_mean 0.7585725357660152
# start recent:9
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [447 246 323], Acc: 0.518
# Fold: 2, Class dist.: [447 246 323], Acc: 0.553
# Fold: 3, Class dist.: [447 246 323], Acc: 0.561
# Fold: 4, Class dist.: [447 246 323], Acc: 0.526
# Fold: 5, Class dist.: [447 247 323], Acc: 0.531
# Fold: 6, Class dist.: [447 247 323], Acc: 0.549
# Fold: 7, Class dist.: [447 247 323], Acc: 0.540
# Fold: 8, Class dist.: [448 247 323], Acc: 0.527
# Fold: 9, Class dist.: [448 247 323], Acc: 0.473
# Fold: 10, Class dist.: [448 247 324], Acc: 0.505
# recent 9: train_mean 0.5573252309738873  v.s. test_mean 0.5281868267895282 , first2_mean 0.7619358504488919
# start recent:10
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [435 242 308], Acc: 0.514
# Fold: 2, Class dist.: [435 242 308], Acc: 0.568
# Fold: 3, Class dist.: [435 242 308], Acc: 0.568
# Fold: 4, Class dist.: [435 242 309], Acc: 0.500
# Fold: 5, Class dist.: [436 242 309], Acc: 0.523
# Fold: 6, Class dist.: [436 242 309], Acc: 0.532
# Fold: 7, Class dist.: [436 242 309], Acc: 0.505
# Fold: 8, Class dist.: [436 242 309], Acc: 0.541
# Fold: 9, Class dist.: [436 242 309], Acc: 0.459
# Fold: 10, Class dist.: [436 243 309], Acc: 0.491
# recent 10: train_mean 0.5549468067812195  v.s. test_mean 0.5199022416912326 , first2_mean 0.761000879945834
# start recent:11
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [422 234 301], Acc: 0.495
# Fold: 2, Class dist.: [422 234 301], Acc: 0.551
# Fold: 3, Class dist.: [422 234 301], Acc: 0.551
# Fold: 4, Class dist.: [422 234 301], Acc: 0.533
# Fold: 5, Class dist.: [422 234 301], Acc: 0.495
# Fold: 6, Class dist.: [422 234 302], Acc: 0.519
# Fold: 7, Class dist.: [422 234 302], Acc: 0.519
# Fold: 8, Class dist.: [422 234 302], Acc: 0.519
# Fold: 9, Class dist.: [422 234 302], Acc: 0.500
# Fold: 10, Class dist.: [423 234 302], Acc: 0.514
# recent 11: train_mean 0.5550335729763464  v.s. test_mean 0.5197057712169685 , first2_mean 0.7593856798582597
# start recent:12
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [408 223 296], Acc: 0.529
# Fold: 2, Class dist.: [408 223 296], Acc: 0.577
# Fold: 3, Class dist.: [408 223 296], Acc: 0.558
# Fold: 4, Class dist.: [408 223 296], Acc: 0.558
# Fold: 5, Class dist.: [409 223 296], Acc: 0.476
# Fold: 6, Class dist.: [409 223 296], Acc: 0.534
# Fold: 7, Class dist.: [409 223 296], Acc: 0.553
# Fold: 8, Class dist.: [409 223 296], Acc: 0.524
# Fold: 9, Class dist.: [409 224 296], Acc: 0.490
# Fold: 10, Class dist.: [409 224 297], Acc: 0.495
# recent 12: train_mean 0.5590036545665162  v.s. test_mean 0.5293778070312414 , first2_mean 0.7672154953271543
# start recent:13
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [396 213 288], Acc: 0.540
# Fold: 2, Class dist.: [396 213 288], Acc: 0.530
# Fold: 3, Class dist.: [396 213 288], Acc: 0.610
# Fold: 4, Class dist.: [396 213 288], Acc: 0.560
# Fold: 5, Class dist.: [396 213 288], Acc: 0.510
# Fold: 6, Class dist.: [396 213 288], Acc: 0.520
# Fold: 7, Class dist.: [396 213 288], Acc: 0.580
# Fold: 8, Class dist.: [396 214 288], Acc: 0.535
# Fold: 9, Class dist.: [396 214 288], Acc: 0.485
# Fold: 10, Class dist.: [396 214 288], Acc: 0.465
# recent 13: train_mean 0.5626876770626165  v.s. test_mean 0.5334848484848485 , first2_mean 0.7713030303030303
# start recent:14
# start format
#  progress 1432finish
# Fold: 1, Class dist.: [380 209 278], Acc: 0.541
# Fold: 2, Class dist.: [380 209 278], Acc: 0.561
# Fold: 3, Class dist.: [380 209 278], Acc: 0.541
# Fold: 4, Class dist.: [381 210 278], Acc: 0.562
# Fold: 5, Class dist.: [381 210 278], Acc: 0.531
# Fold: 6, Class dist.: [381 210 278], Acc: 0.552
# Fold: 7, Class dist.: [381 210 278], Acc: 0.531
# Fold: 8, Class dist.: [381 210 278], Acc: 0.521
# Fold: 9, Class dist.: [381 210 278], Acc: 0.479
# Fold: 10, Class dist.: [381 210 279], Acc: 0.463
# recent 14: train_mean 0.5557846883375996  v.s. test_mean 0.5283098370927319 , first2_mean 0.7565511994271392

# %%
proba = mlp.predict_proba(X_test)
precisionMatrix(proba,y_test)

# %%
#future
mlp.fit(X,y)
inData = c.readPredict("future.csv")
print(inData)
X_in, y_in = c.getH6(5,target=inData)
res = mlp.predict(X_in)
proba= mlp.predict_proba(X_in)
print(mlp.score(X_in,y_in))
print (np.hstack([proba,y_in]))

# %%
return
print(X.shape)

# %%
X,y = c.getH7(removeInsufficient=True, encode=False)
# Out:
# start format
# finish

# %%
print(X.shape)
df = pd.DataFrame(np.hstack([X,y.reshape(y.shape[0],1)]))

df.columns = ['home','away','Referee','time','HRestTime','ARestTime','HAccP - AAccP','H/A','HWin','HDraw','HLose','H goal Diff',
'AWin','ADraw','ALose','A goal diff','moraldiff + h-a',
              'y']
print(df)
# Out:
# (1348, 17)
#                 home            away        Referee   time HRestTime  \
# 0             Fulham        Man City       M Halsey  15612         7
# 1         Man United       Tottenham          C Foy  15612         2
# 2              Stoke         Swansea         J Moss  15612         7
# 3            Norwich       Liverpool        M Jones  15612         2
# 4            Everton     Southampton      L Probert  15612         3
# 5            Arsenal         Chelsea     M Atkinson  15612         2
# 6        Aston Villa       West Brom       A Taylor  15613         4
# 7                QPR        West Ham  M Clattenburg  15614         4
# 8              Wigan         Everton       K Friend  15619         7
# 9           West Ham         Arsenal         P Dowd  15619         4
# 10         West Brom             QPR        M Jones  15619         6
# 11           Swansea         Reading         M Dean  15619         7
# 12          Man City      Sunderland      L Probert  15619         2
# 13           Chelsea         Norwich       A Taylor  15619         3
# 14         Liverpool           Stoke        L Mason  15620         2
# 15         Newcastle      Man United         H Webb  15620         2
# 16       Southampton          Fulham  M Clattenburg  15620         8
# 17         Tottenham     Aston Villa    N Swarbrick  15620         2
# 18           Norwich         Arsenal      L Probert  15633        14
# 19         Tottenham         Chelsea         M Dean  15633        13
# 20          West Ham     Southampton    N Swarbrick  15633        13
# 21           Swansea           Wigan        M Jones  15633        14
# 22        Man United           Stoke       A Taylor  15633        13
# 23         Liverpool         Reading         R East  15633        13
# 24            Fulham     Aston Villa          C Foy  15633        13
# 25         West Brom        Man City  M Clattenburg  15633        14
# 26               QPR         Everton         J Moss  15634        15
# 27        Sunderland       Newcastle     M Atkinson  15634        15
# 28           Reading          Fulham        M Jones  15640         7
# 29             Wigan        West Ham         J Moss  15640         7
# ...              ...             ...            ...    ...       ...
# 1318     Southampton         Chelsea     M Atkinson  16858        14
# 1319       Leicester         Norwich    N Swarbrick  16858        13
# 1320           Stoke     Aston Villa       K Friend  16858        14
# 1321       Tottenham         Swansea        M Jones  16859         2
# 1322      Man United         Arsenal       C Pawson  16859         2
# 1323     Aston Villa         Everton         R East  16861         3
# 1324     Bournemouth     Southampton         M Dean  16861         3
# 1325       Leicester       West Brom  M Clattenburg  16861         3
# 1326         Norwich         Chelsea        L Mason  16861         3
# 1327      Sunderland  Crystal Palace       A Taylor  16861         3
# 1328       Liverpool        Man City     M Atkinson  16862         2
# 1329        West Ham       Tottenham     A Marriner  16862         4
# 1330         Arsenal         Swansea       R Madley  16862         3
# 1331      Man United         Watford        M Jones  16862         3
# 1332           Stoke       Newcastle    N Swarbrick  16862         4
# 1333         Everton        West Ham       A Taylor  16865         3
# 1334        Man City     Aston Villa        L Mason  16865         2
# 1335         Watford       Leicester         J Moss  16865         2
# 1336       Newcastle     Bournemouth      P Tierney  16865         2
# 1337         Swansea         Norwich       C Pawson  16865         2
# 1338       Tottenham         Arsenal       M Oliver  16865         2
# 1339         Chelsea           Stoke  M Clattenburg  16865         3
# 1340     Southampton      Sunderland    N Swarbrick  16865         3
# 1341  Crystal Palace       Liverpool     A Marriner  16866         4
# 1342       West Brom      Man United         M Dean  16866         4
# 1343         Norwich        Man City         J Moss  16872         7
# 1344     Bournemouth         Swansea         R East  16872         7
# 1345           Stoke     Southampton        L Mason  16872         7
# 1346     Aston Villa       Tottenham       A Taylor  16873         8
# 1347       Leicester       Newcastle       C Pawson  16874         8
#
#      ARestTime HAccP - AAccP       H/A HWin HDraw HLose H goal Diff AWin  \
# 0            3             0         1    3     0     2           5    2
# 1            2             4   1.16667    4     0     1           6    2
# 2            3            -3  0.869565    0     4     1          -1    2
# 3            2             1   1.05556    0     3     2          -6    0
# 4            3             7   1.36842    3     1     1           4    1
# 5            3            -4  0.862069    2     3     0           7    4
# 6            3            -6  0.769231    1     1     3          -4    3
# 7            5            -6      0.75    0     2     3          -8    2
# 8            7            -9  0.678571    1     1     3          -4    3
# 9            2             2   1.08333    2     2     1           1    2
# 10           4             9   1.52941    2     2     1           0    0
# 11           7             4   1.22222    1     1     3          -4    0
# 12           7             4   1.17391    2     3     0           3    1
# 13           7            13   1.72222    4     1     0           6    0
# 14           8            -2  0.909091    1     2     2           0    1
# 15           4            -3  0.888889    1     3     1          -1    4
# 16           8            -6      0.75    1     0     4          -7    2
# 17           7             6       1.3    3     2     0           4    1
# 18          13            -9  0.653846    0     2     3          -7    3
# 19          14            -5  0.848485    4     1     0           6    4
# 20          13             7   1.38889    2     2     1           2    1
# 21          14             3   1.15789    0     2     3          -7    0
# 22          13             7   1.31818    4     0     1           8    1
# 23          14             2   1.11111    1     2     2           0    0
# 24          13             5   1.26316    2     1     2           0    1
# 25          14            -1  0.965517    3     1     1           1    3
# 26          15           -12  0.571429    0     1     4          -5    2
# 27          14            -1  0.956522    1     3     1          -2    1
# 28           7            -9  0.653846    0     2     3          -4    3
# 29           7            -9  0.666667    0     1     4          -7    2
# ...        ...           ...       ...  ...   ...   ...         ...  ...
# 1318         5             8    1.2963    4     1     0           6    2
# 1319        14            25   2.47059    3     1     1           6    0
# 1320        13            21   2.61538    1     1     3          -7    1
# 1321        15            24   2.26316    5     0     0          10    2
# 1322         4           -13  0.690476    2     1     2           2    2
# 1323         9           -14  0.481481    1     1     3          -7    2
# 1324         3            -9   0.71875    1     2     2          -3    3
# 1325         2            17   1.60714    4     0     1           7    2
# 1326         3           -13  0.551724    0     1     4          -7    3
# 1327         2             1   1.04762    1     2     2          -1    0
# 1328         2            -2  0.939394    2     1     2           4    2
# 1329         3           -12   0.72093    2     2     1           2    5
# 1330         3            20   2.05263    2     1     2           1    1
# 1331         4             0         1    2     1     2           2    2
# 1332        17            11   1.47826    2     0     3          -6    2
# 1333         2            -6  0.818182    3     0     2           6    3
# 1334         3            20   2.53846    1     1     3          -5    1
# 1335         3           -15  0.651163    1     2     2          -1    3
# 1336         3            -3      0.88    1     0     4          -8    2
# 1337         3             5    1.3125    1     2     2          -1    0
# 1338         2             6   1.16667    4     0     1           5    2
# 1339         2            -2  0.941176    3     2     0           6    3
# 1340         3             7   1.31818    2     1     2          -1    1
# 1341         3           -12  0.612903    0     2     3          -3    3
# 1342         3            -3   0.90625    2     2     1           1    3
# 1343         7           -17  0.484848    0     1     4          -5    2
# 1344         7             4   1.16667    2     1     2           0    2
# 1345         7             3   1.10345    3     1     1           1    2
# 1346         2           -29  0.309524    1     0     4         -11    3
# 1347         9            23   2.04545    3     1     1           3    1
#
#      ADraw ALose A goal diff moraldiff + h-a  y
# 0        3     0           3         -5.4577  A
# 1        2     1           2         7.24231  A
# 2        1     2           3        -0.98787  H
# 3        2     3          -6         4.26691  A
# 4        0     4          -6         20.4973  H
# 5        1     0           7         -7.3312  A
# 6        1     1           3        -16.1433  D
# 7        2     1           1        -16.4869  A
# 8        1     1           5        -18.8485  D
# 9        2     1           6         1.33957  A
# 10       2     3          -4         17.7318  H
# 11       2     3          -5         3.22343  D
# 12       4     0           1         5.22302  H
# 13       3     2          -4         26.8163  H
# 14       3     1           1        -5.98228  D
# 15       0     1           6         -7.8114  A
# 16       0     3          -1        -9.28572  D
# 17       2     2          -3         17.1502  H
# 18       1     1           8        -21.3046  H
# 19       1     0           7        -2.72658  A
# 20       1     3          -5         12.8002  H
# 21       2     3          -6        0.178857  H
# 22       3     1           1         9.43603  H
# 23       2     3          -5         7.88105  H
# 24       2     2          -3         5.66887  H
# 25       2     0           6        -6.20904  A
# 26       2     1           3        -23.5168  D
# 27       3     1          -2       -0.225469  D
# 28       1     1           4         -20.955  D
# 29       2     1           2        -21.3318  H
# ...    ...   ...         ...             ... ..
# 1318     3     0           5         9.59745  A
# 1319     1     4          -9         40.3464  H
# 1320     2     2          -6         4.67314  H
# 1321     2     1           1         24.3468  H
# 1322     2     1           2        -16.3937  H
# 1323     1     2           4        -7.89062  A
# 1324     1     1           2        -13.7102  H
# 1325     2     1           1         18.5451  D
# 1326     2     0           6        -36.2694  A
# 1327     1     4          -5         15.3122  D
# 1328     1     2           2        -2.28404  H
# 1329     0     0           8        -19.9385  H
# 1330     2     2          -1         13.1779  A
# 1331     2     1           1        -4.32401  H
# 1332     0     3          -6         3.14025  H
# 1333     1     1           3        -10.8407  A
# 1334     0     4          -9         13.3512  H
# 1335     1     1           4        -19.0615  A
# 1336     1     2          -1        -12.8138  A
# 1337     1     4          -7         19.0105  H
# 1338     1     2           1         13.5843  D
# 1339     0     2          -2         9.61243  D
# 1340     2     2          -1         1.78991  D
# 1341     1     1           8        -24.5246  A
# 1342     1     1           4        -4.45653  H
# 1343     0     3          -1        -21.0893  D
# 1344     1     2           0         1.36626  H
# 1345     1     2          -1         8.06201  A
# 1346     1     1           2        -30.6047  A
# 1347     0     4          -9         31.6266  H
#
# [1348 rows x 18 columns]

# %%
df.to_csv('dataSet/moral.csv',index=False)
