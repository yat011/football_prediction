# %%
passId = 12496
import urllib.request
raw =str(urllib.request.urlopen('http://www.espnfc.co.uk/gamecast/statistics/id/422406/statistics.html').read())

# %%
print(raw)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n<script type=\'text/javascript\'>var _sf_startpt=(new Date()).getTime()</script>\r\n<meta name="google-site-verification" content="4_qSmiePwMZeSyNswhhNiGD6LiJ5Tr98wgD77PXAaMU"/>\r\n        <script type="text/javascript">\r\n            function mobileDetectRed() {\r\n                var detectGameId;\r\n                var redirectToUrl;\r\n                try {\r\n                    var pageurl = window.location.href;\r\n                    var isGamecast = pageurl.indexOf(\'gamecast.html\') > -1 ? true : false;\r\n                    var isStatistics = pageurl.indexOf(\'statistics.html\') > -1 ? true : false;\r\n                    var urlpart;\r\n                    if (isGamecast === true) {\r\n                        urlpart = pageurl.split(\'/gamecast/\');\r\n                    }\r\n                    if(isStatistics === true) {\r\n                        urlpart = pageurl.split(\'/gamecast/statistics/id/\');\r\n        
# ...

# %%
import numpy as np
import pandas as pd
res = pd.read_html('http://www.espnfc.co.uk/gamecast/statistics/id/422406/statistics.html',
                   attrs={'class':"no-borders"},encoding='UTF-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e458ad1376b2> in <module>()
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 res = pd.read_html(raw,
#       5                    attrs={'class':"no-borders"},encoding='UTF-8')
#
# NameError: name 'raw' is not defined
